# %% [markdown]
# # Delaware Case Study
# ## Simple Model of SGD

# %%
# %matplotlib inline
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors

#Name model
modelname = 'homogenous'

# run installed version of flopy or add local path
try:
    import flopy
except:
    fpth = os.path.abspath(os.path.join('..', '..'))
    sys.path.append(fpth)
    import flopy

print(sys.version)
print('numpy version: {}'.format(np.__version__))
print('flopy version: {}'.format(flopy.__version__))

model_ws = os.path.join('/Users/ianpg/Documents/ProjectsLocal/DelawareSGD','work','flopy')
if not os.path.exists(model_ws):
    os.makedirs(model_ws)


os.listdir(model_ws)

print('Model workspace:',os.path.abspath(model_ws))
# Out:
# 3.6.1 |Anaconda custom (x86_64)| (default, May 11 2017, 13:04:09)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
# numpy version: 1.13.3
# flopy version: 3.2.6
# Model workspace: /Users/ianpg/Documents/ProjectsLocal/DelawareSGD/work/flopy

# %%
#Other functions and imports

#import function to find exepaths
sys.path.append('/Users/ianpg/Documents/ProjectsLocal/SyntheticSWI/notebooks/flopy')
import config

#nearest value in array
def find_nearest(array,value):
    import numpy as np
    idx = (np.abs(array-value)).argmin()
    idx.astype('int')
    return array[idx]

def loc_to_col(locs):
    cols = [int(find_nearest((np.arange(ncol)*delc),loc)) for loc in locs]
    return cols

# %%
#Model grid
#Grid: 0.5 *1*1m • Size:70m*20m
        
Lx = 70.
Lz = 20.
nlay = 40
nrow = 1
ncol = 70
delr = Lx / ncol
delc = 1.0
delv = Lz / nlay
henry_top = Lz
henry_botm = np.linspace(henry_top - delv, 0., nlay)

# %%
#Create basic model instance and dis pacakge

m = flopy.seawat.Seawat(modelname, exe_name=config.swexe, model_ws=model_ws,verbose=verbose)
print(m.namefile)

# Add DIS package to the MODFLOW model
dis = flopy.modflow.ModflowDis(m, nlay, nrow, ncol, nper=nper, delr=delr,
                               delc=delc, laycbd=0, top=henry_top,
                               botm=henry_botm, perlen=perlen, nstp=nstp,
                               steady=steady,itmuni=itmuni,lenuni=lenuni,
                               tsmult=tsmult)
# Out:
# User specified FTL file does not exist in model directory
# MT3D will not work without a linker file
# homogenous.nam
# adding Package:  DIS

# %%
#Hydraulic properties


#Hydraulic conductivity
hkSand = 80.  #horizontal hydraulic conductivity m/day
hkClay = 1. 
lithmat = hkSand*np.ones((nlay,nrow,ncol), dtype=np.int32) #sandy background
    
#add low conductivity region next to ocean as a barrier to flow
low_k_loc = (20,30)
low_k_col = loc_to_col(low_k_loc)
lithmat[0:20,0,low_k_col[0]:low_k_col[1]] = hkClay

lithmat=   np.random.random((nlay,nrow,ncol))*(hkSand-hkClay) + hkClay

hk = lithmat
sy = 0.15
ss = 0.00005
por = 0.2
vka = 1/10 # = vk/hk
al = 3 #longitudinal dispersivity, in m
#dmcoef = 0.57024 #m2/day  Could also try 1.62925 as another case of the Henry problem
dmcoef = 0. #test for numerical dispersion

#Variable density parameters
Csalt = 35.0001
Cfresh = 0.
densesalt = 1025.
densefresh = 1000.
denseslp = (densesalt - densefresh) / (Csalt - Cfresh)

# %%
#Stress periods
nper = 1
perlen = [100]
nstp = [100]
steady = [True]
itmuni = 4 #time unit 4= days
lenuni = 2 #length unit 2= meter
tsmult = 1
verbose=True
ssm_data = None

# %%
#BCs
calc_inland_head = 0 #don't calculate from hgrad

def calc_head_inland(calc_head_yn,manual=1):
    if calc_head_yn==1:
        head_inland = ocean_loc[0]*hgrad #calculate inland head from measured head gradient
    else:
        head_inland = manual
    return head_inland


# save cell fluxes to unit 53
ipakcb = 53

#MODFLOW BCs
hgrad = 0.0033 #hydraulic gradient, m/m
qinflow = 0  #influent FW m3/day
manual_inland_head = 10
head_inland = calc_head_inland(calc_inland_head,manual_inland_head)

#Create ocean boundary at top of model
ocean_loc = [30,70] # location of ocean [start,end] in m
ocean_col = [int(find_nearest((np.arange(ncol)*delc),loc)) for loc in ocean_loc]
ocean_col_vec = np.arange(ocean_col[0],ocean_col[1]+1)
ocean_coords = (0,0,slice(ocean_col[0],ocean_col[1]+1)) #top of the model

#Set ibound
ibound = np.ones((nlay, nrow, ncol), dtype=np.int32)
ibound[:, :, 0] = -1 #first column (FW boundary) has fixed head
ibound[ocean_coords] = -1
ibound[0:10,0,low_k_col[0]:low_k_col[1]] = 0

#Set starting heads
strt = head_inland*np.ones((nlay, nrow, ncol)) #starting heads (for fixed head BC, this is will assign the head)
strt[ocean_coords] = 0 #head of ocean boundary


#Transport BCs
sconc = Cfresh*np.ones((nlay, nrow, ncol), dtype=np.float32) #Begin fresh
sconc[ocean_coords] = Csalt

icbund = np.ones((nlay, nrow, ncol), dtype=np.int) 
icbund[(ibound < 0)] = -1 #constant concentration cells where also constant head

# %%
plt.imshow(np.squeeze(strt))

# %%
#Create instances in flopy

bas = flopy.modflow.ModflowBas(m, ibound, strt=strt)

# Add LPF package to the MODFLOW model
lpf = flopy.modflow.ModflowLpf(m, hk=hk, vka=vka, ipakcb=ipakcb, ss=ss, sy=sy)

# Add PCG Package to the MODFLOW model
pcg = flopy.modflow.ModflowPcg(m, hclose=1.e-8)

# Add OC package to the MODFLOW model
oc = flopy.modflow.ModflowOc(m,
                             stress_period_data={(0, 0): ['save head', 'save budget']},
                             compact=True)
#wel = flopy.modflow.ModflowWel(m, stress_period_data=wel_data, ipakcb=ipakcb)

#Create the basic MT3DMS model structure
btn = flopy.mt3d.Mt3dBtn(m, 
                         #nlay=nlay, nrow=nrow, ncol=ncol, nper=nper, 
                         laycon=lpf.laytyp, htop=henry_top, 
                         dz=dis.thickness.get_value(), prsity=0.2, icbund=icbund,
                         sconc=sconc, nprs=-10)
adv = flopy.mt3d.Mt3dAdv(m, mixelm=0)
dsp = flopy.mt3d.Mt3dDsp(m, al=al, trpt=1., trpv=1., dmcoef=dmcoef)
gcg = flopy.mt3d.Mt3dGcg(m, iter1=500, mxiter=1, isolve=1, cclose=1e-7)
ssm = flopy.mt3d.Mt3dSsm(m, stress_period_data=ssm_data)

#vdf = flopy.seawat.SeawatVdf(m, iwtable=0, densemin=0, densemax=0,denseref=1000., denseslp=0.7143, firstdt=1e-3)
vdf = flopy.seawat.SeawatVdf(m, mtdnconc=1, mfnadvfd=1, nswtcpl=0, iwtable=0, 
                             densemin=0., densemax=0., denseslp=denseslp, denseref=densefresh)
# Out:
# adding Package:  BAS6
# adding Package:  LPF
# adding Package:  PCG
# adding Package:  OC
# adding Package:  BTN
# adding Package:  ADV
# adding Package:  DSP
# adding Package:  GCG
# adding Package:  SSM
# adding Package:  VDF

# %%
# Make plot of the grid
f = plt.figure(figsize=(15, 5))
ax = f.add_subplot(1, 1, 1)
mm = flopy.plot.ModelCrossSection(ax=ax, model=m, line={'row':0});
hkpatchcollection = mm.plot_array(hk, norm=matplotlib.colors.LogNorm(),vmin=hkClay, vmax=hkSand);
linecollectdsion = mm.plot_grid();
patchcollection = mm.plot_ibound();
cb = plt.colorbar(patchcollection);
cb.set_label('Boundary condition',rotation=90)
cb2 = plt.colorbar(hkpatchcollection,ax=ax);
cb2.set_label('Kh (m/d)', rotation=90)
plt.title('K-field & Boundary conditions');
print(lbls)
# Out:
# [0 1 2 3]

# %%
#Write input
m.write_input()

# Try to delete the output files, to prevent accidental use of older files
try:
    os.remove(os.path.join(model_ws,'MT3D.CNF'))
    os.remove(os.path.join(model_ws,'MT3D001.MAS'))
    os.remove(os.path.join(model_ws, 'MT3D001.UCN'))
    os.remove(os.path.join(model_ws, modelname + '.hds'))
    os.remove(os.path.join(model_ws, modelname + '.cbc'))
except:
    pass
# Out:
# Writing packages:
#    Package:  DIS
#    Package:  BAS6
#    Package:  LPF
#    Package:  PCG
#    Package:  OC
#    Package:  BTN
#    Package:  ADV
#    Package:  DSP
#    Package:  GCG
#    Package:  SSM
#    Package:  VDF

# %%
#Run model
v = m.run_model(silent=False, report=True)
for idx in range(-3, 0):
    print(v[1][idx])
# Out:
# FloPy is using the following executable to run the model: /Users/ianpg/Documents/ProjectsLocal/SyntheticSWI/bin/modflow_macOS/swt_v4
#
#                                   SEAWAT Version 4
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 4.00.05 10/19/2012
#
# Incorporated MODFLOW Version: 1.18.01 06/20/2008
# Incorporated MT3DMS  Version: 5.20    10/30/2006
#
#
#  This program is public domain and is released on the
#  condition that neither the U.S. Geological Survey nor
#  the United States Government may be held liable for any
#  damages resulting from their authorized or unauthorized
#  use.
#
#
#  Using NAME file: homogenous.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/07/30 23:52:23
#
#
#  STRESS PERIOD NO.    1
#
#   STRESS PERIOD    1 TIME STEP    1 FROM TIME =   0.0000     TO    1.0000
#
#  Transport Step:    1   Step Size:  1.0000E-03 Total Elapsed Time:  1.00000E-03
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8463E-02  [K,I,J]    2    1   31
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7170E-04  [K,I,J]    3    1   31
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6094E-06  [K,I,J]    4    1   31
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5195E-08  [K,I,J]    5    1   31
#  Transport Step:    2   Step Size:  4.5103E-02 Total Elapsed Time:  4.61028E-02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1932      [K,I,J]    2    1   31
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4529E-01  [K,I,J]    3    1   31
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1060E-01  [K,I,J]    4    1   31
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2454E-02  [K,I,J]    5    1   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5538E-03  [K,I,J]    6    1   31
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1452E-03  [K,I,J]    4    1   31
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3044E-04  [K,I,J]    7    1   32
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.9387E-05  [K,I,J]    8    1   32
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.3074E-05  [K,I,J]    9    1   50
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1238E-05  [K,I,J]    9    1   32
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.5774E-06  [K,I,J]    7    1   33
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.3077E-06  [K,I,J]   12    1   44
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1657E-06  [K,I,J]   13    1   42
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.1522E-06  [K,I,J]    8    1   33
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.7710E-07  [K,I,J]    7    1   33
#  Transport Step:    3   Step Size:  4.4647E-02 Total Elapsed Time:  9.07499E-02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1345      [K,I,J]    2    1   31
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3004E-01  [K,I,J]    3    1   31
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6685E-02  [K,I,J]    4    1   31
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1487E-02  [K,I,J]    5    1   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3288E-03  [K,I,J]    6    1   31
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9356E-04  [K,I,J]    4    1   31
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2111E-04  [K,I,J]    4    1   31
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.7793E-05  [K,I,J]    7    1   69
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.3291E-05  [K,I,J]    8    1   69
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1627E-05  [K,I,J]    9    1   32
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.8375E-06  [K,I,J]   12    1   40
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.6084E-06  [K,I,J]    9    1   33
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.2620E-06  [K,I,J]    8    1   33
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.1159E-06  [K,I,J]   11    1   31
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.8940E-07  [K,I,J]    8    1   33
#  Transport Step:    4   Step Size:  4.4709E-02 Total Elapsed Time:  0.13546
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9544E-01  [K,I,J]    2    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1835E-01  [K,I,J]    3    1   32
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4098E-02  [K,I,J]    4    1   32
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9243E-03  [K,I,J]    5    1   43
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2144E-03  [K,I,J]    6    1   42
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6155E-04  [K,I,J]    4    1   31
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1733E-04  [K,I,J]    4    1   31
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.7361E-05  [K,I,J]    7    1   69
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.3897E-05  [K,I,J]   10    1   40
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.2262E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1425E-05  [K,I,J]    9    1   32
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.7532E-06  [K,I,J]    9    1   33
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.4124E-06  [K,I,J]    8    1   33
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.4507E-06  [K,I,J]   12    1   33
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.1439E-06  [K,I,J]   12    1   33
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.1372E-06  [K,I,J]   13    1   33
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.4639E-07  [K,I,J]   14    1   33
#  Transport Step:    5   Step Size:  4.4701E-02 Total Elapsed Time:  0.18016
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7013E-01  [K,I,J]    2    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1096E-01  [K,I,J]    3    1   32
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2443E-02  [K,I,J]    4    1   32
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6045E-03  [K,I,J]    4    1   70
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1583E-03  [K,I,J]    5    1   70
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.4184E-04  [K,I,J]    4    1   31
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1587E-04  [K,I,J]    4    1   31
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.7717E-05  [K,I,J]    9    1   46
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.4915E-05  [K,I,J]   11    1   40
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.2926E-05  [K,I,J]    8    1   69
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1856E-05  [K,I,J]    9    1   32
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.6993E-06  [K,I,J]   13    1   37
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.4695E-06  [K,I,J]   11    1   33
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.2849E-06  [K,I,J]   12    1   33
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.1855E-06  [K,I,J]    8    1   33
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.9661E-07  [K,I,J]    8    1   33
#  Transport Step:    6   Step Size:  4.4704E-02 Total Elapsed Time:  0.22486
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5278E-01  [K,I,J]    2    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6828E-02  [K,I,J]    2    1   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1795E-02  [K,I,J]    3    1   70
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4581E-03  [K,I,J]    4    1   70
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1189E-03  [K,I,J]    5    1   70
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3456E-04  [K,I,J]    6    1   70
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1672E-04  [K,I,J]    4    1   31
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1040E-04  [K,I,J]   10    1   40
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.6112E-05  [K,I,J]   12    1   38
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.3355E-05  [K,I,J]    8    1   32
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1687E-05  [K,I,J]    9    1   32
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.9011E-06  [K,I,J]   10    1   35
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.6095E-06  [K,I,J]   11    1   33
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.3426E-06  [K,I,J]   13    1   47
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.2085E-06  [K,I,J]   14    1   45
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.1378E-06  [K,I,J]   15    1   41
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.8420E-07  [K,I,J]   13    1   37
#  Transport Step:    7   Step Size:  4.4709E-02 Total Elapsed Time:  0.26957
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4061E-01  [K,I,J]    2    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5686E-02  [K,I,J]    2    1   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1344E-02  [K,I,J]    3    1   70
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3303E-03  [K,I,J]    4    1   70
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8746E-04  [K,I,J]    5    1   70
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2895E-04  [K,I,J]    6    1   70
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2047E-04  [K,I,J]   10    1   40
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1255E-04  [K,I,J]   11    1   38
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.7182E-05  [K,I,J]   12    1   36
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.3877E-05  [K,I,J]   12    1   37
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.2393E-05  [K,I,J]   12    1   36
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1508E-05  [K,I,J]   11    1   36
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.7908E-06  [K,I,J]   11    1   35
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.4383E-06  [K,I,J]   12    1   33
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.2570E-06  [K,I,J]   14    1   41
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.1754E-06  [K,I,J]   15    1   41
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.9660E-07  [K,I,J]   12    1   38
#  Transport Step:    8   Step Size:  4.4713E-02 Total Elapsed Time:  0.31429
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3278E-01  [K,I,J]    3    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4581E-02  [K,I,J]    2    1   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9489E-03  [K,I,J]    3    1   70
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2273E-03  [K,I,J]    4    1   70
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6502E-04  [K,I,J]    5    1   69
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3570E-04  [K,I,J]   10    1   40
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2505E-04  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1406E-04  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.7173E-05  [K,I,J]   12    1   36
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.4176E-05  [K,I,J]   13    1   38
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.3056E-05  [K,I,J]   12    1   36
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.2665E-05  [K,I,J]   11    1   36
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.3106E-05  [K,I,J]   11    1   37
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.3090E-06  [K,I,J]   12    1   38
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.1417E-05  [K,I,J]   12    1   38
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.6624E-06  [K,I,J]   12    1   38
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.5807E-06  [K,I,J]   12    1   37
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.1753E-06  [K,I,J]   12    1   38
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.6610E-07  [K,I,J]   11    1   38
#  Transport Step:    9   Step Size:  4.4717E-02 Total Elapsed Time:  0.35900
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2916E-01  [K,I,J]    3    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3657E-02  [K,I,J]    2    1   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6366E-03  [K,I,J]    3    1   70
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1502E-03  [K,I,J]    4    1   69
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5966E-04  [K,I,J]    9    1   46
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.4596E-04  [K,I,J]   10    1   40
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2688E-04  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1385E-04  [K,I,J]   12    1   38
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.7159E-05  [K,I,J]   13    1   38
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.5998E-05  [K,I,J]   10    1   31
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1034E-04  [K,I,J]   10    1   31
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1818E-05  [K,I,J]   11    1   31
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.9479E-06  [K,I,J]   11    1   32
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.6080E-06  [K,I,J]   12    1   32
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.3543E-06  [K,I,J]   11    1   32
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.1942E-06  [K,I,J]   10    1   32
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.9085E-07  [K,I,J]   14    1   48
#  Transport Step:   10   Step Size:  4.4722E-02 Total Elapsed Time:  0.40372
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2584E-01  [K,I,J]    3    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2931E-02  [K,I,J]    2    1   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4073E-03  [K,I,J]    3    1   70
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1205E-03  [K,I,J]    3    1   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7223E-04  [K,I,J]   10    1   41
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5128E-04  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2794E-04  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1622E-04  [K,I,J]   12    1   38
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.3290E-06  [K,I,J]    4    1   31
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.7662E-05  [K,I,J]   11    1   30
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.3320E-05  [K,I,J]   10    1   31
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1847E-05  [K,I,J]   11    1   31
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1286E-05  [K,I,J]   11    1   32
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.8789E-06  [K,I,J]   12    1   32
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.6072E-06  [K,I,J]   11    1   32
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.5245E-06  [K,I,J]   11    1   33
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.7088E-07  [K,I,J]   12    1   33
#  Transport Step:   11   Step Size:  4.4726E-02 Total Elapsed Time:  0.44845
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2292E-01  [K,I,J]    3    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2376E-02  [K,I,J]    2    1   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2873E-03  [K,I,J]    2    1   31
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1139E-03  [K,I,J]    3    1   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8831E-04  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6473E-04  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4099E-04  [K,I,J]   12    1   33
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3663E-04  [K,I,J]   11    1   33
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.3375E-04  [K,I,J]   12    1   33
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.6842E-04  [K,I,J]   11    1   33
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.9166E-04  [K,I,J]   11    1   33
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.6500E-05  [K,I,J]   12    1   33
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.2082E-05  [K,I,J]   11    1   33
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.1048E-05  [K,I,J]   10    1   31
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.4829E-06  [K,I,J]   11    1   41
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.3492E-06  [K,I,J]   12    1   41
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.3485E-06  [K,I,J]   12    1   35
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.3298E-06  [K,I,J]   12    1   36
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.1893E-06  [K,I,J]   11    1   36
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.5143E-07  [K,I,J]   11    1   37
#  Transport Step:   12   Step Size:  4.4731E-02 Total Elapsed Time:  0.49318
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2039E-01  [K,I,J]    3    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1956E-02  [K,I,J]    2    1   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2615E-03  [K,I,J]    2    1   31
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1271E-03  [K,I,J]    9    1   45
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1098E-03  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7375E-04  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6008E-04  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1664E-04  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1475E-04  [K,I,J]   14    1   39
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.7446E-05  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.7276E-05  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.2507E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.7331E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.1944E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.6378E-06  [K,I,J]   10    1   32
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.4544E-06  [K,I,J]   12    1   41
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.3711E-06  [K,I,J]   13    1   41
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.6593E-06  [K,I,J]   11    1   40
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.1373E-06  [K,I,J]   13    1   41
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.1889E-06  [K,I,J]   12    1   40
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.1056E-06  [K,I,J]   11    1   40
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =  0.7402E-07  [K,I,J]   11    1   40
#  Transport Step:   13   Step Size:  4.4735E-02 Total Elapsed Time:  0.53792
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1823E-01  [K,I,J]    3    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1638E-02  [K,I,J]    2    1   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2537E-03  [K,I,J]    8    1   40
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1519E-03  [K,I,J]   10    1   40
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1282E-03  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.8349E-04  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1162E-03  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1618E-03  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1460E-04  [K,I,J]   14    1   39
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1213E-04  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.2062E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1109E-04  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.3595E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.3253E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.3416E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.1522E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.9792E-06  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.1611E-06  [K,I,J]   11    1   41
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.2644E-06  [K,I,J]   11    1   40
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.1002E-06  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.1279E-06  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =  0.6315E-07  [K,I,J]   11    1   39
#  Transport Step:   14   Step Size:  4.4739E-02 Total Elapsed Time:  0.58266
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1638E-01  [K,I,J]    3    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1395E-02  [K,I,J]    2    1   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2673E-03  [K,I,J]    8    1   40
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1758E-03  [K,I,J]   10    1   40
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1453E-03  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9758E-04  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6666E-06  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.5101E-04  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1648E-04  [K,I,J]   14    1   39
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.2347E-04  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1139E-04  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.6969E-05  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.4072E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.1599E-04  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.1265E-04  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.1395E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.2248E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.1289E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.5667E-06  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.1734E-06  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.7158E-07  [K,I,J]   12    1   41
#  Transport Step:   15   Step Size:  4.4744E-02 Total Elapsed Time:  0.62740
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1487E-01  [K,I,J]    4    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1264E-02  [K,I,J]    3    1   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2809E-03  [K,I,J]    8    1   40
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1945E-03  [K,I,J]   10    1   40
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1563E-03  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1137E-03  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1702E-04  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.4057E-04  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1793E-04  [K,I,J]   14    1   39
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.3821E-03  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.3694E-03  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.6061E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.4786E-05  [K,I,J]   10    1   39
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.6010E-06  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.3095E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.1274E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.3124E-06  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.5619E-06  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.6093E-06  [K,I,J]   11    1   40
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.4574E-06  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.6678E-07  [K,I,J]   12    1   40
#  Transport Step:   16   Step Size:  4.4748E-02 Total Elapsed Time:  0.67215
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1387E-01  [K,I,J]    4    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1187E-02  [K,I,J]    3    1   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2915E-03  [K,I,J]    8    1   40
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2128E-03  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1653E-03  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1430E-03  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4553E-04  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3873E-04  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1939E-04  [K,I,J]   14    1   39
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.2935E-04  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.4323E-04  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.5967E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.5527E-05  [K,I,J]   10    1   39
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.2055E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.2239E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.1569E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.7619E-06  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.3966E-06  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.9072E-06  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.1054E-05  [K,I,J]   11    1   40
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.6884E-07  [K,I,J]   12    1   40
#  Transport Step:   17   Step Size:  4.4752E-02 Total Elapsed Time:  0.71690
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1294E-01  [K,I,J]    4    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1114E-02  [K,I,J]    3    1   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3211E-03  [K,I,J]   11    1   40
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2369E-03  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1696E-03  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1982E-03  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1003E-03  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3825E-04  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2130E-04  [K,I,J]   10    1   39
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1188E-04  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.2609E-04  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.5856E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.7126E-05  [K,I,J]   10    1   39
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.3773E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.1896E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.2585E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.1808E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.3375E-06  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.2160E-06  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.3713E-06  [K,I,J]   11    1   40
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.7162E-07  [K,I,J]   12    1   40
#  Transport Step:   18   Step Size:  4.4757E-02 Total Elapsed Time:  0.76166
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1209E-01  [K,I,J]    4    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1047E-02  [K,I,J]    3    1   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3560E-03  [K,I,J]   11    1   40
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2591E-03  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1710E-03  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3285E-03  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2300E-03  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3807E-04  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2273E-04  [K,I,J]   10    1   39
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.5736E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1988E-04  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.5842E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1098E-04  [K,I,J]   10    1   39
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.7479E-05  [K,I,J]   10    1   39
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.1743E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.1156E-04  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.1080E-04  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.3125E-06  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.1242E-06  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.2875E-06  [K,I,J]   11    1   40
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.7197E-07  [K,I,J]   12    1   39
#  Transport Step:   19   Step Size:  4.4761E-02 Total Elapsed Time:  0.80642
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1132E-01  [K,I,J]    4    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9864E-03  [K,I,J]    3    1   70
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3834E-03  [K,I,J]   11    1   40
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2799E-03  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1774E-03  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.8058E-03  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.7065E-03  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3779E-04  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2373E-04  [K,I,J]   10    1   39
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.2407E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1639E-04  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.5899E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.2684E-04  [K,I,J]   10    1   39
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.2335E-04  [K,I,J]   10    1   39
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.1663E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.4064E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.4824E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.2992E-06  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.9807E-07  [K,I,J]   11    1   39
#  Transport Step:   20   Step Size:  4.4766E-02 Total Elapsed Time:  0.85118
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1062E-01  [K,I,J]    4    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9322E-03  [K,I,J]    8    1   52
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4047E-03  [K,I,J]   11    1   40
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3004E-03  [K,I,J]   12    1   40
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1817E-03  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9273E-02  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.9172E-02  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3758E-04  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2454E-04  [K,I,J]   10    1   39
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.8718E-06  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1490E-04  [K,I,J]   12    1   32
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.6144E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.8238E-04  [K,I,J]   10    1   39
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.8597E-04  [K,I,J]   10    1   39
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.1646E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.1834E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.2607E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.2980E-06  [K,I,J]   13    1   38
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.1230E-06  [K,I,J]   13    1   38
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.3049E-06  [K,I,J]   13    1   40
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.7249E-07  [K,I,J]   12    1   39
#  Transport Step:   21   Step Size:  4.4770E-02 Total Elapsed Time:  0.89595
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9977E-02  [K,I,J]    4    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9400E-03  [K,I,J]    8    1   52
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4169E-03  [K,I,J]   11    1   40
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3164E-03  [K,I,J]   12    1   40
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1833E-03  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1223E-02  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1324E-02  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3663E-04  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2521E-04  [K,I,J]   11    1   32
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.9539E-06  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1422E-04  [K,I,J]   12    1   32
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.6071E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1402E-04  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.1746E-04  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.1582E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.1077E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.1854E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.3017E-06  [K,I,J]   13    1   38
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.1137E-06  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.2949E-06  [K,I,J]   13    1   40
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.7206E-07  [K,I,J]   12    1   39
#  Transport Step:   22   Step Size:  4.4775E-02 Total Elapsed Time:  0.94073
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9393E-02  [K,I,J]    4    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9442E-03  [K,I,J]    8    1   52
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4251E-03  [K,I,J]   11    1   40
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3312E-03  [K,I,J]   12    1   40
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1832E-03  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9868E-03  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1089E-02  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3715E-04  [K,I,J]   12    1   52
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2635E-04  [K,I,J]   11    1   32
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1884E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1400E-04  [K,I,J]   12    1   32
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.6120E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.8239E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.1172E-04  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.1555E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.8178E-06  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.1604E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.3062E-06  [K,I,J]   13    1   38
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.1357E-06  [K,I,J]   13    1   38
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.3151E-06  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.7156E-07  [K,I,J]   12    1   39
#  Transport Step:   23   Step Size:  4.4779E-02 Total Elapsed Time:  0.98551
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8859E-02  [K,I,J]    4    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9449E-03  [K,I,J]    8    1   52
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4295E-03  [K,I,J]   11    1   40
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3434E-03  [K,I,J]   12    1   40
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1818E-03  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1285E-02  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1389E-02  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3779E-04  [K,I,J]   12    1   52
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2732E-04  [K,I,J]   11    1   32
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.2464E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1393E-04  [K,I,J]   12    1   32
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.6155E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.6194E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.9721E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.1533E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.7265E-06  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.1523E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.3088E-06  [K,I,J]   13    1   38
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.1709E-06  [K,I,J]   13    1   38
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.3472E-06  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.7118E-07  [K,I,J]   12    1   39
#  Transport Step:   24   Step Size:  1.4492E-02 Total Elapsed Time:   1.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2729E-02  [K,I,J]    4    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2259E-03  [K,I,J]   10    1   40
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1059E-03  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3892E-04  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1676E-04  [K,I,J]   12    1   31
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1203E-04  [K,I,J]   11    1   31
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6113E-05  [K,I,J]   12    1   31
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2030E-05  [K,I,J]   12    1   32
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1031E-05  [K,I,J]   11    1   32
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.5046E-06  [K,I,J]   12    1   32
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1941E-06  [K,I,J]   11    1   31
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.6628E-07  [K,I,J]   12    1   33
#
#   STRESS PERIOD    1 TIME STEP    2 FROM TIME =   1.0000     TO    2.0000
#
#  Transport Step:    1   Step Size:  4.4788E-02 Total Elapsed Time:   1.0448
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8218E-02  [K,I,J]    4    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9413E-03  [K,I,J]    8    1   52
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4316E-03  [K,I,J]   11    1   40
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3555E-03  [K,I,J]   12    1   40
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1785E-03  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5962E-02  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6066E-02  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3825E-04  [K,I,J]   12    1   52
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2863E-04  [K,I,J]   11    1   32
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.3101E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1389E-04  [K,I,J]   12    1   32
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.6175E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.4700E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.8273E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.1556E-05  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.7096E-06  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.1520E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.3091E-06  [K,I,J]   13    1   38
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.2179E-06  [K,I,J]   13    1   38
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.3907E-06  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.7075E-07  [K,I,J]   12    1   39
#  Transport Step:    2   Step Size:  4.4789E-02 Total Elapsed Time:   1.0896
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7783E-02  [K,I,J]    4    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9344E-03  [K,I,J]    8    1   52
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4312E-03  [K,I,J]   11    1   40
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3614E-03  [K,I,J]   12    1   40
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1753E-03  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2058E-02  [K,I,J]   11    1   31
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1976E-02  [K,I,J]   11    1   31
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3828E-04  [K,I,J]   12    1   52
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2898E-04  [K,I,J]   11    1   32
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.3022E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1412E-04  [K,I,J]   10    1   32
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.6152E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.4779E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.8369E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.1583E-05  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.9037E-06  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.1720E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.3087E-06  [K,I,J]   13    1   38
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.3292E-06  [K,I,J]   13    1   38
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.4979E-06  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.7081E-07  [K,I,J]   12    1   39
#  Transport Step:    3   Step Size:  4.4793E-02 Total Elapsed Time:   1.1344
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7422E-02  [K,I,J]    5    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9248E-03  [K,I,J]    8    1   52
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4298E-03  [K,I,J]   11    1   40
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3649E-03  [K,I,J]   12    1   40
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1719E-03  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9220E-03  [K,I,J]   11    1   31
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.8381E-03  [K,I,J]   11    1   31
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3816E-04  [K,I,J]   12    1   52
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2940E-04  [K,I,J]   11    1   32
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.2978E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1440E-04  [K,I,J]   10    1   32
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.6119E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.4850E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.8453E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.1604E-05  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.1220E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.2040E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.3071E-06  [K,I,J]   13    1   38
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.5098E-06  [K,I,J]   13    1   38
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.6781E-06  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.7100E-07  [K,I,J]   12    1   39
#  Transport Step:    4   Step Size:  4.4798E-02 Total Elapsed Time:   1.1792
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7118E-02  [K,I,J]    5    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9249E-03  [K,I,J]    9    1   48
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4278E-03  [K,I,J]   11    1   40
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3664E-03  [K,I,J]   12    1   40
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1684E-03  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6123E-03  [K,I,J]   11    1   31
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.5261E-03  [K,I,J]   11    1   31
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3792E-04  [K,I,J]   12    1   52
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2968E-04  [K,I,J]   11    1   32
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.2918E-05  [K,I,J]   10    1   32
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1473E-04  [K,I,J]   10    1   32
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.6073E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.5179E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.8787E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.1619E-05  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.1868E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.2689E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.3053E-06  [K,I,J]   13    1   38
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.1013E-05  [K,I,J]   13    1   38
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.1182E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.7140E-07  [K,I,J]   12    1   39
#  Transport Step:    5   Step Size:  4.4802E-02 Total Elapsed Time:   1.2240
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6832E-02  [K,I,J]    5    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9256E-03  [K,I,J]    9    1   48
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4254E-03  [K,I,J]   11    1   40
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3661E-03  [K,I,J]   12    1   40
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1651E-03  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.4687E-03  [K,I,J]   11    1   31
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3805E-03  [K,I,J]   11    1   31
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3761E-04  [K,I,J]   12    1   52
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2980E-04  [K,I,J]   11    1   32
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.2746E-05  [K,I,J]   10    1   32
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1513E-04  [K,I,J]   10    1   32
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.6017E-05  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.5822E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.9431E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.1629E-05  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.3568E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.4390E-05  [K,I,J]   12    1   39
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.3036E-06  [K,I,J]   13    1   38
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.1078E-04  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.1095E-04  [K,I,J]   11    1   39
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.7205E-07  [K,I,J]   12    1   39
#  Transport Step:    6   Step Size:  4.4806E-02 Total Elapsed Time:   1.2688
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6563E-02  [K,I,J]    5    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9233E-03  [K,I,J]    9    1   48
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4229E-03  [K,I,J]   11    1   40
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3644E-03  [K,I,J]   12    1   40
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1619E-03  [K,I,J]   13    1   39
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3857E-03  [K,I,J]   11    1   31
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2959E-03  [K,I,J]   11    1   31
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3725E-04  [K,I,J]   12    1   52
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2979E-04  [K,I,J]   11    1   32
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.2436E-05  [K,I,J]   10    1   32
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1560E-04  [K,I,J]   10    1   32
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.5952E-05  [K,I,J]   11    1   39
# ...
#  Transport Step:   20   Step Size:  4.4971E-02 Total Elapsed Time:   98.899
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6338E-04  [K,I,J]   30    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6352E-05  [K,I,J]   17    1   68
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1695E-05  [K,I,J]   12    1   66
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4661E-06  [K,I,J]   12    1   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1597E-06  [K,I,J]   13    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1134E-06  [K,I,J]   12    1   55
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6064E-07  [K,I,J]   12    1   54
#  Transport Step:   21   Step Size:  4.4971E-02 Total Elapsed Time:   98.944
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6335E-04  [K,I,J]   30    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6347E-05  [K,I,J]   17    1   68
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1696E-05  [K,I,J]   12    1   66
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4803E-06  [K,I,J]   12    1   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2002E-06  [K,I,J]   13    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9507E-07  [K,I,J]   11    1   31
#  Transport Step:   22   Step Size:  4.4971E-02 Total Elapsed Time:   98.989
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6332E-04  [K,I,J]   30    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6340E-05  [K,I,J]   17    1   68
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1690E-05  [K,I,J]   12    1   66
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4499E-06  [K,I,J]   12    1   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2052E-06  [K,I,J]   11    1   30
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1293E-06  [K,I,J]   13    1   56
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6477E-07  [K,I,J]   12    1   54
#  Transport Step:   23   Step Size:  1.0629E-02 Total Elapsed Time:   99.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1463E-04  [K,I,J]   29    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5569E-06  [K,I,J]   17    1   66
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6716E-07  [K,I,J]   12    1   61
#
#   STRESS PERIOD    1 TIME STEP  100 FROM TIME =   99.000     TO    100.00
#
#  Transport Step:    1   Step Size:  4.4971E-02 Total Elapsed Time:   99.045
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6328E-04  [K,I,J]   30    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6334E-05  [K,I,J]   17    1   68
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1693E-05  [K,I,J]   12    1   66
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4820E-06  [K,I,J]   12    1   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2229E-06  [K,I,J]   13    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1142E-06  [K,I,J]   12    1   55
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4817E-07  [K,I,J]   11    1   53
#  Transport Step:    2   Step Size:  4.4971E-02 Total Elapsed Time:   99.090
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6325E-04  [K,I,J]   30    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6329E-05  [K,I,J]   17    1   68
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1690E-05  [K,I,J]   12    1   66
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4788E-06  [K,I,J]   12    1   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2146E-06  [K,I,J]   13    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9964E-07  [K,I,J]   12    1   55
#  Transport Step:    3   Step Size:  4.4971E-02 Total Elapsed Time:   99.135
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6322E-04  [K,I,J]   30    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6322E-05  [K,I,J]   17    1   68
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1688E-05  [K,I,J]   12    1   66
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4540E-06  [K,I,J]   12    1   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1538E-06  [K,I,J]   11    1   26
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1221E-06  [K,I,J]   13    1   56
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6364E-07  [K,I,J]   12    1   54
#  Transport Step:    4   Step Size:  4.4971E-02 Total Elapsed Time:   99.180
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6319E-04  [K,I,J]   30    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6317E-05  [K,I,J]   17    1   68
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1689E-05  [K,I,J]   12    1   66
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4779E-06  [K,I,J]   12    1   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2074E-06  [K,I,J]   13    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9664E-07  [K,I,J]   12    1   55
#  Transport Step:    5   Step Size:  4.4971E-02 Total Elapsed Time:   99.225
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6316E-04  [K,I,J]   30    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6310E-05  [K,I,J]   17    1   68
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1684E-05  [K,I,J]   12    1   66
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4505E-06  [K,I,J]   12    1   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2232E-06  [K,I,J]   11    1   30
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1254E-06  [K,I,J]   13    1   56
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6296E-07  [K,I,J]   12    1   54
#  Transport Step:    6   Step Size:  4.4971E-02 Total Elapsed Time:   99.270
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6313E-04  [K,I,J]   30    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6305E-05  [K,I,J]   17    1   68
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1686E-05  [K,I,J]   12    1   66
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4758E-06  [K,I,J]   12    1   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1943E-06  [K,I,J]   13    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9644E-07  [K,I,J]   12    1   55
#  Transport Step:    7   Step Size:  4.4971E-02 Total Elapsed Time:   99.315
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6310E-04  [K,I,J]   30    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6298E-05  [K,I,J]   17    1   68
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1680E-05  [K,I,J]   12    1   66
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4569E-06  [K,I,J]   12    1   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1474E-06  [K,I,J]   13    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1171E-06  [K,I,J]   13    1   56
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6209E-07  [K,I,J]   12    1   54
#  Transport Step:    8   Step Size:  4.4971E-02 Total Elapsed Time:   99.360
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6307E-04  [K,I,J]   30    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6293E-05  [K,I,J]   17    1   68
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1683E-05  [K,I,J]   12    1   66
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4771E-06  [K,I,J]   12    1   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2077E-06  [K,I,J]   13    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9634E-07  [K,I,J]   12    1   55
#  Transport Step:    9   Step Size:  4.4971E-02 Total Elapsed Time:   99.405
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6304E-04  [K,I,J]   30    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6286E-05  [K,I,J]   17    1   68
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1678E-05  [K,I,J]   12    1   66
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4493E-06  [K,I,J]   12    1   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2307E-06  [K,I,J]   11    1   30
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1242E-06  [K,I,J]   13    1   56
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6222E-07  [K,I,J]   12    1   54
#  Transport Step:   10   Step Size:  4.4971E-02 Total Elapsed Time:   99.450
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6301E-04  [K,I,J]   30    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6281E-05  [K,I,J]   17    1   68
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1680E-05  [K,I,J]   12    1   66
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4728E-06  [K,I,J]   12    1   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1877E-06  [K,I,J]   13    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9769E-07  [K,I,J]   12    1   55
#  Transport Step:   11   Step Size:  4.4971E-02 Total Elapsed Time:   99.495
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6298E-04  [K,I,J]   30    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6275E-05  [K,I,J]   17    1   68
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1675E-05  [K,I,J]   12    1   66
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4575E-06  [K,I,J]   12    1   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1483E-06  [K,I,J]   13    1   57
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1146E-06  [K,I,J]   12    1   55
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6152E-07  [K,I,J]   12    1   54
#  Transport Step:   12   Step Size:  4.4971E-02 Total Elapsed Time:   99.540
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6295E-04  [K,I,J]   30    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6270E-05  [K,I,J]   17    1   68
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1677E-05  [K,I,J]   12    1   66
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4752E-06  [K,I,J]   12    1   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2069E-06  [K,I,J]   13    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9605E-07  [K,I,J]   12    1   55
#  Transport Step:   13   Step Size:  4.4971E-02 Total Elapsed Time:   99.585
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6292E-04  [K,I,J]   30    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6263E-05  [K,I,J]   17    1   68
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1672E-05  [K,I,J]   12    1   66
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4475E-06  [K,I,J]   12    1   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2226E-06  [K,I,J]   11    1   30
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1238E-06  [K,I,J]   13    1   56
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6186E-07  [K,I,J]   12    1   54
#  Transport Step:   14   Step Size:  4.4971E-02 Total Elapsed Time:   99.630
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6289E-04  [K,I,J]   30    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6258E-05  [K,I,J]   17    1   68
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1674E-05  [K,I,J]   12    1   66
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4709E-06  [K,I,J]   12    1   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1866E-06  [K,I,J]   13    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9753E-07  [K,I,J]   12    1   55
#  Transport Step:   15   Step Size:  4.4971E-02 Total Elapsed Time:   99.675
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6286E-04  [K,I,J]   30    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6252E-05  [K,I,J]   17    1   68
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1669E-05  [K,I,J]   12    1   66
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4560E-06  [K,I,J]   12    1   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1480E-06  [K,I,J]   13    1   57
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1140E-06  [K,I,J]   12    1   55
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6117E-07  [K,I,J]   12    1   54
#  Transport Step:   16   Step Size:  4.4971E-02 Total Elapsed Time:   99.720
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6283E-04  [K,I,J]   30    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6247E-05  [K,I,J]   17    1   68
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1671E-05  [K,I,J]   12    1   66
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4732E-06  [K,I,J]   12    1   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2053E-06  [K,I,J]   13    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9552E-07  [K,I,J]   12    1   55
#  Transport Step:   17   Step Size:  4.4971E-02 Total Elapsed Time:   99.765
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6280E-04  [K,I,J]   30    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6240E-05  [K,I,J]   17    1   68
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1666E-05  [K,I,J]   12    1   66
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4456E-06  [K,I,J]   12    1   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2164E-06  [K,I,J]   11    1   30
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1234E-06  [K,I,J]   13    1   56
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6161E-07  [K,I,J]   12    1   54
#  Transport Step:   18   Step Size:  4.4971E-02 Total Elapsed Time:   99.809
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6277E-04  [K,I,J]   30    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6236E-05  [K,I,J]   17    1   68
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1668E-05  [K,I,J]   12    1   66
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4693E-06  [K,I,J]   12    1   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1867E-06  [K,I,J]   13    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9698E-07  [K,I,J]   12    1   55
#  Transport Step:   19   Step Size:  4.4971E-02 Total Elapsed Time:   99.854
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6274E-04  [K,I,J]   30    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6229E-05  [K,I,J]   17    1   68
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1663E-05  [K,I,J]   12    1   66
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4541E-06  [K,I,J]   12    1   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1474E-06  [K,I,J]   13    1   57
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1136E-06  [K,I,J]   12    1   55
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6086E-07  [K,I,J]   12    1   54
#  Transport Step:   20   Step Size:  4.4971E-02 Total Elapsed Time:   99.899
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6271E-04  [K,I,J]   30    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6224E-05  [K,I,J]   17    1   68
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1665E-05  [K,I,J]   12    1   66
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4713E-06  [K,I,J]   12    1   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2036E-06  [K,I,J]   13    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9492E-07  [K,I,J]   12    1   55
#  Transport Step:   21   Step Size:  4.4971E-02 Total Elapsed Time:   99.944
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6268E-04  [K,I,J]   30    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6217E-05  [K,I,J]   17    1   68
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1660E-05  [K,I,J]   12    1   66
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4439E-06  [K,I,J]   12    1   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2129E-06  [K,I,J]   11    1   30
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1230E-06  [K,I,J]   13    1   56
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6140E-07  [K,I,J]   12    1   54
#  Transport Step:   22   Step Size:  4.4971E-02 Total Elapsed Time:   99.989
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6265E-04  [K,I,J]   30    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6213E-05  [K,I,J]   17    1   68
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1663E-05  [K,I,J]   12    1   66
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4677E-06  [K,I,J]   12    1   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1869E-06  [K,I,J]   13    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9637E-07  [K,I,J]   12    1   55
#  Transport Step:   23   Step Size:  1.0630E-02 Total Elapsed Time:   100.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1446E-04  [K,I,J]   29    1   70
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5455E-06  [K,I,J]   17    1   66
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6472E-07  [K,I,J]   12    1   61
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/07/30 23:52:52
#  Elapsed run time: 28.505 Seconds
#
#  Normal termination of SEAWAT
#  Elapsed run time: 28.505 Seconds
#
#  Normal termination of SEAWAT

# %% [markdown]
# ## Post-processing results

# %%
times = ucnobj.get_times()
hds = hdobj.get_data(totim=times[-1])
hds[np.where(ibound != 1)] = np.nan
kstpkper = ucnobj.get_kstpkper()

#Find the kstpkper index with the beginning of each period
#per_init = []
#for per in range(nper):
#    per_init.append(kstpkper.index((0,per)))

#Extract Discharge data
def plotdischarge(modelname,model_ws,color='w',kstpkper_ind=-1,scale=50):
    fname = os.path.join(model_ws, '' + modelname + '.cbc')
    budobj = flopy.utils.CellBudgetFile(fname)
    qx = budobj.get_data(text='FLOW RIGHT FACE')[kstpkper_ind]
    qz = budobj.get_data(text='FLOW LOWER FACE')[kstpkper_ind]
    
    # Average flows to cell centers
    qx_avg = np.empty(qx.shape, dtype=qx.dtype)
    qx_avg[:, :, 1:] = 0.5 * (qx[:, :, 0:ncol-1] + qx[:, :, 1:ncol])
    qx_avg[:, :, 0] = 0.5 * qx[:, :, 0]
    qz_avg = np.empty(qz.shape, dtype=qz.dtype)
    qz_avg[1:, :, :] = 0.5 * (qz[0:nlay-1, :, :] + qz[1:nlay, :, :])
    qz_avg[0, :, :] = 0.5 * qz[0, :, :]
    
    y, x, z = dis.get_node_coordinates()
    X, Z = np.meshgrid(x, z[:, 0, 0])
    iskip = 1 #how many cells to skip, 1 means plot every cell
    
    ax = plt.gca()
    cpatchcollection = ax.quiver(X[::iskip, ::iskip], Z[::iskip, ::iskip],
              qx_avg[::iskip, 0, ::iskip], -qz_avg[::iskip, 0, ::iskip],
              color=color, scale=scale, headwidth=4, headlength=2,
              headaxislength=1, width=0.0025)
    return cpatchcollection

def permute_kstpkper(ucnobj):
    kstpkper = ucnobj.get_kstpkper()
    kstpkper_unique = []
    index_unique = []
    niter = 0
    for entry in kstpkper:
        if not entry in kstpkper_unique:
            kstpkper_unique.append(entry)
            index_unique.append(niter)
        niter += 1
    return kstpkper_unique, index_unique

def kstpkper_from_time(ucnobj,tottim):
    kstpkpers = ucnobj.get_kstpkper()
    times = ucnobj.get_times()
    timeind = times.index(tottim)    
    kstpkper = kstpkpers[timeind]
    return kstpkper

def kstpkper_ind_from_kstpkper(ucnobj,kstpkper=(0,0)):
    kstpkpers = ucnobj.get_kstpkper()
    kstpkper_unique = permute_kstpkper(ucnobj)[0]
    kstpkper_ind = kstpkper_unique.index(kstpkper)
    return kstpkper_ind

def get_ocean_outflow(m,ocean_coords):
    fname = os.path.join(m.model_ws, m.name + '.cbc') 
    budobj = flopy.utils.CellBudgetFile(fname)
    qx = budobj.get_data(text='FLOW RIGHT FACE')[-1]
    qz = budobj.get_data(text='FLOW LOWER FACE')[-1]
    ocean_flow = np.sqrt(np.square(-qz[ocean_coords]) + np.square(qx[ocean_coords]))
    return ocean_flow

# %% [markdown]
# #Temporarily removed... the 'constant head' data doesn't seem right...
# def get_ocean_outflow(m,ocean_col):
#     fname = os.path.join(m.model_ws, m.name + '.cbc')
#     budobj = flopy.utils.CellBudgetFile(fname)
#     ch = budobj.get_data(text='CONSTANT HEAD')
#     ocean_col_vec = np.arange(ocean_col[0],ocean_col[1]+1)
#     ocean_nodes = np.ravel_multi_index([np.zeros(ocean_col_vec.size,dtype=int), #nodes in constant head flow file are 1-based
#                                       np.zeros(ocean_col_vec.size,dtype=int),   #create a list of node numbers for ocean cells
#                                       ocean_col_vec],
#                                      (m.dis.nlay,m.dis.nrow,m.dis.ncol)) + 1
#
#     ocean_flow =  [ch[-1]['q'][i] for i,node in enumerate(ch[-1]['node']) if node in ocean_nodes]
#     tot_flow = np.sum(ocean_flow)
#     return flow

# %%
# Extract heads
fname = os.path.join(model_ws, '' + modelname + '.hds')
times = ucnobj.get_times()
hdobj = flopy.utils.binaryfile.HeadFile(fname)
hds = hdobj.get_data(totim=times[-1])
hds[np.where(ibound != 1)] = np.nan

# Extract salinity
fname = os.path.join(model_ws, 'MT3D001.UCN')
ucnobj = flopy.utils.binaryfile.UcnFile(fname)
times = ucnobj.get_times()
conc = ucnobj.get_data(totim=times[-1])
conc[np.where(ibound != 1)] = np.nan

# %%
# Make head and quiver plot
plot_hds_conc = 'conc'
#f = plt.figure(figsize=(15, 15))
f, axs = plt.subplots(2,1, sharex=True, figsize=(15, 8),
                     gridspec_kw = {'height_ratios':[1, 7]})
plt.tight_layout()

#Plot discharge and ibound
mm = flopy.plot.ModelCrossSection(ax=axs[1], model=m, line={'row':0})
if plot_hds_conc == 'conc':
    cpatchcollection = mm.plot_array(conc,cmap='jet')
else:
    cpatchcollection = mm.plot_array(hds,cmap='jet')

mm.plot_ibound()
plotdischarge(modelname,model_ws,color='white',kstpkper_ind=-1,scale=50);
plt.xlabel('Distance (m)')
plt.ylabel('Height (m)')

#plot SGD
ocean_flow = get_ocean_outflow(m,ocean_coords)


plt.sca(axs[0]) #set current axes
plt.bar(ocean_col_vec+delc/2,np.asarray(ocean_flow))
axs[0].set_ylim(np.min(ocean_flow),np.max(ocean_flow))
plt.ylabel('SGD (m^3/d)')
axs[0].annotate('total flow = ' + str(np.sum(ocean_flow)) + ' m^3/d', xy=(.1,.5),
            xytext=(0.1, 0.5), xycoords='axes fraction', textcoords='axes fraction')

#align plots and set colorbar
f.subplots_adjust(right=0.93)
cbar_ax = f.add_axes([0.95, 0.1, 0.02, 0.7])
cb = f.colorbar(cpatchcollection,cax=cbar_ax)

if plot_hds_conc=='conc':
    cb.set_label('Concentration (g/L)')
else:
    cb.set_label('Head (m)')
plt.savefig(os.path.join(model_ws, modelname + '_flow_vectors.png'),dpi=300)
plt.show()
# Out:
# /Users/ianpg/anaconda/lib/python3.6/site-packages/flopy/utils/binaryfile.py:756: FutureWarning: Assignment between structured arrays with different field names will change in numpy 1.14.
#
# Previously fields in the dst would be set to the value of the identically-named field in the src. In numpy 1.14 fields will instead be assigned 'by position': The Nth field of the dst will be set to the Nth field of the src array.
#
# See the release notes for details
#   header2 = header2.astype(self.header2_dtype)

# %%
plt.plot(ocean_flow)

# %%
#Issue: which "flow" is the correct flow?
    #Can get flow from the cell-by-cell file in either FLOW RIGHT FACE and FLOW LOWER FACE
    # Or from the constant head flow

ocean_flow = get_ocean_outflow(m,ocean_col);
print('total flow into ocean cells from const. head flow:',-np.sum(ocean_flow),'m^3/d')

fname = os.path.join(model_ws, '' + modelname + '.cbc')
budobj = flopy.utils.CellBudgetFile(fname)
qx = budobj.get_data(text='FLOW RIGHT FACE')[-1]
qz = budobj.get_data(text='FLOW LOWER FACE')[-1]
tot_flow = np.sum( np.sqrt(np.square(-qz[ocean_coords]) + np.square(qx[ocean_coords])))
print('Total flow from lower-right face in cbc file', tot_flow ,'m^3/d' )
# Out:
# /Users/ianpg/anaconda/lib/python3.6/site-packages/flopy/utils/binaryfile.py:756: FutureWarning: Assignment between structured arrays with different field names will change in numpy 1.14.
#
# Previously fields in the dst would be set to the value of the identically-named field in the src. In numpy 1.14 fields will instead be assigned 'by position': The Nth field of the dst will be set to the Nth field of the src array.
#
# See the release notes for details
#   header2 = header2.astype(self.header2_dtype)
# total flow into ocean cells from const. head flow: 42.1443 m^3/d
# Total flow from lower-right face in cbc file 0.479019 m^3/d

# %%
alltimes = ucnobj.get_times()

conc = ucnobj.get_data(totim=alltimes[-1])
conc[np.where(ibound != 1)] = np.nan

#Plot
f = plt.figure(figsize=(15, 5))
ax = plt.subplot(1, 1, 1)
xs = flopy.plot.ModelCrossSection(ax=ax, model=m, line={'row': 0})
xs.plot_ibound();
pc = xs.plot_array(conc, vmin=Cfresh, vmax=Csalt)
plt.colorbar(pc)

# %%
fname = os.path.join(model_ws, '' + modelname + '.cbc')
budobj = flopy.utils.CellBudgetFile(fname)
qx = budobj.get_data(text='FLOW RIGHT FACE')[-1]
qz = budobj.get_data(text='FLOW LOWER FACE')[-1]
ch = budobj.get_data(text='CONSTANT HEAD')
budobj.get_unique_record_names();
# Out:
# /Users/ianpg/anaconda/lib/python3.6/site-packages/flopy/utils/binaryfile.py:756: FutureWarning: Assignment between structured arrays with different field names will change in numpy 1.14.
#
# Previously fields in the dst would be set to the value of the identically-named field in the src. In numpy 1.14 fields will instead be assigned 'by position': The Nth field of the dst will be set to the Nth field of the src array.
#
# See the release notes for details
#   header2 = header2.astype(self.header2_dtype)

# %%
# Out:
# Total vertical flux from -22.536

# %%
# Out:
# '/Users/ianpg/Documents/ProjectsLocal/DelawareSGD/work/flopy/homogenous.cbc'
