# %% [markdown]
# # Delaware Case Study
# ## Simple Model of SGD

# %%
# %matplotlib inline
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors
import warnings

#Name model
modelname = 'test'

# run installed version of flopy or add local path
try:
    import flopy
except:
    fpth = os.path.abspath(os.path.join('..', '..'))
    sys.path.append(fpth)
    import flopy
import SGD

print(sys.version)
print('numpy version: {}'.format(np.__version__))
print('flopy version: {}'.format(flopy.__version__))

if sys.platform == "darwin":
    model_ws = os.path.join('/Users/ianpg/Documents/ProjectsLocal/DelawareSGD','work',modelname)
elif sys.platform == "win32":
    model_ws = os.path.join('E:\Projects\DelawareSGD','work',modelname)    

if not os.path.exists(model_ws):
    os.makedirs(model_ws)
sys.path.append(os.path.join(model_ws,'..','..'))
import config
sw_exe = config.swexe

os.listdir(model_ws)

print('Model workspace:',os.path.abspath(model_ws))
# Out:
# 3.5.5 |Anaconda 4.2.0 (64-bit)| (default, Apr  7 2018, 04:52:34) [MSC v.1900 64 bit (AMD64)]
# numpy version: 1.15.0
# flopy version: 3.2.9
# Model workspace: E:\Projects\DelawareSGD\work\test

# %%
#Other functions and imports

#nearest value in array
def find_nearest(array,value):
    import numpy as np
    idx = (np.abs(array-value)).argmin()
    idx.astype('int')
    return array[idx]

#take distance in meters, return column in model
def loc_to_col(locs):
    cols = [int(find_nearest((np.arange(ncol)*delc),loc)) for loc in locs]
    return cols

# %%
#Model grid
#Grid: 0.5 *1*1m • Size:70m*20m
        
Lx = 70.
Lz = 20.
nlay = 40
nrow = 3
ncol = 70
delr = Lx / ncol
delc = 1.0
delv = Lz / nlay
henry_top = Lz
henry_botm = np.linspace(henry_top - delv, 0., nlay)

#Period data
perlen = [1,100]
nstp = [100,100]
nper = len(perlen)
steady = [True,False]
itmuni = 4 #time unit 4= days
lenuni = 2 #length unit 2 = meter
tsmult = 1
ssm_data = None
verbose = True

# %%
#Create basic model instance and dis pacakge
m = flopy.seawat.Seawat(modelname, exe_name=sw_exe, model_ws=model_ws,verbose=verbose)
SGD.ModelSGD.Seawat2SGD(m)
print(m.namefile)

# Add DIS package to the MODFLOW model
dis = flopy.modflow.ModflowDis(m, nlay, nrow, ncol, nper=nper, delr=delr,
                               delc=delc, laycbd=0, top=henry_top,
                               botm=henry_botm, perlen=perlen, nstp=nstp,
                               steady=steady,itmuni=itmuni,lenuni=lenuni,
                               tsmult=tsmult)
# Out:
# test.nam
# adding Package:  DIS

# %%
#Hydraulic conductivity field 

hkSand = 80.  #horizontal hydraulic conductivity m/day
hkClay = 1. 
lithmat = hkSand*np.ones((nlay,nrow,ncol), dtype=np.int32) #sandy background
addclay_yn = 1


def rand_clay_blocks(lithmat,hkClay,numblocks,sizeblocks):
    nlay,nrow,ncol = lithmat.shape
    lay_block = np.random.randint(1,nlay-sizeblocks[0],numblocks)
    row_block = np.random.randint(0,nrow-sizeblocks[1]+1,numblocks)
    col_block = np.random.randint(1,ncol-sizeblocks[2],numblocks)
    lithmat_blocks = lithmat.copy()
    for i in range(numblocks):
        block_coords = [slice(lay_block[i],lay_block[i]+sizeblocks[0]),
                        slice(row_block[i],row_block[i]+sizeblocks[1]),
                        slice(col_block[i],col_block[i]+sizeblocks[2])]
        lithmat_blocks[block_coords] = hkClay
    return lithmat_blocks

#add low conductivity regions
if addclay_yn == 1:
    lithmat = rand_clay_blocks(lithmat,hkClay,100,(2,1,5))
low_k_loc = (20,30)
low_k_col = loc_to_col(low_k_loc)
#lithmat[1:3,0,0:65] = hkClay
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:19: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
#Set Hydraulic properties

hk = lithmat
sy = 0.15
ss = 0.00005
por = 0.2
vka = 1/10 # = vk/hk
al = 3 #longitudinal dispersivity, in m
#dmcoef = 0.57024 #m2/day  Could also try 1.62925 as another case of the Henry problem
dmcoef = 0. #test for numerical dispersion

#Variable density parameters
Csalt = 35.0001
Cfresh = 0.
densesalt = 1025.
densefresh = 1000.
denseslp = (densesalt - densefresh) / (Csalt - Cfresh)

# %%
#BCs
calc_inland_head = 1 #don't calculate from hgrad
manual_inland_head = Lz + .1
ocean_shead = [Lz,Lz-.5]
ocean_ehead = ocean_shead
start_fresh_yn = 1

# save cell fluxes to unit 53
ipakcb = 53

#MODFLOW BCs
hgrad = 0.0033 #hydraulic gradient, m/m
qinflow = 0  #influent FW m3/day

#Create ocean boundary at top of model
ocean_loc = [30,70] # location of ocean [start,end] in m
ocean_col = [int(find_nearest((np.arange(ncol)*delc),loc)) for loc in ocean_loc]
ocean_col_vec = (0,0,np.arange(ocean_col[0],ocean_col[1]+1))
ocean_coords = (0,slice(0,nrow),slice(ocean_col[0],ocean_col[1]+1)) #top of the model
ocean_bool = np.zeros((nlay,nrow,ncol), dtype=bool)
ocean_bool[0,:,np.arange(ocean_col[0],ocean_col[1]+1)] = 1
m.ocean_arr = ocean_bool
if calc_inland_head ==1:
    head_inland = ocean_loc[0]*hgrad + Lz
else:
    head_inland = manual_inland_head


#Set ibound
ibound = np.ones((nlay, nrow, ncol), dtype=np.int32)
ibound[:, :, 0] = -1 #first column (FW boundary) has fixed head
ibound[ocean_bool] = -1
ibound[0:2,:,ocean_col[0]-3:ocean_col[0]] = 0

#Set starting heads
strt = head_inland*np.ones((nlay, nrow, ncol)) #starting heads (for fixed head BC, this is will assign the head)
strt[ocean_bool] = ocean_shead[0] #head of ocean boundary

#Transport BCs
if start_fresh_yn == 1:
    sconc = Cfresh*np.ones((nlay, nrow, ncol), dtype=np.float32) #Begin fresh
elif start_fresh_yn == 0:
    sconc = Csalt*np.ones((nlay, nrow, ncol), dtype=np.float32) #Begin SW-saturated

sconc[ocean_bool] = Csalt
sconc[:,:,0] = Cfresh

icbund = np.ones((nlay, nrow, ncol), dtype=np.int) 
icbund[(ibound < 0)] = -1 #constant concentration cells where also constant head

#Constant head boundary
stress_period_data = {}
ocean_sub = np.where(ocean_bool)
for i in range(nper):
    dat = []
    for j in range(np.sum(ocean_bool)):
        dat.append([ocean_sub[0][j],ocean_sub[1][j],ocean_sub[2][j],ocean_shead[i],ocean_ehead[i]])
    stress_period_data[i] = dat

# %%
#Create instances in flopy

bas = flopy.modflow.ModflowBas(m, ibound, strt=strt)

# Add LPF package to the MODFLOW model
lpf = flopy.modflow.ModflowLpf(m, hk=hk, vka=vka, ipakcb=ipakcb, ss=ss, sy=sy)

# Add PCG Package to the MODFLOW model
pcg = flopy.modflow.ModflowPcg(m, hclose=1.e-8)

# Add OC package to the MODFLOW model
oc = flopy.modflow.ModflowOc(m,
                             stress_period_data={(0, 0): ['save head', 'save budget']},
                             compact=True)
#wel = flopy.modflow.ModflowWel(m, stress_period_data=wel_data, ipakcb=ipakcb)

#Create the basic MT3DMS model structure
btn = flopy.mt3d.Mt3dBtn(m, 
                         #nlay=nlay, nrow=nrow, ncol=ncol, nper=nper, 
                         laycon=lpf.laytyp, htop=henry_top, 
                         dz=dis.thickness.get_value(), prsity=0.2, icbund=icbund,
                         sconc=sconc, nprs=-10)
adv = flopy.mt3d.Mt3dAdv(m, mixelm=0)
dsp = flopy.mt3d.Mt3dDsp(m, al=al, trpt=1., trpv=1., dmcoef=dmcoef)
gcg = flopy.mt3d.Mt3dGcg(m, iter1=500, mxiter=1, isolve=1, cclose=1e-7)
ssm = flopy.mt3d.Mt3dSsm(m, stress_period_data=ssm_data)
chd = flopy.modflow.ModflowChd(m, stress_period_data=stress_period_data)
#vdf = flopy.seawat.SeawatVdf(m, iwtable=0, densemin=0, densemax=0,denseref=1000., denseslp=0.7143, firstdt=1e-3)
vdf = flopy.seawat.SeawatVdf(m, mtdnconc=1, mfnadvfd=1, nswtcpl=0, iwtable=0, 
                             densemin=0., densemax=0., denseslp=denseslp, denseref=densefresh)
# Out:
# adding Package:  BAS6
# Adding test.cbc (unit=53) to the output list.
# adding Package:  LPF
# adding Package:  PCG
# Adding test.hds (unit=51) to the output list.
# adding Package:  OC
# adding Package:  BTN
# adding Package:  ADV
# adding Package:  DSP
# adding Package:  GCG
# adding Package:  SSM
# adding Package:  CHD
# adding Package:  VDF

# %%
#Write input
m.write_input()

# Try to delete the output files, to prevent accidental use of older files
try:
    os.remove(os.path.join(model_ws,'MT3D.CNF'))
    os.remove(os.path.join(model_ws,'MT3D001.MAS'))
    os.remove(os.path.join(model_ws, 'MT3D001.UCN'))
    os.remove(os.path.join(model_ws, modelname + '.hds'))
    os.remove(os.path.join(model_ws, modelname + '.cbc'))
except:
    pass
# Out:
# Writing packages:
#    Package:  DIS
#    Package:  BAS6
#    Package:  LPF
#    Package:  PCG
#    Package:  OC
#    Package:  BTN
#    Package:  ADV
#    Package:  DSP
#    Package:  GCG
#    Package:  SSM
#    Package:  CHD
#    Package:  VDF

# %%
#Run model
v = m.run_model(silent=False, report=True)
for idx in range(-3, 0):
    print(v[1][idx])
# Out:
# FloPy is using the following executable to run the model: E:\Projects\DelawareSGD\bin\win64\swt_v4.exe
#
#                                   SEAWAT Version 4
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 4.00.05 10/19/2012
#
# Incorporated MODFLOW Version: 1.18.01 06/20/2008
# Incorporated MT3DMS  Version: 5.20    10/30/2006
#
#
#  This program is public domain and is released on the
#  condition that neither the U.S. Geological Survey nor
#  the United States Government may be held liable for any
#  damages resulting from their authorized or unauthorized
#  use.
#
#
#  Using NAME file: test.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/08/29 17:43:37
#
#
#  STRESS PERIOD NO.    1
#
#   STRESS PERIOD    1 TIME STEP    1 FROM TIME =   0.0000     TO   0.10000E-01
#
#  Transport Step:    1   Step Size:  1.0000E-03 Total Elapsed Time:  1.00000E-03
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7784E-03  [K,I,J]    2    2   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6106E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4438E-07  [K,I,J]    4    2   33
#  Transport Step:    2   Step Size:  9.0000E-03 Total Elapsed Time:  1.00000E-02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7332E-02  [K,I,J]    2    2   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4741E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3098E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2128E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7289E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP    2 FROM TIME =  0.10000E-01 TO   0.20000E-01
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  2.00000E-02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7240E-02  [K,I,J]    2    2   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5313E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3617E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2632E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.9891E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP    3 FROM TIME =  0.20000E-01 TO   0.30000E-01
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  3.00000E-02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6543E-02  [K,I,J]    2    2   33
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5027E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3253E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2492E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.9407E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP    4 FROM TIME =  0.30000E-01 TO   0.40000E-01
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  4.00000E-02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6195E-02  [K,I,J]    2    2   34
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4921E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3055E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2432E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.9310E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP    5 FROM TIME =  0.40000E-01 TO   0.50000E-01
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  5.00000E-02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5874E-02  [K,I,J]    2    2   34
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4806E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2868E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2338E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.9014E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP    6 FROM TIME =  0.50000E-01 TO   0.60000E-01
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  6.00000E-02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5548E-02  [K,I,J]    2    2   34
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4672E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2692E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2246E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8700E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP    7 FROM TIME =  0.60000E-01 TO   0.70000E-01
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  7.00000E-02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5258E-02  [K,I,J]    2    2   34
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4551E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2550E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2175E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8465E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP    8 FROM TIME =  0.70000E-01 TO   0.80000E-01
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  8.00000E-02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5071E-02  [K,I,J]    2    1   39
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4444E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2434E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2117E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8263E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP    9 FROM TIME =  0.80000E-01 TO   0.90000E-01
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  9.00000E-02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4953E-02  [K,I,J]    2    1   39
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4341E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2334E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2065E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8074E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   10 FROM TIME =  0.90000E-01 TO   0.10000E+00
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  1.00000E-01
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4842E-02  [K,I,J]    2    1   40
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4243E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2249E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2021E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7906E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   11 FROM TIME =  0.10000E+00 TO   0.11000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.11000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4741E-02  [K,I,J]    2    1   40
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4151E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2177E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1982E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7757E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   12 FROM TIME =  0.11000     TO   0.12000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.12000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4642E-02  [K,I,J]    2    1   40
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4063E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2114E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1948E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7620E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   13 FROM TIME =  0.12000     TO   0.13000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.13000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4545E-02  [K,I,J]    2    1   40
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3980E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2059E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1918E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7495E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   14 FROM TIME =  0.13000     TO   0.14000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.14000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4450E-02  [K,I,J]    2    1   40
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3900E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2010E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1891E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7378E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   15 FROM TIME =  0.14000     TO   0.15000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.15000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4358E-02  [K,I,J]    2    1   40
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3824E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1967E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1866E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7268E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   16 FROM TIME =  0.15000     TO   0.16000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.16000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4275E-02  [K,I,J]    2    1   41
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3751E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1927E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1842E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7164E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   17 FROM TIME =  0.16000     TO   0.17000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.17000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4194E-02  [K,I,J]    2    1   41
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3681E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1891E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1820E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7064E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   18 FROM TIME =  0.17000     TO   0.18000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.18000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4114E-02  [K,I,J]    2    1   41
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3614E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1857E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1799E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6969E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   19 FROM TIME =  0.18000     TO   0.19000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.19000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4036E-02  [K,I,J]    2    1   41
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3550E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1826E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1779E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6877E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   20 FROM TIME =  0.19000     TO   0.20000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.20000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3961E-02  [K,I,J]    2    1   41
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3488E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1797E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1759E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6789E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   21 FROM TIME =  0.20000     TO   0.21000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.21000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3886E-02  [K,I,J]    2    1   41
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3428E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1769E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1740E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6703E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   22 FROM TIME =  0.21000     TO   0.22000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.22000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3814E-02  [K,I,J]    2    1   41
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3370E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1742E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1721E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6621E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   23 FROM TIME =  0.22000     TO   0.23000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.23000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3747E-02  [K,I,J]    2    1   42
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3315E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1717E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1703E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6540E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   24 FROM TIME =  0.23000     TO   0.24000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.24000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3683E-02  [K,I,J]    2    1   42
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3261E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1693E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1685E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6462E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   25 FROM TIME =  0.24000     TO   0.25000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.25000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3620E-02  [K,I,J]    2    1   42
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3210E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1670E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1667E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6386E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   26 FROM TIME =  0.25000     TO   0.26000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.26000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3558E-02  [K,I,J]    2    1   42
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3160E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1648E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1649E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6313E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   27 FROM TIME =  0.26000     TO   0.27000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.27000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3498E-02  [K,I,J]    2    1   42
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3111E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1626E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1632E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6241E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   28 FROM TIME =  0.27000     TO   0.28000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.28000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3438E-02  [K,I,J]    2    1   42
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3065E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1605E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1615E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6172E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   29 FROM TIME =  0.28000     TO   0.29000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.29000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3381E-02  [K,I,J]    2    1   42
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3020E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1585E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1598E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6104E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   30 FROM TIME =  0.29000     TO   0.30000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.30000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3324E-02  [K,I,J]    2    1   42
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2976E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1565E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1582E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6038E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   31 FROM TIME =  0.30000     TO   0.31000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.31000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3269E-02  [K,I,J]    2    1   42
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2934E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1546E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1566E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5974E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   32 FROM TIME =  0.31000     TO   0.32000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.32000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3215E-02  [K,I,J]    2    1   42
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2893E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1528E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1550E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5912E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   33 FROM TIME =  0.32000     TO   0.33000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.33000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3162E-02  [K,I,J]    2    1   42
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2854E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1510E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1534E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5851E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   34 FROM TIME =  0.33000     TO   0.34000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.34000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3110E-02  [K,I,J]    2    1   42
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2816E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1492E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1519E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5792E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   35 FROM TIME =  0.34000     TO   0.35000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.35000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3060E-02  [K,I,J]    2    1   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2778E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1475E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1503E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5735E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   36 FROM TIME =  0.35000     TO   0.36000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.36000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3013E-02  [K,I,J]    2    1   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2743E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1458E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1488E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5678E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   37 FROM TIME =  0.36000     TO   0.37000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.37000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2967E-02  [K,I,J]    2    1   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2708E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1442E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1474E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5624E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   38 FROM TIME =  0.37000     TO   0.38000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.38000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2922E-02  [K,I,J]    2    1   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2674E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1426E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1459E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5570E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   39 FROM TIME =  0.38000     TO   0.39000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.39000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2878E-02  [K,I,J]    2    1   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2641E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1411E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1445E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5518E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   40 FROM TIME =  0.39000     TO   0.40000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.40000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2836E-02  [K,I,J]    2    1   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2609E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1396E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1431E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5467E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   41 FROM TIME =  0.40000     TO   0.41000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.41000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2793E-02  [K,I,J]    2    1   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2578E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1381E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1418E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5417E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   42 FROM TIME =  0.41000     TO   0.42000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.42000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2752E-02  [K,I,J]    2    1   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2548E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1367E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1404E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5369E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   43 FROM TIME =  0.42000     TO   0.43000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.43000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2712E-02  [K,I,J]    2    1   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2519E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1353E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1391E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5322E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   44 FROM TIME =  0.43000     TO   0.44000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.44000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2672E-02  [K,I,J]    2    1   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2491E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1339E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1378E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5275E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   45 FROM TIME =  0.44000     TO   0.45000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.45000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2634E-02  [K,I,J]    2    1   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2463E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1326E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1365E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5230E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   46 FROM TIME =  0.45000     TO   0.46000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.46000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2596E-02  [K,I,J]    2    1   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2436E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1313E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1353E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5186E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   47 FROM TIME =  0.46000     TO   0.47000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.47000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2559E-02  [K,I,J]    2    1   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2410E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1300E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1341E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5143E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   48 FROM TIME =  0.47000     TO   0.48000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.48000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2541E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2384E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1288E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1329E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5100E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   49 FROM TIME =  0.48000     TO   0.49000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.49000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2527E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2360E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1276E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1317E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5059E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   50 FROM TIME =  0.49000     TO   0.50000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.50000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2513E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2336E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1264E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1305E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5019E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   51 FROM TIME =  0.50000     TO   0.51000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.51000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2500E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2312E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1252E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1294E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4979E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   52 FROM TIME =  0.51000     TO   0.52000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.52000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2486E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2289E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1241E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1283E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4940E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   53 FROM TIME =  0.52000     TO   0.53000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.53000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2472E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2267E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1230E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1272E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4902E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   54 FROM TIME =  0.53000     TO   0.54000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.54000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2458E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2245E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1219E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1261E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4865E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   55 FROM TIME =  0.54000     TO   0.55000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.55000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2444E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2223E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1208E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1251E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4828E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   56 FROM TIME =  0.55000     TO   0.56000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.56000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2430E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2203E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1198E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1240E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4793E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   57 FROM TIME =  0.56000     TO   0.57000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.57000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2416E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2182E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1187E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1230E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4757E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   58 FROM TIME =  0.57000     TO   0.58000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.58000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2401E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2162E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1177E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1220E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4723E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   59 FROM TIME =  0.58000     TO   0.59000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.59000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2387E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2143E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1168E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1210E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4689E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   60 FROM TIME =  0.59000     TO   0.60000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.60000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2373E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2124E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1158E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1201E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4656E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   61 FROM TIME =  0.60000     TO   0.61000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.61000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2359E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2106E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1149E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1191E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4624E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   62 FROM TIME =  0.61000     TO   0.62000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.62000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2345E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2088E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1139E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1182E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4592E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   63 FROM TIME =  0.62000     TO   0.63000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.63000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2331E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2070E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1130E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1173E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4560E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   64 FROM TIME =  0.63000     TO   0.64000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.64000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2317E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2052E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1121E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1164E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4530E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   65 FROM TIME =  0.64000     TO   0.65000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.65000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2303E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2035E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1113E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1155E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4499E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   66 FROM TIME =  0.65000     TO   0.66000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.66000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2289E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2019E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1104E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1146E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4470E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   67 FROM TIME =  0.66000     TO   0.67000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.67000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2275E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2003E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1096E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1138E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4440E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   68 FROM TIME =  0.67000     TO   0.68000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.68000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2261E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1987E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1088E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1129E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4412E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   69 FROM TIME =  0.68000     TO   0.69000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.69000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2247E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1971E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1079E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1121E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4383E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   70 FROM TIME =  0.69000     TO   0.70000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.70000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2233E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1956E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1072E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1113E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4356E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   71 FROM TIME =  0.70000     TO   0.71000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.71000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2219E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1941E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1064E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1105E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4328E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   72 FROM TIME =  0.71000     TO   0.72000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.72000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2205E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1926E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1056E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1097E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4301E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   73 FROM TIME =  0.72000     TO   0.73000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.73000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2191E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1911E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1049E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1090E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4275E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   74 FROM TIME =  0.73000     TO   0.74000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.74000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2178E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1897E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1041E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1082E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4249E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   75 FROM TIME =  0.74000     TO   0.75000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.75000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2164E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1883E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1034E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1074E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4223E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   76 FROM TIME =  0.75000     TO   0.76000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.76000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2150E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1870E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1027E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1067E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4198E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   77 FROM TIME =  0.76000     TO   0.77000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.77000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2137E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1856E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1020E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1060E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4173E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   78 FROM TIME =  0.77000     TO   0.78000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.78000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2123E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1843E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1013E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1053E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4148E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   79 FROM TIME =  0.78000     TO   0.79000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.79000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2109E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1830E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1006E-04  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1046E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4124E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   80 FROM TIME =  0.79000     TO   0.80000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.80000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2096E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1817E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9995E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1039E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4100E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   81 FROM TIME =  0.80000     TO   0.81000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.81000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2083E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1805E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9929E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1032E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4077E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   82 FROM TIME =  0.81000     TO   0.82000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.82000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2069E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1792E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9865E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1025E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4053E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   83 FROM TIME =  0.82000     TO   0.83000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.83000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2056E-02  [K,I,J]    2    3   53
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1780E-03  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9801E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1019E-05  [K,I,J]    3    2   33
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4030E-07  [K,I,J]    2    2   33
#
#   STRESS PERIOD    1 TIME STEP   84 FROM TIME =  0.83000     TO   0.84000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.84000
# ...
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4912E-03  [K,I,J]   14    3   50
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2984E-04  [K,I,J]    7    2   66
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1164E-04  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4697E-05  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1201E-05  [K,I,J]    6    2   61
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7633E-06  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2933E-06  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1156E-06  [K,I,J]    6    2   59
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.6497E-07  [K,I,J]    6    2   61
#  Transport Step:    5   Step Size:  8.9008E-02 Total Elapsed Time:   99.445
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4909E-03  [K,I,J]   14    3   50
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2979E-04  [K,I,J]    7    2   66
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1162E-04  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4678E-05  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1201E-05  [K,I,J]    6    2   61
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7304E-06  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2109E-06  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1051E-06  [K,I,J]    4    1   35
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.6865E-07  [K,I,J]    6    2   60
#  Transport Step:    6   Step Size:  8.9008E-02 Total Elapsed Time:   99.534
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4906E-03  [K,I,J]   14    3   50
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2974E-04  [K,I,J]    7    2   66
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1160E-04  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4682E-05  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1194E-05  [K,I,J]    6    2   61
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7573E-06  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2809E-06  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1025E-06  [K,I,J]    6    2   59
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.5983E-07  [K,I,J]    4    1   35
#  Transport Step:    7   Step Size:  8.9008E-02 Total Elapsed Time:   99.623
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4903E-03  [K,I,J]   14    3   50
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2969E-04  [K,I,J]    7    2   66
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1158E-04  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4671E-05  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1182E-05  [K,I,J]    6    2   61
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7097E-06  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1799E-06  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1017E-06  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.7069E-07  [K,I,J]    6    2   60
#  Transport Step:    8   Step Size:  8.9008E-02 Total Elapsed Time:   99.712
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4900E-03  [K,I,J]   14    3   50
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2964E-04  [K,I,J]    7    2   66
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1156E-04  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4669E-05  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1184E-05  [K,I,J]    6    2   61
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7554E-06  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2855E-06  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1100E-06  [K,I,J]    6    2   59
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.6759E-07  [K,I,J]    4    1   35
#  Transport Step:    9   Step Size:  8.9008E-02 Total Elapsed Time:   99.801
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4897E-03  [K,I,J]   14    3   50
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2959E-04  [K,I,J]    7    2   66
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1153E-04  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4650E-05  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1176E-05  [K,I,J]    6    2   61
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6991E-06  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1708E-06  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1077E-06  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.7106E-07  [K,I,J]    6    2   60
#  Transport Step:   10   Step Size:  8.9008E-02 Total Elapsed Time:   99.890
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4894E-03  [K,I,J]   14    3   50
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2954E-04  [K,I,J]    7    2   66
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1151E-04  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4650E-05  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1179E-05  [K,I,J]    5    2   60
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7522E-06  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2874E-06  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1118E-06  [K,I,J]    6    2   59
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.6110E-07  [K,I,J]    4    1   35
#  Transport Step:   11   Step Size:  8.9007E-02 Total Elapsed Time:   99.979
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4891E-03  [K,I,J]   14    3   50
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2949E-04  [K,I,J]    7    2   66
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1148E-04  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4631E-05  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1172E-05  [K,I,J]    6    2   61
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6974E-06  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1730E-06  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1045E-06  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.7050E-07  [K,I,J]    6    2   60
#  Transport Step:   12   Step Size:  2.0913E-02 Total Elapsed Time:  100.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1131E-03  [K,I,J]   14    3   50
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3623E-05  [K,I,J]    6    2   61
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5085E-06  [K,I,J]    5    2   57
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6670E-07  [K,I,J]    7    2   61
#
#   STRESS PERIOD    2 TIME STEP  100 FROM TIME =  100.000     TO    101.00
#
#  Transport Step:    1   Step Size:  8.9007E-02 Total Elapsed Time:   100.09
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4887E-03  [K,I,J]   14    3   50
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2942E-04  [K,I,J]    7    2   66
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1146E-04  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4627E-05  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1176E-05  [K,I,J]    6    2   61
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7472E-06  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2886E-06  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1126E-06  [K,I,J]    6    2   59
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.6353E-07  [K,I,J]    6    2   61
#  Transport Step:    2   Step Size:  8.9007E-02 Total Elapsed Time:   100.18
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4883E-03  [K,I,J]   14    3   50
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2937E-04  [K,I,J]    7    2   66
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1143E-04  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4608E-05  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1177E-05  [K,I,J]    6    2   61
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7249E-06  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2285E-06  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1020E-06  [K,I,J]    4    1   35
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.6366E-07  [K,I,J]    6    2   60
#  Transport Step:    3   Step Size:  8.9007E-02 Total Elapsed Time:   100.27
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4880E-03  [K,I,J]   14    3   50
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2932E-04  [K,I,J]    7    2   66
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1141E-04  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4611E-05  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1167E-05  [K,I,J]    6    2   61
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7389E-06  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2680E-06  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.9665E-07  [K,I,J]    6    2   59
#  Transport Step:    4   Step Size:  8.9007E-02 Total Elapsed Time:   100.36
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4877E-03  [K,I,J]   14    3   50
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2927E-04  [K,I,J]    7    2   66
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1138E-04  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4587E-05  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1148E-05  [K,I,J]    5    2   58
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6452E-06  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1748E-06  [K,I,J]    4    1   35
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1324E-06  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.7086E-07  [K,I,J]    6    2   60
#  Transport Step:    5   Step Size:  8.9007E-02 Total Elapsed Time:   100.45
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4874E-03  [K,I,J]   14    3   50
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2922E-04  [K,I,J]    7    2   66
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1137E-04  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4595E-05  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1165E-05  [K,I,J]    5    2   58
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7368E-06  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2726E-06  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1031E-06  [K,I,J]    6    2   59
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.5850E-07  [K,I,J]    3    1   35
#  Transport Step:    6   Step Size:  8.9007E-02 Total Elapsed Time:   100.53
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4870E-03  [K,I,J]   14    3   50
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2917E-04  [K,I,J]    7    2   66
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1134E-04  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4583E-05  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1156E-05  [K,I,J]    5    2   60
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7131E-06  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2116E-06  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.9176E-07  [K,I,J]    4    1   34
#  Transport Step:    7   Step Size:  8.9007E-02 Total Elapsed Time:   100.62
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4867E-03  [K,I,J]   14    3   50
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2912E-04  [K,I,J]    7    2   66
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1130E-04  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4551E-05  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1154E-05  [K,I,J]    6    2   61
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6671E-06  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1536E-06  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1147E-06  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.6994E-07  [K,I,J]    6    2   60
#  Transport Step:    8   Step Size:  8.9007E-02 Total Elapsed Time:   100.71
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4864E-03  [K,I,J]   14    3   50
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2907E-04  [K,I,J]    7    2   66
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1130E-04  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4565E-05  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1153E-05  [K,I,J]    5    2   60
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7304E-06  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2701E-06  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.9970E-07  [K,I,J]    6    2   59
#  Transport Step:    9   Step Size:  8.9007E-02 Total Elapsed Time:   100.80
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4860E-03  [K,I,J]   14    3   50
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2902E-04  [K,I,J]    7    2   66
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1127E-04  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4548E-05  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1143E-05  [K,I,J]    5    2   58
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6411E-06  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1634E-06  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1305E-06  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.6962E-07  [K,I,J]    6    2   60
#  Transport Step:   10   Step Size:  8.9007E-02 Total Elapsed Time:   100.89
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4857E-03  [K,I,J]   14    3   50
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2897E-04  [K,I,J]    7    2   66
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1126E-04  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4553E-05  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1156E-05  [K,I,J]    5    2   58
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7291E-06  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2757E-06  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1094E-06  [K,I,J]    6    2   59
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.6808E-07  [K,I,J]    4    1   35
#  Transport Step:   11   Step Size:  8.9007E-02 Total Elapsed Time:   100.98
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4853E-03  [K,I,J]   14    3   50
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2892E-04  [K,I,J]    7    2   66
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1123E-04  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4537E-05  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1142E-05  [K,I,J]    5    2   60
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7024E-06  [K,I,J]    7    2   60
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2080E-06  [K,I,J]    6    2   60
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1023E-06  [K,I,J]    4    1   35
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.6475E-07  [K,I,J]    6    2   60
#  Transport Step:   12   Step Size:  2.0924E-02 Total Elapsed Time:   101.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1123E-03  [K,I,J]   14    3   50
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3546E-05  [K,I,J]    6    2   61
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4972E-06  [K,I,J]    5    2   57
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6489E-07  [K,I,J]    7    2   61
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/08/29 17:44:13
#  Elapsed run time: 35.433 Seconds
#
#  Normal termination of SEAWAT
#  Elapsed run time: 35.433 Seconds
#
#  Normal termination of SEAWAT

# %% [markdown]
# ## Post-processing results

# %%
#Post-processing functions
def plotdischarge(modelname,model_ws,color='w',per=-1,scale=50,rowslice=0):
    fname = os.path.join(model_ws, '' + modelname + '.cbc')
    budobj = flopy.utils.CellBudgetFile(fname)
    qx = budobj.get_data(text='FLOW RIGHT FACE')[per]
    qz = budobj.get_data(text='FLOW LOWER FACE')[per]
    
    # Average flows to cell centers
    qx_avg = np.empty(qx.shape, dtype=qx.dtype)
    qx_avg[:, :, 1:] = 0.5 * (qx[:, :, 0:ncol-1] + qx[:, :, 1:ncol])
    qx_avg[:, :, 0] = 0.5 * qx[:, :, 0]
    qz_avg = np.empty(qz.shape, dtype=qz.dtype)
    qz_avg[1:, :, :] = 0.5 * (qz[0:nlay-1, :, :] + qz[1:nlay, :, :])
    qz_avg[0, :, :] = 0.5 * qz[0, :, :]
    
    y, x, z = dis.get_node_coordinates()
    X, Z = np.meshgrid(x, z[:, 0, 0])
    iskip = 1 #how many cells to skip, 1 means plot every cell
    
    ax = plt.gca()
    cpatchcollection = ax.quiver(X[::iskip, ::iskip], Z[::iskip, ::iskip],
              qx_avg[::iskip, rowslice, ::iskip], -qz_avg[::iskip, rowslice, ::iskip],
              color=color, scale=scale, headwidth=4, headlength=2,
              headaxislength=1, width=0.0025)
    return cpatchcollection

def permute_kstpkper(ucnobj):
    kstpkper = ucnobj.get_kstpkper()
    kstpkper_unique = []
    index_unique = []
    niter = 0
    for entry in kstpkper:
        if not entry in kstpkper_unique:
            kstpkper_unique.append(entry)
            index_unique.append(niter)
        niter += 1
    return kstpkper_unique, index_unique

def kstpkper_from_time(ucnobj,tottim):
    kstpkpers = ucnobj.get_kstpkper()
    times = ucnobj.get_times()
    timeind = times.index(tottim)    
    kstpkper = kstpkpers[timeind]
    return kstpkper

def kstpkper_ind_from_kstpkper(ucnobj,kstpkper=(0,0)):
    kstpkpers = ucnobj.get_kstpkper()
    kstpkper_unique = permute_kstpkper(ucnobj)[0]
    kstpkper_ind = kstpkper_unique.index(kstpkper)
    return kstpkper_ind

def get_salt_outflow(m,kstpkper=None,totim=None):
    fname = os.path.join(m.model_ws, 'MT3D001.UCN')
    ucnobj = flopy.utils.binaryfile.UcnFile(fname)
    totim = ucnobj.get_times()[-1]
    if kstpkper==None:
        kstpkper = ucnobj.get_kstpkper()[-1]
    ocean_conc = ucnobj.get_data(kstpkper=kstpkper)
    return ocean_conc
    
def plot_background(mm,array,label=None):
    if label==None:
        label = [ k for k,v in globals().items() if v is array][-1]
    print('label: ',label)
    if label=='hk':
        norm=matplotlib.colors.LogNorm()
        vmin=hkClay
        vmax=hkSand
        cmap='jet'
    else:
        norm = None
        vmin=None
        vmax=None
        cmap='jet'
    cpatchcollection = mm.plot_array(array,cmap=cmap,norm=norm,vmin=vmin,vmax=vmax)
    cpatchcollection.set_label(label)
    return cpatchcollection,label

# %%
fname = os.path.join(model_ws, '' + modelname + '.cbc')
budobj = flopy.utils.CellBudgetFile(fname)
qx = budobj.get_data(text='FLOW RIGHT FACE')[0]
y, x, z = dis.get_node_coordinates()
X, Z = np.meshgrid(x, z[:, 0, 0])

# %%
X
# Out:
# array([[ 0.5,  1.5,  2.5, ..., 67.5, 68.5, 69.5],
#        [ 0.5,  1.5,  2.5, ..., 67.5, 68.5, 69.5],
#        [ 0.5,  1.5,  2.5, ..., 67.5, 68.5, 69.5],
#        ...,
#        [ 0.5,  1.5,  2.5, ..., 67.5, 68.5, 69.5],
#        [ 0.5,  1.5,  2.5, ..., 67.5, 68.5, 69.5],
#        [ 0.5,  1.5,  2.5, ..., 67.5, 68.5, 69.5]])

# %% [markdown]
# #Temporarily removed... the 'constant head' data doesn't seem right...
# def get_ocean_outflow(m,ocean_col):
#     fname = os.path.join(m.model_ws, m.name + '.cbc')
#     budobj = flopy.utils.CellBudgetFile(fname)
#     ch = budobj.get_data(text='CONSTANT HEAD')
#     ocean_col_vec = np.arange(ocean_col[0],ocean_col[1]+1)
#     ocean_nodes = np.ravel_multi_index([np.zeros(ocean_col_vec.size,dtype=int), #nodes in constant head flow file are 1-based
#                                       np.zeros(ocean_col_vec.size,dtype=int),   #create a list of node numbers for ocean cells
#                                       ocean_col_vec],
#                                      (m.dis.nlay,m.dis.nrow,m.dis.ncol)) + 1
#
#     ocean_flow =  [ch[-1]['q'][i] for i,node in enumerate(ch[-1]['node']) if node in ocean_nodes]
#     tot_flow = np.sum(ocean_flow)
#     return flow

# %%
# Extract heads
fname = os.path.join(model_ws, '' + modelname + '.hds')
hdobj = flopy.utils.binaryfile.HeadFile(fname)
times = hdobj.get_times()
hdobj.get_kstpkper()
hds = hdobj.get_data(totim=times[-1])
hds[np.where(ibound != 1)] = np.nan

# Extract salinity
fname = os.path.join(model_ws, 'MT3D001.UCN')
ucnobj = flopy.utils.binaryfile.UcnFile(fname)
times = ucnobj.get_times()
conc = ucnobj.get_data(totim=times[-1])
conc[np.where(ibound != 1)] = np.nan

# %%
# Make head and quiver plot
import utils
printyn = 0
rowslice = 0
f, axs = plt.subplots(2,1, sharex=True, figsize=(15, 8),
                     gridspec_kw = {'height_ratios':[1, 7]})
plt.tight_layout()

#Plot discharge and ibound
mm = flopy.plot.ModelCrossSection(ax=axs[1], model=m, line={'row':rowslice})
cpatchcollection,label = plot_background(mm,hk)
mm.plot_ibound()
plotdischarge(m.name,m.model_ws,color='white',per=-1,scale=1,rowslice=rowslice);
plt.xlabel('Distance (m)')
plt.ylabel('Height (m)')

#plot SGD
ocean_flow = 100 * np.asarray(utils.get_ocean_outflow_chd(m,ocean_bool))

plt.sca(axs[0]) #set current axes
plt.bar(np.arange(ocean_col[0],ocean_col[1]+1)+delc/2,
        ocean_flow[:,rowslice,:][ocean_bool[:,rowslice,:]])
axs[0].axhline()
axs[0].set_ylim(np.min(ocean_flow)*0.9,np.max(ocean_flow)*1.1)
plt.ylabel('SGD (cm/d)')
axs[0].annotate('total flow = ' + str(np.sum(ocean_flow)) + ' cm/d', xy=(.1,.5),
            xytext=(0.1, 0.5), xycoords='axes fraction', textcoords='axes fraction')

#Plot salt content of cells beneath outflow
ocean_below_ind = [np.where(ocean_bool)[0]+1,
                   np.where(ocean_bool)[1],
                   np.where(ocean_bool)[2]]
ind = np.where(ocean_below_ind[1] == rowslice)
ocean_below_ind_slice = (ocean_below_ind[0][ind],ocean_below_ind[1][ind],ocean_below_ind[2][ind])           
ocean_salt_outflow = get_salt_outflow(m,kstpkper = (nstp[-1]-1,nper-1))[ocean_below_ind_slice]
                   
                   
axs02 = axs[0].twinx()
plt.plot(ocean_col_vec[2]+delc/2 , ocean_salt_outflow,'r.')
#axs02.set_ylim(0,Csalt)

plt.ylabel('conc of underlying (g/L)')

#align plots and set colorbar
f.subplots_adjust(right=0.93)
cbar_ax = f.add_axes([0.95, 0.1, 0.02, 0.7])
cb = f.colorbar(cpatchcollection,cax=cbar_ax)
cb.set_label(label)
if printyn == 1:
    plt.savefig(os.path.join(m.model_ws, m.name + '_flow_vectors.png'),dpi=300)
plt.show()
# Out:
# label:  hk

# %%
# Load the mas file and make a plot of total mass in aquifer versus time
fname = os.path.join(model_ws, 'MT3D001.MAS')
mas = flopy.mt3d.Mt3dms.load_mas(fname)
f = plt.figure()
ax = f.add_subplot(1, 1, 1)
lines = ax.plot(mas.time, mas.total_mass)
mas[0]
plt.show()

# %% [markdown]
# # Reading in real data

# %%
import pandas
from pathlib import Path
ws = Path(m.model_ws)
basedir = ws.joinpath('..','..')
datadir = basedir.joinpath('data')
fname = datadir.joinpath('seepage_flow_2015.xlsx')
flowsheet = pandas.read_excel(fname,skiprows=1)
print('Columns: ',flowsheet.columns)
# Out:
# Columns:  Index(['Row', 'Column', 'X', 'Y', 'Z', 'MeterNo', 'Flow', 'EC_IN', 'pctFW',
#        'FlowFW', 'FlowSW'],
#       dtype='object')

# %%
plt.scatter(flowsheet.X,flowsheet.Y,s=np.exp(flowsheet.Row),c=flowsheet.Column)

# %% [markdown]
# #Issue: which "flow" is the correct flow?
#     #Can get flow from the cell-by-cell file in either FLOW RIGHT FACE and FLOW LOWER FACE
#     # Or from the constant head flow
#
# ocean_flow = get_ocean_outflow(m,ocean_col);
# print('total flow into ocean cells from const. head flow:',-np.sum(ocean_flow),'m^3/d')
#
# fname = os.path.join(model_ws, '' + modelname + '.cbc')
# budobj = flopy.utils.CellBudgetFile(fname)
# qx = budobj.get_data(text='FLOW RIGHT FACE')[-1]
# qz = budobj.get_data(text='FLOW LOWER FACE')[-1]
# tot_flow = np.sum( np.sqrt(np.square(-qz[ocean_coords]) + np.square(qx[ocean_coords])))
# print('Total flow from lower-right face in cbc file', tot_flow ,'m^3/d' )
