# %% [markdown]
# # Delaware Case Study
# ## Simple Model of SGD

# %%
# %matplotlib inline
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors
import warnings
from pathlib import Path
import flopy
import SGD
print(sys.version)
print('numpy version: {}'.format(np.__version__))
print('flopy version: {}'.format(flopy.__version__))

########
modelname = 'test'
########

basedir = Path(os.path.abspath('.'))
if not basedir.stem == 'DelawareSGD':
    warnings.warn('\nThis is not the expected directory. \nPlease run file from directory ".../DelawareSGD"')

model_ws = basedir.joinpath('work',modelname)
model_ws_str = model_ws.as_posix()
if not model_ws.exists():
    model_ws.mkdir()
sys.path.append(basedir.as_posix())
import config
sw_exe = config.swexe
print('Base directory:',basedir.as_posix())
print('Model workspace:',model_ws_str)
# Out:
# 3.5.5 |Anaconda 4.2.0 (64-bit)| (default, Apr  7 2018, 04:52:34) [MSC v.1900 64 bit (AMD64)]
# numpy version: 1.15.0
# flopy version: 3.2.9
# Base directory: E:/Projects/DelawareSGD
# Model workspace: E:/Projects/DelawareSGD/work/test

# %%
#Other functions and imports

#nearest value in array
def find_nearest(array,value):
    import numpy as np
    idx = (np.abs(array-value)).argmin()
    idx.astype('int')
    return array[idx]

#take distance in meters, return column in model
def loc_to_col(locs):
    cols = [int(find_nearest((np.arange(ncol)*delc),loc)) for loc in locs]
    return cols

# %%
#Model grid
#Grid: 0.5 *1*1m • Size:70m*20m
        
Lx = 70.
Lz = 20.
nlay = 40
nrow = 3
ncol = 70
delr = Lx / ncol
delc = 1.0
delv = Lz / nlay
henry_top = Lz
henry_botm = np.linspace(henry_top - delv, 0., nlay)

#Period data
perlen = [1,100]
nstp = [100,100]
nper = len(perlen)
steady = [True,False]
itmuni = 4 #time unit 4= days
lenuni = 2 #length unit 2 = meter
tsmult = 1
ssm_data = None
verbose = True

# %%
#Create basic model instance and dis pacakge
m = flopy.seawat.Seawat(modelname, exe_name=sw_exe, model_ws=model_ws,verbose=verbose)
SGD.ModelSGD.Seawat2SGD(m)
print(m.namefile)

# Add DIS package to the MODFLOW model
dis = flopy.modflow.ModflowDis(m, nlay, nrow, ncol, nper=nper, delr=delr,
                               delc=delc, laycbd=0, top=henry_top,
                               botm=henry_botm, perlen=perlen, nstp=nstp,
                               steady=steady,itmuni=itmuni,lenuni=lenuni,
                               tsmult=tsmult)
# Out:
# test.nam
# adding Package:  DIS

# %%
#Hydraulic conductivity field 

hkSand = 80.  #horizontal hydraulic conductivity m/day
hkClay = 1. 
lithmat = hkSand*np.ones((nlay,nrow,ncol), dtype=np.int32) #sandy background
addclay_yn = 1


def rand_clay_blocks(lithmat,hkClay,numblocks,sizeblocks):
    nlay,nrow,ncol = lithmat.shape
    lay_block = np.random.randint(1,nlay-sizeblocks[0],numblocks)
    row_block = np.random.randint(0,nrow-sizeblocks[1]+1,numblocks)
    col_block = np.random.randint(1,ncol-sizeblocks[2],numblocks)
    lithmat_blocks = lithmat.copy()
    for i in range(numblocks):
        block_coords = [slice(lay_block[i],lay_block[i]+sizeblocks[0]),
                        slice(row_block[i],row_block[i]+sizeblocks[1]),
                        slice(col_block[i],col_block[i]+sizeblocks[2])]
        lithmat_blocks[block_coords] = hkClay
    return lithmat_blocks

#add low conductivity regions
if addclay_yn == 1:
    lithmat = rand_clay_blocks(lithmat,hkClay,100,(2,1,5))
low_k_loc = (20,30)
low_k_col = loc_to_col(low_k_loc)
#lithmat[1:3,0,0:65] = hkClay
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:19: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
#Set Hydraulic properties

hk = lithmat
sy = 0.15
ss = 0.00005
por = 0.2
vka = 1/10 # = vk/hk
al = 3 #longitudinal dispersivity, in m
#dmcoef = 0.57024 #m2/day  Could also try 1.62925 as another case of the Henry problem
dmcoef = 0. #test for numerical dispersion

#Variable density parameters
Csalt = 35.0001
Cfresh = 0.
densesalt = 1025.
densefresh = 1000.
denseslp = (densesalt - densefresh) / (Csalt - Cfresh)

# %%
#BCs
calc_inland_head = 1 #don't calculate from hgrad
manual_inland_head = Lz + .1
ocean_shead = [Lz,Lz-.5]
ocean_ehead = ocean_shead
start_fresh_yn = 1

# save cell fluxes to unit 53
ipakcb = 53

#MODFLOW BCs
hgrad = 0.0033 #hydraulic gradient, m/m
qinflow = 0  #influent FW m3/day

#Create ocean boundary at top of model
ocean_loc = [30,70] # location of ocean [start,end] in m
ocean_col = [int(find_nearest((np.arange(ncol)*delc),loc)) for loc in ocean_loc]
ocean_col_vec = (0,0,np.arange(ocean_col[0],ocean_col[1]+1))
ocean_coords = (0,slice(0,nrow),slice(ocean_col[0],ocean_col[1]+1)) #top of the model
ocean_bool = np.zeros((nlay,nrow,ncol), dtype=bool)
ocean_bool[0,:,np.arange(ocean_col[0],ocean_col[1]+1)] = 1
m.ocean_arr = ocean_bool
if calc_inland_head ==1:
    head_inland = ocean_loc[0]*hgrad + Lz
else:
    head_inland = manual_inland_head


#Set ibound
ibound = np.ones((nlay, nrow, ncol), dtype=np.int32)
ibound[:, :, 0] = -1 #first column (FW boundary) has fixed head
ibound[ocean_bool] = -1
ibound[0:2,:,ocean_col[0]-3:ocean_col[0]] = 0

#Set starting heads
strt = head_inland*np.ones((nlay, nrow, ncol)) #starting heads (for fixed head BC, this is will assign the head)
strt[ocean_bool] = ocean_shead[0] #head of ocean boundary

#Transport BCs
if start_fresh_yn == 1:
    sconc = Cfresh*np.ones((nlay, nrow, ncol), dtype=np.float32) #Begin fresh
elif start_fresh_yn == 0:
    sconc = Csalt*np.ones((nlay, nrow, ncol), dtype=np.float32) #Begin SW-saturated

sconc[ocean_bool] = Csalt
sconc[:,:,0] = Cfresh

icbund = np.ones((nlay, nrow, ncol), dtype=np.int) 
icbund[(ibound < 0)] = -1 #constant concentration cells where also constant head

#Constant head boundary
stress_period_data = {}
ocean_sub = np.where(ocean_bool)
for i in range(nper):
    dat = []
    for j in range(np.sum(ocean_bool)):
        dat.append([ocean_sub[0][j],ocean_sub[1][j],ocean_sub[2][j],ocean_shead[i],ocean_ehead[i]])
    stress_period_data[i] = dat

# %%
#Create instances in flopy
bas = flopy.modflow.ModflowBas(m, ibound, strt=strt)

# Add LPF package to the MODFLOW model
lpf = flopy.modflow.ModflowLpf(m, hk=hk, vka=vka, ipakcb=ipakcb, ss=ss, sy=sy)

# Add PCG Package to the MODFLOW model
pcg = flopy.modflow.ModflowPcg(m, hclose=1.e-8)

# Add OC package to the MODFLOW model
oc = flopy.modflow.ModflowOc(m,
                             stress_period_data={(0, 0): ['save head', 'save budget']},
                             compact=True)
#wel = flopy.modflow.ModflowWel(m, stress_period_data=wel_data, ipakcb=ipakcb)

#Create the basic MT3DMS model structure
btn = flopy.mt3d.Mt3dBtn(m, 
                         #nlay=nlay, nrow=nrow, ncol=ncol, nper=nper, 
                         laycon=lpf.laytyp, htop=henry_top, 
                         dz=dis.thickness.get_value(), prsity=0.2, icbund=icbund,
                         sconc=sconc, nprs=-10)
adv = flopy.mt3d.Mt3dAdv(m, mixelm=0)
dsp = flopy.mt3d.Mt3dDsp(m, al=al, trpt=1., trpv=1., dmcoef=dmcoef)
gcg = flopy.mt3d.Mt3dGcg(m, iter1=500, mxiter=1, isolve=1, cclose=1e-7)
ssm = flopy.mt3d.Mt3dSsm(m, stress_period_data=ssm_data)
chd = flopy.modflow.ModflowChd(m, stress_period_data=stress_period_data)
#vdf = flopy.seawat.SeawatVdf(m, iwtable=0, densemin=0, densemax=0,denseref=1000., denseslp=0.7143, firstdt=1e-3)
vdf = flopy.seawat.SeawatVdf(m, mtdnconc=1, mfnadvfd=1, nswtcpl=0, iwtable=0, 
                             densemin=0., densemax=0., denseslp=denseslp, denseref=densefresh)
# Out:
# adding Package:  BAS6
# Adding test.cbc (unit=53) to the output list.
# adding Package:  LPF
# adding Package:  PCG
# Adding test.hds (unit=51) to the output list.
# adding Package:  OC
# adding Package:  BTN
# adding Package:  ADV
# adding Package:  DSP
# adding Package:  GCG
# adding Package:  SSM
# adding Package:  CHD
# adding Package:  VDF

# %%
#Write input
m.write_input()

# Try to delete the output files, to prevent accidental use of older files
try:
    os.remove(os.path.join(model_ws,'MT3D.CNF'))
    os.remove(os.path.join(model_ws,'MT3D001.MAS'))
    os.remove(os.path.join(model_ws, 'MT3D001.UCN'))
    os.remove(os.path.join(model_ws, modelname + '.hds'))
    os.remove(os.path.join(model_ws, modelname + '.cbc'))
except:
    pass
# Out:
# Writing packages:
#    Package:  DIS
#    Package:  BAS6
#    Package:  LPF
#    Package:  PCG
#    Package:  OC
#    Package:  BTN
#    Package:  ADV
#    Package:  DSP
#    Package:  GCG
#    Package:  SSM
#    Package:  CHD
#    Package:  VDF

# %%
#Run model
v = m.run_model(silent=False, report=True)
for idx in range(-3, 0):
    print(v[1][idx])
# Out:
# FloPy is using the following executable to run the model: E:\Projects\DelawareSGD\bin\win64\swt_v4.exe
#
#                                   SEAWAT Version 4
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 4.00.05 10/19/2012
#
# Incorporated MODFLOW Version: 1.18.01 06/20/2008
# Incorporated MT3DMS  Version: 5.20    10/30/2006
#
#
#  This program is public domain and is released on the
#  condition that neither the U.S. Geological Survey nor
#  the United States Government may be held liable for any
#  damages resulting from their authorized or unauthorized
#  use.
#
#
#  Using NAME file: test.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/08/30 10:37:31
#
#
#  STRESS PERIOD NO.    1
#
#   STRESS PERIOD    1 TIME STEP    1 FROM TIME =   0.0000     TO   0.10000E-01
#
#  Transport Step:    1   Step Size:  1.0000E-03 Total Elapsed Time:  1.00000E-03
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7369E-03  [K,I,J]    2    2   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1941E-05  [K,I,J]    3    2   43
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9850E-08  [K,I,J]    4    2   33
#  Transport Step:    2   Step Size:  9.0000E-03 Total Elapsed Time:  1.00000E-02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6850E-02  [K,I,J]    2    2   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1659E-03  [K,I,J]    3    2   43
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6666E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4339E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2486E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP    2 FROM TIME =  0.10000E-01 TO   0.20000E-01
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  2.00000E-02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6564E-02  [K,I,J]    2    2   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1726E-03  [K,I,J]    3    2   43
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8985E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5996E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3631E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP    3 FROM TIME =  0.20000E-01 TO   0.30000E-01
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  3.00000E-02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6196E-02  [K,I,J]    2    2   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1649E-03  [K,I,J]    3    2   43
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8728E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5826E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3453E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP    4 FROM TIME =  0.30000E-01 TO   0.40000E-01
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  4.00000E-02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6231E-02  [K,I,J]    2    2   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1706E-03  [K,I,J]    3    2   43
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8653E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5757E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3374E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP    5 FROM TIME =  0.40000E-01 TO   0.50000E-01
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  5.00000E-02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6119E-02  [K,I,J]    2    2   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1712E-03  [K,I,J]    3    2   43
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8626E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5645E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3264E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP    6 FROM TIME =  0.50000E-01 TO   0.60000E-01
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  6.00000E-02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5915E-02  [K,I,J]    2    2   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1683E-03  [K,I,J]    3    2   43
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8544E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5525E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3152E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP    7 FROM TIME =  0.60000E-01 TO   0.70000E-01
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  7.00000E-02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5754E-02  [K,I,J]    2    2   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1666E-03  [K,I,J]    3    2   43
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8444E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5429E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.3062E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP    8 FROM TIME =  0.70000E-01 TO   0.80000E-01
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  8.00000E-02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5622E-02  [K,I,J]    2    2   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1655E-03  [K,I,J]    3    2   43
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8352E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5346E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2985E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP    9 FROM TIME =  0.80000E-01 TO   0.90000E-01
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  9.00000E-02
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5485E-02  [K,I,J]    2    2   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1641E-03  [K,I,J]    3    2   43
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8261E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5266E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2914E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   10 FROM TIME =  0.90000E-01 TO   0.10000E+00
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  1.00000E-01
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5347E-02  [K,I,J]    2    2   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1624E-03  [K,I,J]    3    2   43
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8167E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5191E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2849E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   11 FROM TIME =  0.10000E+00 TO   0.11000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.11000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5216E-02  [K,I,J]    2    2   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1608E-03  [K,I,J]    3    2   43
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8073E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5122E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2791E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   12 FROM TIME =  0.11000     TO   0.12000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.12000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5091E-02  [K,I,J]    2    2   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1592E-03  [K,I,J]    3    2   43
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7980E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5057E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2738E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   13 FROM TIME =  0.12000     TO   0.13000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.13000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4969E-02  [K,I,J]    2    2   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1575E-03  [K,I,J]    3    2   43
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7889E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4994E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2689E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   14 FROM TIME =  0.13000     TO   0.14000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.14000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4851E-02  [K,I,J]    2    2   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1558E-03  [K,I,J]    3    2   43
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7800E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4934E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2642E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   15 FROM TIME =  0.14000     TO   0.15000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.15000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4737E-02  [K,I,J]    2    2   43
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1541E-03  [K,I,J]    3    2   43
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7712E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4875E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2599E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   16 FROM TIME =  0.15000     TO   0.16000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.16000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4632E-02  [K,I,J]    2    1   44
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1524E-03  [K,I,J]    3    2   43
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7626E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4818E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2557E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   17 FROM TIME =  0.16000     TO   0.17000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.17000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4543E-02  [K,I,J]    2    1   44
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1507E-03  [K,I,J]    3    2   43
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7541E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4762E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2517E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   18 FROM TIME =  0.17000     TO   0.18000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.18000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4457E-02  [K,I,J]    2    1   44
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1490E-03  [K,I,J]    3    2   43
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7458E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4707E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2478E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   19 FROM TIME =  0.18000     TO   0.19000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.19000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4372E-02  [K,I,J]    2    1   44
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1480E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7377E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4652E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2441E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   20 FROM TIME =  0.19000     TO   0.20000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.20000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4290E-02  [K,I,J]    2    1   45
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1471E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7297E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4598E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2405E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   21 FROM TIME =  0.20000     TO   0.21000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.21000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4215E-02  [K,I,J]    2    1   45
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1462E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7219E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4545E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2369E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   22 FROM TIME =  0.21000     TO   0.22000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.22000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4142E-02  [K,I,J]    2    1   45
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1452E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7142E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4492E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2335E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   23 FROM TIME =  0.22000     TO   0.23000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.23000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4070E-02  [K,I,J]    2    1   45
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1443E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7067E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4440E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2301E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   24 FROM TIME =  0.23000     TO   0.24000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.24000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4000E-02  [K,I,J]    2    1   45
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1433E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6993E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4389E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2267E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   25 FROM TIME =  0.24000     TO   0.25000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.25000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3931E-02  [K,I,J]    2    1   45
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1423E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6921E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4338E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2235E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   26 FROM TIME =  0.25000     TO   0.26000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.26000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3863E-02  [K,I,J]    2    1   45
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1413E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6850E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4287E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2203E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   27 FROM TIME =  0.26000     TO   0.27000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.27000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3798E-02  [K,I,J]    2    1   46
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1403E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6780E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4237E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2172E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   28 FROM TIME =  0.27000     TO   0.28000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.28000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3738E-02  [K,I,J]    2    1   46
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1393E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6712E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4188E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2141E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   29 FROM TIME =  0.28000     TO   0.29000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.29000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3678E-02  [K,I,J]    2    1   46
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1382E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6645E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4139E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2111E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   30 FROM TIME =  0.29000     TO   0.30000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.30000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3620E-02  [K,I,J]    2    1   46
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1372E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6579E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4091E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2081E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   31 FROM TIME =  0.30000     TO   0.31000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.31000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3563E-02  [K,I,J]    2    1   46
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1362E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6515E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4043E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2053E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   32 FROM TIME =  0.31000     TO   0.32000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.32000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3507E-02  [K,I,J]    2    1   46
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1351E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6451E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3996E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2024E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   33 FROM TIME =  0.32000     TO   0.33000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.33000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3452E-02  [K,I,J]    2    1   46
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1341E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6389E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3956E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1996E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   34 FROM TIME =  0.33000     TO   0.34000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.34000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3399E-02  [K,I,J]    2    1   46
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1331E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6328E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3920E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1969E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   35 FROM TIME =  0.34000     TO   0.35000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.35000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3346E-02  [K,I,J]    2    1   46
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1321E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6269E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3885E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1943E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   36 FROM TIME =  0.35000     TO   0.36000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.36000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3294E-02  [K,I,J]    2    1   46
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1311E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6210E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3850E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1916E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   37 FROM TIME =  0.36000     TO   0.37000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.37000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3244E-02  [K,I,J]    2    1   47
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1301E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6153E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3816E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1891E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   38 FROM TIME =  0.37000     TO   0.38000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.38000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3197E-02  [K,I,J]    2    1   47
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1291E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6096E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3782E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1866E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   39 FROM TIME =  0.38000     TO   0.39000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.39000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3152E-02  [K,I,J]    2    1   47
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1281E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6041E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3748E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1841E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   40 FROM TIME =  0.39000     TO   0.40000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.40000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3107E-02  [K,I,J]    2    1   47
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1271E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5987E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3715E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1817E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   41 FROM TIME =  0.40000     TO   0.41000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.41000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3062E-02  [K,I,J]    2    1   47
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1261E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5934E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3683E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1794E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   42 FROM TIME =  0.41000     TO   0.42000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.42000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3019E-02  [K,I,J]    2    1   47
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1252E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5882E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3651E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1771E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   43 FROM TIME =  0.42000     TO   0.43000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.43000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2992E-02  [K,I,J]    2    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1242E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5831E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3620E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1749E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   44 FROM TIME =  0.43000     TO   0.44000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.44000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2972E-02  [K,I,J]    2    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1233E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5781E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3589E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1727E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   45 FROM TIME =  0.44000     TO   0.45000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.45000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2953E-02  [K,I,J]    2    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1224E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5732E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3558E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1705E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   46 FROM TIME =  0.45000     TO   0.46000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.46000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2934E-02  [K,I,J]    2    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1215E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5684E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3529E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1684E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   47 FROM TIME =  0.46000     TO   0.47000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.47000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2914E-02  [K,I,J]    2    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1206E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5636E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3499E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1664E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   48 FROM TIME =  0.47000     TO   0.48000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.48000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2895E-02  [K,I,J]    2    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1197E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5590E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3471E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1644E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   49 FROM TIME =  0.48000     TO   0.49000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.49000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2876E-02  [K,I,J]    2    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1188E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5545E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3442E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1624E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   50 FROM TIME =  0.49000     TO   0.50000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.50000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2857E-02  [K,I,J]    2    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1180E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5500E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3415E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1605E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   51 FROM TIME =  0.50000     TO   0.51000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.51000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2837E-02  [K,I,J]    2    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1171E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5456E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3387E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1586E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   52 FROM TIME =  0.51000     TO   0.52000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.52000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2819E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1163E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5414E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3361E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1568E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   53 FROM TIME =  0.52000     TO   0.53000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.53000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2800E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1154E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5372E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3334E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1550E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   54 FROM TIME =  0.53000     TO   0.54000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.54000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2782E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1146E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5330E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3308E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1533E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   55 FROM TIME =  0.54000     TO   0.55000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.55000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2764E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1138E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5290E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3283E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1515E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   56 FROM TIME =  0.55000     TO   0.56000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.56000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2746E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1130E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5250E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3258E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1499E-07  [K,I,J]    4    3   31
#
#   STRESS PERIOD    1 TIME STEP   57 FROM TIME =  0.56000     TO   0.57000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.57000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2728E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1122E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5211E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3234E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1486E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   58 FROM TIME =  0.57000     TO   0.58000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.58000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2710E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1115E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5172E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3210E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1475E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   59 FROM TIME =  0.58000     TO   0.59000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.59000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2692E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1107E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5135E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3186E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1464E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   60 FROM TIME =  0.59000     TO   0.60000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.60000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2674E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1100E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5098E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3163E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1454E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   61 FROM TIME =  0.60000     TO   0.61000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.61000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2656E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1092E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5061E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3140E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1443E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   62 FROM TIME =  0.61000     TO   0.62000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.62000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2638E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1085E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5026E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3118E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1433E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   63 FROM TIME =  0.62000     TO   0.63000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.63000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2620E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1078E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4990E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3095E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1423E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   64 FROM TIME =  0.63000     TO   0.64000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.64000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2602E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1071E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4956E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3074E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1413E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   65 FROM TIME =  0.64000     TO   0.65000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.65000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2585E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1064E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4922E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3053E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1403E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   66 FROM TIME =  0.65000     TO   0.66000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.66000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2567E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1057E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4889E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3032E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1393E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   67 FROM TIME =  0.66000     TO   0.67000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.67000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2549E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1050E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4856E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3011E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1383E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   68 FROM TIME =  0.67000     TO   0.68000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.68000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2532E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1043E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4823E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2991E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1374E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   69 FROM TIME =  0.68000     TO   0.69000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.69000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2514E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1037E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4792E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2971E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1365E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   70 FROM TIME =  0.69000     TO   0.70000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.70000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2497E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1030E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4760E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2951E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1356E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   71 FROM TIME =  0.70000     TO   0.71000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.71000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2480E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1024E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4730E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2932E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1347E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   72 FROM TIME =  0.71000     TO   0.72000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.72000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2462E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1018E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4699E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2913E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1338E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   73 FROM TIME =  0.72000     TO   0.73000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.73000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2445E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1011E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4670E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2894E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1329E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   74 FROM TIME =  0.73000     TO   0.74000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.74000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2428E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1005E-03  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4640E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2876E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1321E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   75 FROM TIME =  0.74000     TO   0.75000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.75000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2411E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9992E-04  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4611E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2858E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1313E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   76 FROM TIME =  0.75000     TO   0.76000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.76000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2395E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9932E-04  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4583E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2840E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1304E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   77 FROM TIME =  0.76000     TO   0.77000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.77000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2378E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9874E-04  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4555E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2823E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1296E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   78 FROM TIME =  0.77000     TO   0.78000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.78000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2361E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9816E-04  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4527E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2805E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1288E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   79 FROM TIME =  0.78000     TO   0.79000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.79000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2345E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9759E-04  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4500E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2788E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1280E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   80 FROM TIME =  0.79000     TO   0.80000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.80000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2328E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9702E-04  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4473E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2772E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1272E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   81 FROM TIME =  0.80000     TO   0.81000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.81000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2312E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9647E-04  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4447E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2755E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1265E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   82 FROM TIME =  0.81000     TO   0.82000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.82000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2295E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9592E-04  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4421E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2739E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1257E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   83 FROM TIME =  0.82000     TO   0.83000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.83000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2279E-02  [K,I,J]    2    3   56
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9538E-04  [K,I,J]    3    2   34
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4395E-05  [K,I,J]    4    2   33
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2723E-06  [K,I,J]    3    2   31
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1250E-07  [K,I,J]    4    2   31
#
#   STRESS PERIOD    1 TIME STEP   84 FROM TIME =  0.83000     TO   0.84000
#
#  Transport Step:    1   Step Size:  1.0000E-02 Total Elapsed Time:  0.84000
# ...
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2624E-05  [K,I,J]    6    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9142E-06  [K,I,J]    5    1   55
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3057E-06  [K,I,J]    5    1   61
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1740E-06  [K,I,J]    3    3   29
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1117E-06  [K,I,J]    4    3   29
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.7491E-07  [K,I,J]    3    3   29
#  Transport Step:    9   Step Size:  2.0803E-02 Total Elapsed Time:   99.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1347E-03  [K,I,J]   13    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3001E-05  [K,I,J]    5    2   65
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4922E-06  [K,I,J]    6    1   56
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6296E-07  [K,I,J]    6    1   54
#
#   STRESS PERIOD    2 TIME STEP   99 FROM TIME =   99.000     TO   100.000
#
#  Transport Step:    1   Step Size:  0.1224     Total Elapsed Time:   99.122
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8186E-03  [K,I,J]   13    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5255E-04  [K,I,J]    9    2   65
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1753E-04  [K,I,J]    6    2   64
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6004E-05  [K,I,J]    6    1   57
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2610E-05  [K,I,J]    6    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9177E-06  [K,I,J]    5    1   55
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3198E-06  [K,I,J]    5    1   60
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1509E-06  [K,I,J]    5    1   59
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1100E-06  [K,I,J]    4    3   29
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.8260E-07  [K,I,J]    3    3   29
#  Transport Step:    2   Step Size:  0.1224     Total Elapsed Time:   99.245
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8175E-03  [K,I,J]   13    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5243E-04  [K,I,J]    9    2   65
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1749E-04  [K,I,J]    6    2   64
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5988E-05  [K,I,J]    6    1   57
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2606E-05  [K,I,J]    6    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9035E-06  [K,I,J]    5    1   55
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2908E-06  [K,I,J]    5    1   61
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1740E-06  [K,I,J]    3    3   29
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1052E-06  [K,I,J]    4    3   29
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.7144E-07  [K,I,J]    3    3   29
#  Transport Step:    3   Step Size:  0.1224     Total Elapsed Time:   99.367
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8165E-03  [K,I,J]   13    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5230E-04  [K,I,J]    9    2   65
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1745E-04  [K,I,J]    6    2   64
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5968E-05  [K,I,J]    6    1   57
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2598E-05  [K,I,J]    6    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9090E-06  [K,I,J]    5    1   55
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3171E-06  [K,I,J]    5    1   61
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1465E-06  [K,I,J]    5    1   59
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1049E-06  [K,I,J]    4    3   29
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.7940E-07  [K,I,J]    3    3   29
#  Transport Step:    4   Step Size:  0.1224     Total Elapsed Time:   99.490
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8155E-03  [K,I,J]   13    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5217E-04  [K,I,J]    9    2   65
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1741E-04  [K,I,J]    6    2   64
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5948E-05  [K,I,J]    6    1   57
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2588E-05  [K,I,J]    6    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9013E-06  [K,I,J]    5    1   55
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2965E-06  [K,I,J]    5    1   61
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1691E-06  [K,I,J]    3    3   29
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1060E-06  [K,I,J]    4    3   29
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.7178E-07  [K,I,J]    3    3   29
#  Transport Step:    5   Step Size:  0.1224     Total Elapsed Time:   99.612
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8144E-03  [K,I,J]   13    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5204E-04  [K,I,J]    9    2   65
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1737E-04  [K,I,J]    6    2   64
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5928E-05  [K,I,J]    6    1   57
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2581E-05  [K,I,J]    6    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9015E-06  [K,I,J]    5    1   55
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3090E-06  [K,I,J]    5    1   61
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1447E-06  [K,I,J]    5    2   60
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1038E-06  [K,I,J]    4    3   29
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.7766E-07  [K,I,J]    3    3   29
#  Transport Step:    6   Step Size:  0.1224     Total Elapsed Time:   99.734
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8133E-03  [K,I,J]   13    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5192E-04  [K,I,J]    9    2   65
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1733E-04  [K,I,J]    6    2   64
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5908E-05  [K,I,J]    6    1   57
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2571E-05  [K,I,J]    6    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.8972E-06  [K,I,J]    5    1   55
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2984E-06  [K,I,J]    5    1   61
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1660E-06  [K,I,J]    3    3   29
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1061E-06  [K,I,J]    4    3   29
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.7146E-07  [K,I,J]    3    3   29
#  Transport Step:    7   Step Size:  0.1224     Total Elapsed Time:   99.857
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8122E-03  [K,I,J]   13    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5179E-04  [K,I,J]    9    2   65
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1729E-04  [K,I,J]    6    2   64
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5888E-05  [K,I,J]    6    1   57
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2564E-05  [K,I,J]    6    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.8949E-06  [K,I,J]    5    1   55
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3017E-06  [K,I,J]    5    1   61
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1452E-06  [K,I,J]    3    3   31
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1018E-06  [K,I,J]    4    3   29
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.7622E-07  [K,I,J]    3    3   29
#  Transport Step:    8   Step Size:  0.1224     Total Elapsed Time:   99.979
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8111E-03  [K,I,J]   13    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5166E-04  [K,I,J]    9    2   65
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1725E-04  [K,I,J]    6    2   64
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5868E-05  [K,I,J]    6    1   57
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2555E-05  [K,I,J]    6    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.8920E-06  [K,I,J]    5    1   55
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2974E-06  [K,I,J]    5    1   61
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1639E-06  [K,I,J]    3    3   29
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1052E-06  [K,I,J]    4    3   29
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.7063E-07  [K,I,J]    3    3   29
#  Transport Step:    9   Step Size:  2.0811E-02 Total Elapsed Time:  100.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1333E-03  [K,I,J]   13    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2941E-05  [K,I,J]    5    2   65
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4790E-06  [K,I,J]    6    1   56
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6169E-07  [K,I,J]    6    1   54
#
#   STRESS PERIOD    2 TIME STEP  100 FROM TIME =  100.000     TO    101.00
#
#  Transport Step:    1   Step Size:  0.1224     Total Elapsed Time:   100.12
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8098E-03  [K,I,J]   13    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5151E-04  [K,I,J]    9    2   65
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1721E-04  [K,I,J]    6    2   64
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5842E-05  [K,I,J]    6    1   57
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2541E-05  [K,I,J]    6    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.8953E-06  [K,I,J]    5    1   55
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3088E-06  [K,I,J]    5    1   60
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1449E-06  [K,I,J]    5    1   59
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1040E-06  [K,I,J]    4    3   29
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.7749E-07  [K,I,J]    3    3   29
#  Transport Step:    2   Step Size:  0.1224     Total Elapsed Time:   100.24
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8085E-03  [K,I,J]   13    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5139E-04  [K,I,J]    9    2   65
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1717E-04  [K,I,J]    6    2   64
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5826E-05  [K,I,J]    6    1   57
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2538E-05  [K,I,J]    6    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.8819E-06  [K,I,J]    5    1   55
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2830E-06  [K,I,J]    5    1   61
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1648E-06  [K,I,J]    3    3   29
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.9904E-07  [K,I,J]    4    3   29
#  Transport Step:    3   Step Size:  0.1224     Total Elapsed Time:   100.37
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8073E-03  [K,I,J]   13    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5127E-04  [K,I,J]    9    2   65
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1712E-04  [K,I,J]    6    2   64
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5788E-05  [K,I,J]    6    1   57
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2510E-05  [K,I,J]    6    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.8820E-06  [K,I,J]    5    1   55
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2576E-06  [K,I,J]    5    2   62
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1694E-06  [K,I,J]    3    3   30
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1092E-06  [K,I,J]    5    2   57
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.6732E-07  [K,I,J]    3    3   28
#  Transport Step:    4   Step Size:  0.1224     Total Elapsed Time:   100.49
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8061E-03  [K,I,J]   13    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5114E-04  [K,I,J]    9    2   65
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1709E-04  [K,I,J]    6    2   64
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5789E-05  [K,I,J]    6    1   57
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2532E-05  [K,I,J]    6    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.8796E-06  [K,I,J]    5    1   55
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3121E-06  [K,I,J]    5    1   61
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1450E-06  [K,I,J]    5    1   59
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1038E-06  [K,I,J]    3    3   29
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.7188E-07  [K,I,J]    3    3   28
#  Transport Step:    5   Step Size:  0.1224     Total Elapsed Time:   100.61
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8049E-03  [K,I,J]   13    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5102E-04  [K,I,J]    9    2   65
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1705E-04  [K,I,J]    6    2   64
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5764E-05  [K,I,J]    6    1   57
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2508E-05  [K,I,J]    6    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.8827E-06  [K,I,J]    5    1   55
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2930E-06  [K,I,J]    5    1   61
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1572E-06  [K,I,J]    3    3   30
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1005E-06  [K,I,J]    3    3   29
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.6924E-07  [K,I,J]    3    3   28
#  Transport Step:    6   Step Size:  0.1224     Total Elapsed Time:   100.73
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8036E-03  [K,I,J]   13    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5089E-04  [K,I,J]    9    2   65
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1701E-04  [K,I,J]    6    2   64
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5749E-05  [K,I,J]    6    1   57
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2507E-05  [K,I,J]    6    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.8744E-06  [K,I,J]    5    1   55
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2993E-06  [K,I,J]    5    1   61
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1495E-06  [K,I,J]    3    3   30
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1009E-06  [K,I,J]    3    3   29
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.6940E-07  [K,I,J]    3    3   28
#  Transport Step:    7   Step Size:  0.1224     Total Elapsed Time:   100.86
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8023E-03  [K,I,J]   13    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5077E-04  [K,I,J]    9    2   65
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1697E-04  [K,I,J]    6    2   64
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5728E-05  [K,I,J]    6    1   57
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2495E-05  [K,I,J]    6    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.8773E-06  [K,I,J]    5    1   55
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2999E-06  [K,I,J]    5    1   61
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1487E-06  [K,I,J]    3    3   30
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1015E-06  [K,I,J]    3    3   29
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.6949E-07  [K,I,J]    3    3   28
#  Transport Step:    8   Step Size:  0.1224     Total Elapsed Time:   100.98
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.8010E-03  [K,I,J]   13    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.5065E-04  [K,I,J]    9    2   65
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1693E-04  [K,I,J]    6    2   64
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5710E-05  [K,I,J]    6    1   57
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2488E-05  [K,I,J]    6    1   56
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.8692E-06  [K,I,J]    5    1   55
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2899E-06  [K,I,J]    5    1   61
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1527E-06  [K,I,J]    3    3   30
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.9738E-07  [K,I,J]    3    3   29
#  Transport Step:    9   Step Size:  2.0820E-02 Total Elapsed Time:   101.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1317E-03  [K,I,J]   13    3   55
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2882E-05  [K,I,J]    5    2   65
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4660E-06  [K,I,J]    6    1   56
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5966E-07  [K,I,J]    6    1   54
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/08/30 10:37:58
#  Elapsed run time: 27.550 Seconds
#
#  Normal termination of SEAWAT
#  Elapsed run time: 27.550 Seconds
#
#  Normal termination of SEAWAT

# %% [markdown]
# ## Post-processing results

# %%
#Post-processing functions
def plotdischarge(modelname,model_ws,color='w',per=-1,scale=50,rowslice=0):
    fname = os.path.join(model_ws, '' + modelname + '.cbc')
    budobj = flopy.utils.CellBudgetFile(fname)
    qx = budobj.get_data(text='FLOW RIGHT FACE')[per]
    qz = budobj.get_data(text='FLOW LOWER FACE')[per]
    
    # Average flows to cell centers
    qx_avg = np.empty(qx.shape, dtype=qx.dtype)
    qx_avg[:, :, 1:] = 0.5 * (qx[:, :, 0:ncol-1] + qx[:, :, 1:ncol])
    qx_avg[:, :, 0] = 0.5 * qx[:, :, 0]
    qz_avg = np.empty(qz.shape, dtype=qz.dtype)
    qz_avg[1:, :, :] = 0.5 * (qz[0:nlay-1, :, :] + qz[1:nlay, :, :])
    qz_avg[0, :, :] = 0.5 * qz[0, :, :]
    
    y, x, z = dis.get_node_coordinates()
    X, Z = np.meshgrid(x, z[:, 0, 0])
    iskip = 1 #how many cells to skip, 1 means plot every cell
    
    ax = plt.gca()
    cpatchcollection = ax.quiver(X[::iskip, ::iskip], Z[::iskip, ::iskip],
              qx_avg[::iskip, rowslice, ::iskip], -qz_avg[::iskip, rowslice, ::iskip],
              color=color, scale=scale, headwidth=4, headlength=2,
              headaxislength=1, width=0.0025)
    return cpatchcollection

def permute_kstpkper(ucnobj):
    kstpkper = ucnobj.get_kstpkper()
    kstpkper_unique = []
    index_unique = []
    niter = 0
    for entry in kstpkper:
        if not entry in kstpkper_unique:
            kstpkper_unique.append(entry)
            index_unique.append(niter)
        niter += 1
    return kstpkper_unique, index_unique

def kstpkper_from_time(ucnobj,tottim):
    kstpkpers = ucnobj.get_kstpkper()
    times = ucnobj.get_times()
    timeind = times.index(tottim)    
    kstpkper = kstpkpers[timeind]
    return kstpkper

def kstpkper_ind_from_kstpkper(ucnobj,kstpkper=(0,0)):
    kstpkpers = ucnobj.get_kstpkper()
    kstpkper_unique = permute_kstpkper(ucnobj)[0]
    kstpkper_ind = kstpkper_unique.index(kstpkper)
    return kstpkper_ind

def get_salt_outflow(m,kstpkper=None,totim=None):
    fname = os.path.join(m.model_ws, 'MT3D001.UCN')
    ucnobj = flopy.utils.binaryfile.UcnFile(fname)
    totim = ucnobj.get_times()[-1]
    if kstpkper==None:
        kstpkper = ucnobj.get_kstpkper()[-1]
    ocean_conc = ucnobj.get_data(kstpkper=kstpkper)
    return ocean_conc
    
def plot_background(mm,array,label=None):
    if label==None:
        label = [ k for k,v in globals().items() if v is array][-1]
    print('label: ',label)
    if label=='hk':
        norm=matplotlib.colors.LogNorm()
        vmin=hkClay
        vmax=hkSand
        cmap='jet'
    else:
        norm = None
        vmin=None
        vmax=None
        cmap='jet'
    cpatchcollection = mm.plot_array(array,cmap=cmap,norm=norm,vmin=vmin,vmax=vmax)
    cpatchcollection.set_label(label)
    return cpatchcollection,label

# %%
# Out:
# array([[ 0.5,  1.5,  2.5, ..., 67.5, 68.5, 69.5],
#        [ 0.5,  1.5,  2.5, ..., 67.5, 68.5, 69.5],
#        [ 0.5,  1.5,  2.5, ..., 67.5, 68.5, 69.5],
#        ...,
#        [ 0.5,  1.5,  2.5, ..., 67.5, 68.5, 69.5],
#        [ 0.5,  1.5,  2.5, ..., 67.5, 68.5, 69.5],
#        [ 0.5,  1.5,  2.5, ..., 67.5, 68.5, 69.5]])

# %% [markdown]
# #Temporarily removed... the 'constant head' data doesn't seem right...
# def get_ocean_outflow(m,ocean_col):
#     fname = os.path.join(m.model_ws, m.name + '.cbc')
#     budobj = flopy.utils.CellBudgetFile(fname)
#     ch = budobj.get_data(text='CONSTANT HEAD')
#     ocean_col_vec = np.arange(ocean_col[0],ocean_col[1]+1)
#     ocean_nodes = np.ravel_multi_index([np.zeros(ocean_col_vec.size,dtype=int), #nodes in constant head flow file are 1-based
#                                       np.zeros(ocean_col_vec.size,dtype=int),   #create a list of node numbers for ocean cells
#                                       ocean_col_vec],
#                                      (m.dis.nlay,m.dis.nrow,m.dis.ncol)) + 1
#
#     ocean_flow =  [ch[-1]['q'][i] for i,node in enumerate(ch[-1]['node']) if node in ocean_nodes]
#     tot_flow = np.sum(ocean_flow)
#     return flow

# %%
# Extract heads
fname = os.path.join(model_ws, '' + modelname + '.hds')
hdobj = flopy.utils.binaryfile.HeadFile(fname)
times = hdobj.get_times()
hdobj.get_kstpkper()
hds = hdobj.get_data(totim=times[-1])
hds[np.where(ibound != 1)] = np.nan

# Extract salinity
fname = os.path.join(model_ws, 'MT3D001.UCN')
ucnobj = flopy.utils.binaryfile.UcnFile(fname)
times = ucnobj.get_times()
conc = ucnobj.get_data(totim=times[-1])
conc[np.where(ibound != 1)] = np.nan

# %%
# Make head and quiver plot
import utils
printyn = 0
rowslice = 2
f, axs = plt.subplots(2,1, sharex=True, figsize=(15, 8),
                     gridspec_kw = {'height_ratios':[1, 7]})
plt.tight_layout()

#Plot discharge and ibound
mm = flopy.plot.ModelCrossSection(ax=axs[1], model=m, line={'row':rowslice})
cpatchcollection,label = plot_background(mm,hk)
mm.plot_ibound()
plotdischarge(m.name,m.model_ws,color='white',per=-1,scale=1,rowslice=rowslice);
plt.xlabel('Distance (m)')
plt.ylabel('Height (m)')

#plot SGD
ocean_flow = 100 * np.asarray(utils.get_ocean_outflow_chd(m,ocean_bool))

plt.sca(axs[0]) #set current axes
plt.bar(np.arange(ocean_col[0],ocean_col[1]+1)+delc/2,
        ocean_flow[:,rowslice,:][ocean_bool[:,rowslice,:]])
axs[0].axhline()
axs[0].set_ylim(np.min(ocean_flow)*0.9,np.max(ocean_flow)*1.1)
plt.ylabel('SGD (cm/d)')
axs[0].annotate('total flow = ' + str(np.sum(ocean_flow)) + ' cm/d', xy=(.1,.5),
            xytext=(0.1, 0.5), xycoords='axes fraction', textcoords='axes fraction')

#Plot salt content of cells beneath outflow
ocean_below_ind = [np.where(ocean_bool)[0]+1,
                   np.where(ocean_bool)[1],
                   np.where(ocean_bool)[2]]
ind = np.where(ocean_below_ind[1] == rowslice)
ocean_below_ind_slice = (ocean_below_ind[0][ind],ocean_below_ind[1][ind],ocean_below_ind[2][ind])           
ocean_salt_outflow = get_salt_outflow(m,kstpkper = (nstp[-1]-1,nper-1))[ocean_below_ind_slice]
                   
                   
axs02 = axs[0].twinx()
plt.plot(ocean_col_vec[2]+delc/2 , ocean_salt_outflow,'r.')
#axs02.set_ylim(0,Csalt)

plt.ylabel('conc of underlying (g/L)')

#align plots and set colorbar
f.subplots_adjust(right=0.93)
cbar_ax = f.add_axes([0.95, 0.1, 0.02, 0.7])
cb = f.colorbar(cpatchcollection,cax=cbar_ax)
cb.set_label(label)
if printyn == 1:
    plt.savefig(os.path.join(m.model_ws, m.name + '_flow_vectors.png'),dpi=300)
plt.show()
# Out:
# label:  lithmat

# %%
# Load the mas file and make a plot of total mass in aquifer versus time
fname = os.path.join(model_ws, 'MT3D001.MAS')
mas = flopy.mt3d.Mt3dms.load_mas(fname)
f = plt.figure()
ax = f.add_subplot(1, 1, 1)
lines = ax.plot(mas.time, mas.total_mass)
mas[0]
plt.show()

# %% [markdown]
# # Reading in real data

# %%
import pandas
from pathlib import Path
ws = Path(m.model_ws)
basedir = ws.joinpath('..','..')
datadir = basedir.joinpath('data')
fname = datadir.joinpath('seepage_flow_2015.xlsx')
flowsheet = pandas.read_excel(fname,skiprows=1)
print('Columns: ',flowsheet.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b5dd49014559> in <module>()
#       1 import pandas
#       2 from pathlib import Path
# ----> 3 ws = Path(m.model_ws)
#       4 basedir = ws.joinpath('..','..')
#       5 datadir = basedir.joinpath('data')
#
# NameError: name 'm' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2a31289f7529> in <module>()
# ----> 1 flowsheet.Flow
#
# NameError: name 'flowsheet' is not defined

# %%
plt.scatter(flowsheet.X,flowsheet.Y,s=np.exp(flowsheet.Flow),c=flowsheet.EC_IN)

# %% [markdown]
# #Issue: which "flow" is the correct flow?
#     #Can get flow from the cell-by-cell file in either FLOW RIGHT FACE and FLOW LOWER FACE
#     # Or from the constant head flow
#
# ocean_flow = get_ocean_outflow(m,ocean_col);
# print('total flow into ocean cells from const. head flow:',-np.sum(ocean_flow),'m^3/d')
#
# fname = os.path.join(model_ws, '' + modelname + '.cbc')
# budobj = flopy.utils.CellBudgetFile(fname)
# qx = budobj.get_data(text='FLOW RIGHT FACE')[-1]
# qz = budobj.get_data(text='FLOW LOWER FACE')[-1]
# tot_flow = np.sum( np.sqrt(np.square(-qz[ocean_coords]) + np.square(qx[ocean_coords])))
# print('Total flow from lower-right face in cbc file', tot_flow ,'m^3/d' )
