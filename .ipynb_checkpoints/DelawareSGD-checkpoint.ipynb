# %% [markdown]
# # Delaware Case Study
# ## Simple Model of SGD

# %%
# %matplotlib inline
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors

#Name model
modelname = 'test2'

# run installed version of flopy or add local path
try:
    import flopy
except:
    fpth = os.path.abspath(os.path.join('..', '..'))
    sys.path.append(fpth)
    import flopy

print(sys.version)
print('numpy version: {}'.format(np.__version__))
print('flopy version: {}'.format(flopy.__version__))

if sys.platform == "darwin":
    model_ws = os.path.join('/Users/ianpg/Documents/ProjectsLocal/DelawareSGD','work',modelname)
elif sys.platform == "win32":
    model_ws = os.path.join('E:\Projects\DelawareSGD','work',modelname)    

if not os.path.exists(model_ws):
    os.makedirs(model_ws)
sys.path.append(os.path.join(model_ws,'..','..'))
import config
sw_exe = config.swexe

os.listdir(model_ws)

print('Model workspace:',os.path.abspath(model_ws))
# Out:
# 3.6.1 |Anaconda custom (x86_64)| (default, May 11 2017, 13:04:09)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
# numpy version: 1.13.3
# flopy version: 3.2.6
# Model workspace: /Users/ianpg/Documents/ProjectsLocal/DelawareSGD/work/test2

# %%
#Other functions and imports

#nearest value in array
def find_nearest(array,value):
    import numpy as np
    idx = (np.abs(array-value)).argmin()
    idx.astype('int')
    return array[idx]

#take distance in meters, return column in model
def loc_to_col(locs):
    cols = [int(find_nearest((np.arange(ncol)*delc),loc)) for loc in locs]
    return cols

# %%
#Model grid
#Grid: 0.5 *1*1m • Size:70m*20m
        
Lx = 70.
Lz = 20.
nlay = 40
nrow = 3
ncol = 70
delr = Lx / ncol
delc = 1.0
delv = Lz / nlay
henry_top = Lz
henry_botm = np.linspace(henry_top - delv, 0., nlay)

#Period data
nper = 1
perlen = [100]
nstp = [100]
steady = [True]
itmuni = 4 #time unit 4= days
lenuni = 2 #length unit 2 = meter
tsmult = 1
ssm_data = None
verbose=True

# %%
#Create basic model instance and dis pacakge
m = flopy.seawat.Seawat(modelname, exe_name=sw_exe, model_ws=model_ws,verbose=verbose)
print(m.namefile)

# Add DIS package to the MODFLOW model
dis = flopy.modflow.ModflowDis(m, nlay, nrow, ncol, nper=nper, delr=delr,
                               delc=delc, laycbd=0, top=henry_top,
                               botm=henry_botm, perlen=perlen, nstp=nstp,
                               steady=steady,itmuni=itmuni,lenuni=lenuni,
                               tsmult=tsmult)
# Out:
# User specified FTL file does not exist in model directory
# MT3D will not work without a linker file
# test2.nam
# adding Package:  DIS

# %%
#Hydraulic conductivity field 

hkSand = 80.  #horizontal hydraulic conductivity m/day
hkClay = 1. 
lithmat = hkSand*np.ones((nlay,nrow,ncol), dtype=np.int32) #sandy background
addclay_yn = 1


def rand_clay_blocks(lithmat,hkClay,numblocks,sizeblocks):
    nlay,nrow,ncol = lithmat.shape
    lay_block = np.random.randint(1,nlay-sizeblocks[0],numblocks)
    row_block = np.random.randint(0,nrow-sizeblocks[1]+1,numblocks)
    col_block = np.random.randint(1,ncol-sizeblocks[2],numblocks)
    lithmat_blocks = lithmat.copy()
    for i in range(numblocks):
        block_coords = [slice(lay_block[i],lay_block[i]+sizeblocks[0]),
                        slice(row_block[i],row_block[i]++sizeblocks[1]),
                        slice(col_block[i],col_block[i]+sizeblocks[2])]
        lithmat_blocks[block_coords] = hkClay
    return lithmat_blocks

#add low conductivity regions
if addclay_yn == 1:
    lithmat = rand_clay_blocks(lithmat,hkClay,100,(2,2,5))
low_k_loc = (20,30)
low_k_col = loc_to_col(low_k_loc)
#lithmat[1:3,0,0:65] = hkClay

# %%
#Set Hydraulic properties

hk = lithmat
sy = 0.15
ss = 0.00005
por = 0.2
vka = 1/10 # = vk/hk
al = 3 #longitudinal dispersivity, in m
#dmcoef = 0.57024 #m2/day  Could also try 1.62925 as another case of the Henry problem
dmcoef = 0. #test for numerical dispersion

#Variable density parameters
Csalt = 35.0001
Cfresh = 0.
densesalt = 1025.
densefresh = 1000.
denseslp = (densesalt - densefresh) / (Csalt - Cfresh)

# %%
#BCs
calc_inland_head = 1 #don't calculate from hgrad
manual_inland_head = Lz + .1
ocean_head = Lz
start_fresh_yn = 0

# save cell fluxes to unit 53
ipakcb = 53

#MODFLOW BCs
hgrad = 0.0033 #hydraulic gradient, m/m
qinflow = 0  #influent FW m3/day

#Create ocean boundary at top of model
ocean_loc = [30,70] # location of ocean [start,end] in m
ocean_col = [int(find_nearest((np.arange(ncol)*delc),loc)) for loc in ocean_loc]
ocean_col_vec = (0,0,np.arange(ocean_col[0],ocean_col[1]+1))
ocean_coords = (0,slice(0,nrow),slice(ocean_col[0],ocean_col[1]+1)) #top of the model
ocean_bool = np.zeros((nlay,nrow,ncol), dtype=bool)
ocean_bool[0,:,np.arange(ocean_col[0],ocean_col[1]+1)] = 1

if calc_inland_head ==1:
    head_inland = ocean_loc[0]*hgrad + Lz
else:
    head_inland = manual_inland_head


#Set ibound
ibound = np.ones((nlay, nrow, ncol), dtype=np.int32)
ibound[:, :, 0] = -1 #first column (FW boundary) has fixed head
ibound[ocean_bool] = -1
ibound[0:2,:,ocean_col[0]-3:ocean_col[0]] = 0

#Set starting heads
strt = head_inland*np.ones((nlay, nrow, ncol)) #starting heads (for fixed head BC, this is will assign the head)
strt[ocean_bool] = ocean_head #head of ocean boundary

#Transport BCs
if start_fresh_yn == 1:
    sconc = Cfresh*np.ones((nlay, nrow, ncol), dtype=np.float32) #Begin fresh
elif start_fresh_yn == 0:
    sconc = Csalt*np.ones((nlay, nrow, ncol), dtype=np.float32) #Begin SW-saturated

sconc[ocean_bool] = Csalt
sconc[:,:,0] = Cfresh

icbund = np.ones((nlay, nrow, ncol), dtype=np.int) 
icbund[(ibound < 0)] = -1 #constant concentration cells where also constant head

# %%
#Create instances in flopy

bas = flopy.modflow.ModflowBas(m, ibound, strt=strt)

# Add LPF package to the MODFLOW model
lpf = flopy.modflow.ModflowLpf(m, hk=hk, vka=vka, ipakcb=ipakcb, ss=ss, sy=sy)

# Add PCG Package to the MODFLOW model
pcg = flopy.modflow.ModflowPcg(m, hclose=1.e-8)

# Add OC package to the MODFLOW model
oc = flopy.modflow.ModflowOc(m,
                             stress_period_data={(0, 0): ['save head', 'save budget']},
                             compact=True)
#wel = flopy.modflow.ModflowWel(m, stress_period_data=wel_data, ipakcb=ipakcb)

#Create the basic MT3DMS model structure
btn = flopy.mt3d.Mt3dBtn(m, 
                         #nlay=nlay, nrow=nrow, ncol=ncol, nper=nper, 
                         laycon=lpf.laytyp, htop=henry_top, 
                         dz=dis.thickness.get_value(), prsity=0.2, icbund=icbund,
                         sconc=sconc, nprs=-10)
adv = flopy.mt3d.Mt3dAdv(m, mixelm=0)
dsp = flopy.mt3d.Mt3dDsp(m, al=al, trpt=1., trpv=1., dmcoef=dmcoef)
gcg = flopy.mt3d.Mt3dGcg(m, iter1=500, mxiter=1, isolve=1, cclose=1e-7)
ssm = flopy.mt3d.Mt3dSsm(m, stress_period_data=ssm_data)

#vdf = flopy.seawat.SeawatVdf(m, iwtable=0, densemin=0, densemax=0,denseref=1000., denseslp=0.7143, firstdt=1e-3)
vdf = flopy.seawat.SeawatVdf(m, mtdnconc=1, mfnadvfd=1, nswtcpl=0, iwtable=0, 
                             densemin=0., densemax=0., denseslp=denseslp, denseref=densefresh)
# Out:
# WARNING: unit 13 of package BAS6 already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mfbas.ModflowBas'> <class 'flopy.modflow.mfbas.ModflowBas'>
# replacing existing Package...
# WARNING: unit 15 of package LPF already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mflpf.ModflowLpf'> <class 'flopy.modflow.mflpf.ModflowLpf'>
# replacing existing Package...
# WARNING: unit 27 of package PCG already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mfpcg.ModflowPcg'> <class 'flopy.modflow.mfpcg.ModflowPcg'>
# replacing existing Package...
# WARNING: unit 14 of package OC already in use
# ****Warning -- two packages of the same type:  <class 'flopy.modflow.mfoc.ModflowOc'> <class 'flopy.modflow.mfoc.ModflowOc'>
# replacing existing Package...
# WARNING: unit 31 of package BTN already in use
# ****Warning -- two packages of the same type:  <class 'flopy.mt3d.mtbtn.Mt3dBtn'> <class 'flopy.mt3d.mtbtn.Mt3dBtn'>
# replacing existing Package...
# WARNING: unit 32 of package ADV already in use
# ****Warning -- two packages of the same type:  <class 'flopy.mt3d.mtadv.Mt3dAdv'> <class 'flopy.mt3d.mtadv.Mt3dAdv'>
# replacing existing Package...
# WARNING: unit 33 of package DSP already in use
# ****Warning -- two packages of the same type:  <class 'flopy.mt3d.mtdsp.Mt3dDsp'> <class 'flopy.mt3d.mtdsp.Mt3dDsp'>
# replacing existing Package...
# WARNING: unit 35 of package GCG already in use
# ****Warning -- two packages of the same type:  <class 'flopy.mt3d.mtgcg.Mt3dGcg'> <class 'flopy.mt3d.mtgcg.Mt3dGcg'>
# replacing existing Package...
# WARNING: unit 34 of package SSM already in use
# ****Warning -- two packages of the same type:  <class 'flopy.mt3d.mtssm.Mt3dSsm'> <class 'flopy.mt3d.mtssm.Mt3dSsm'>
# replacing existing Package...
# WARNING: unit 37 of package VDF already in use
# ****Warning -- two packages of the same type:  <class 'flopy.seawat.swtvdf.SeawatVdf'> <class 'flopy.seawat.swtvdf.SeawatVdf'>
# replacing existing Package...

# %%
# Make plot of the grid
f = plt.figure(figsize=(15, 5))
plt.clf()
ax = f.add_subplot(1, 1, 1)
mm = flopy.plot.ModelCrossSection(ax=ax, model=m, line={'row':1});
hkpatchcollection = mm.plot_array(hk, norm=matplotlib.colors.LogNorm(),vmin=hkClay, vmax=hkSand);
linecollectdsion = mm.plot_grid();
patchcollection = mm.plot_ibound();
cb = plt.colorbar(patchcollection);
cb.set_label('Boundary condition',rotation=90)

cb.set_ticks((1.5,2.5))
#cb.set_ticklabels(('No flow','Const head'))
cb.ax.set_yticklabels(('No flow','Const head'),rotation=90)


cb2 = plt.colorbar(hkpatchcollection,ax=ax);
cb2.set_label('Kh (m/d)', rotation=90)
plt.title('K-field & Boundary conditions');

# %%
#Write input
m.write_input()

# Try to delete the output files, to prevent accidental use of older files
try:
    os.remove(os.path.join(model_ws,'MT3D.CNF'))
    os.remove(os.path.join(model_ws,'MT3D001.MAS'))
    os.remove(os.path.join(model_ws, 'MT3D001.UCN'))
    os.remove(os.path.join(model_ws, modelname + '.hds'))
    os.remove(os.path.join(model_ws, modelname + '.cbc'))
except:
    pass
# Out:
# Writing packages:
#    Package:  DIS
#    Package:  BAS6
#    Package:  LPF
#    Package:  PCG
#    Package:  OC
#    Package:  BTN
#    Package:  ADV
#    Package:  DSP
#    Package:  GCG
#    Package:  SSM
#    Package:  VDF

# %%
#Run model
v = m.run_model(silent=False, report=True)
for idx in range(-3, 0):
    print(v[1][idx])
# Out:
# FloPy is using the following executable to run the model: /Users/ianpg/Documents/ProjectsLocal/SyntheticSWI/bin/modflow_macOS/swt_v4
#
#                                   SEAWAT Version 4
#     U.S. GEOLOGICAL SURVEY MODULAR FINITE-DIFFERENCE GROUND-WATER FLOW MODEL
#                              Version 4.00.05 10/19/2012
#
# Incorporated MODFLOW Version: 1.18.01 06/20/2008
# Incorporated MT3DMS  Version: 5.20    10/30/2006
#
#
#  This program is public domain and is released on the
#  condition that neither the U.S. Geological Survey nor
#  the United States Government may be held liable for any
#  damages resulting from their authorized or unauthorized
#  use.
#
#
#  Using NAME file: test2.nam
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2018/08/27 18:42:37
#
#
#  STRESS PERIOD NO.    1
#
#   STRESS PERIOD    1 TIME STEP    1 FROM TIME =   0.0000     TO    1.0000
#
#  Transport Step:    1   Step Size:  1.0000E-03 Total Elapsed Time:  1.00000E-03
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2131E-02  [K,I,J]    1    1    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1008E-04  [K,I,J]    2    2    2
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4591E-07  [K,I,J]    2    2    3
#  Transport Step:    2   Step Size:  0.9244     Total Elapsed Time:  0.92539
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3963      [K,I,J]    1    1    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1832      [K,I,J]    2    1    2
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1046      [K,I,J]    3    1    2
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7107E-01  [K,I,J]    3    1    3
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4516E-01  [K,I,J]    3    2    3
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2843E-01  [K,I,J]    4    2    3
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1905E-01  [K,I,J]    2    2    4
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1206E-01  [K,I,J]    3    2    4
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.7159E-02  [K,I,J]    3    2    5
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.4768E-02  [K,I,J]    2    2    5
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.3019E-02  [K,I,J]    6    2    3
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1981E-02  [K,I,J]    3    2    6
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1194E-02  [K,I,J]    3    2    7
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.8124E-03  [K,I,J]    2    2    7
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.4973E-03  [K,I,J]    2    2    8
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.3276E-03  [K,I,J]    3    2    8
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.2119E-03  [K,I,J]    2    2    8
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.1391E-03  [K,I,J]    2    2    9
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.8626E-04  [K,I,J]    3    2    9
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.5603E-04  [K,I,J]    3    2   10
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.3759E-04  [K,I,J]    2    2   10
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =  0.2334E-04  [K,I,J]    2    2   11
#  Outer Iter.  1  Inner Iter. 23:  Max. DC =  0.1551E-04  [K,I,J]    3    2   11
#  Outer Iter.  1  Inner Iter. 24:  Max. DC =  0.9431E-05  [K,I,J]    3    2   12
#  Outer Iter.  1  Inner Iter. 25:  Max. DC =  0.6203E-05  [K,I,J]    2    2   12
#  Outer Iter.  1  Inner Iter. 26:  Max. DC =  0.3704E-05  [K,I,J]    3    2   12
#  Outer Iter.  1  Inner Iter. 27:  Max. DC =  0.2545E-05  [K,I,J]    3    2   13
#  Outer Iter.  1  Inner Iter. 28:  Max. DC =  0.1530E-05  [K,I,J]    3    3   13
#  Outer Iter.  1  Inner Iter. 29:  Max. DC =  0.1071E-05  [K,I,J]    3    3   14
#  Outer Iter.  1  Inner Iter. 30:  Max. DC =  0.7306E-06  [K,I,J]    4    3   14
#  Outer Iter.  1  Inner Iter. 31:  Max. DC =  0.5065E-06  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 32:  Max. DC =  0.3505E-06  [K,I,J]    3    3   15
#  Outer Iter.  1  Inner Iter. 33:  Max. DC =  0.2279E-06  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 34:  Max. DC =  0.1604E-06  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 35:  Max. DC =  0.9727E-07  [K,I,J]    4    3   17
#  Transport Step:    3   Step Size:  7.4607E-02 Total Elapsed Time:   1.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3149E-01  [K,I,J]    1    3    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6665E-02  [K,I,J]    2    2    2
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9329E-03  [K,I,J]    2    2    3
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2862E-03  [K,I,J]    3    1    2
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5708E-04  [K,I,J]    3    2    2
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1678E-04  [K,I,J]    2    2    2
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4725E-05  [K,I,J]    2    2    3
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.9008E-06  [K,I,J]    1    2    3
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2104E-06  [K,I,J]    1    2    4
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.4854E-07  [K,I,J]    2    2    4
#
#   STRESS PERIOD    1 TIME STEP    2 FROM TIME =   1.0000     TO    2.0000
#
#  Transport Step:    1   Step Size:  0.9234     Total Elapsed Time:   1.9234
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1802      [K,I,J]    6    1    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6555E-01  [K,I,J]    5    2    2
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4303E-01  [K,I,J]    2    2    3
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3314E-01  [K,I,J]    3    2    3
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1742E-01  [K,I,J]    2    1    3
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9702E-02  [K,I,J]    2    3    4
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.6868E-02  [K,I,J]    1    1    4
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.4513E-02  [K,I,J]    2    2    5
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.3073E-02  [K,I,J]    1    2    5
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1858E-02  [K,I,J]    1    2    6
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1223E-02  [K,I,J]    2    2    6
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.7967E-03  [K,I,J]    2    2    7
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.5084E-03  [K,I,J]    3    2    7
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.3244E-03  [K,I,J]    3    2    8
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.2096E-03  [K,I,J]    2    2    8
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.1311E-03  [K,I,J]    2    2    9
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.8472E-04  [K,I,J]    3    2    9
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.5462E-04  [K,I,J]    2    2    9
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.3590E-04  [K,I,J]    2    2   10
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.2326E-04  [K,I,J]    3    2   10
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.1464E-04  [K,I,J]    3    2   11
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =  0.9675E-05  [K,I,J]    2    2   11
#  Outer Iter.  1  Inner Iter. 23:  Max. DC =  0.6148E-05  [K,I,J]    2    2   12
#  Outer Iter.  1  Inner Iter. 24:  Max. DC =  0.3987E-05  [K,I,J]    3    2   12
#  Outer Iter.  1  Inner Iter. 25:  Max. DC =  0.2450E-05  [K,I,J]    3    2   13
#  Outer Iter.  1  Inner Iter. 26:  Max. DC =  0.1654E-05  [K,I,J]    2    2   13
#  Outer Iter.  1  Inner Iter. 27:  Max. DC =  0.1054E-05  [K,I,J]    3    3   14
#  Outer Iter.  1  Inner Iter. 28:  Max. DC =  0.7313E-06  [K,I,J]    4    3   14
#  Outer Iter.  1  Inner Iter. 29:  Max. DC =  0.5041E-06  [K,I,J]    3    3   14
#  Outer Iter.  1  Inner Iter. 30:  Max. DC =  0.3569E-06  [K,I,J]    3    3   15
#  Outer Iter.  1  Inner Iter. 31:  Max. DC =  0.2433E-06  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 32:  Max. DC =  0.1595E-06  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 33:  Max. DC =  0.1024E-06  [K,I,J]    3    3   16
#  Outer Iter.  1  Inner Iter. 34:  Max. DC =  0.6530E-07  [K,I,J]    3    3   17
#  Transport Step:    2   Step Size:  7.6601E-02 Total Elapsed Time:   2.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1792E-01  [K,I,J]    6    1    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3605E-02  [K,I,J]    2    2    3
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6194E-03  [K,I,J]    5    2    2
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1130E-03  [K,I,J]    4    2    2
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.2710E-04  [K,I,J]    3    2    2
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.7753E-05  [K,I,J]    2    2    2
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1682E-05  [K,I,J]    1    2    2
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.5078E-06  [K,I,J]    1    2    3
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.9113E-07  [K,I,J]    1    2    4
#
#   STRESS PERIOD    1 TIME STEP    3 FROM TIME =   2.0000     TO    3.0000
#
#  Transport Step:    1   Step Size:  0.9233     Total Elapsed Time:   2.9233
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1410      [K,I,J]    6    1    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4961E-01  [K,I,J]    5    1    2
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3411E-01  [K,I,J]    4    2    3
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2432E-01  [K,I,J]    3    2    3
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1282E-01  [K,I,J]    2    2    4
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5714E-02  [K,I,J]    1    2    4
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3781E-02  [K,I,J]    1    2    5
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2368E-02  [K,I,J]    2    2    5
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1828E-02  [K,I,J]    2    2    6
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1129E-02  [K,I,J]    1    2    6
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.6223E-03  [K,I,J]    1    2    7
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.4044E-03  [K,I,J]    2    2    7
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.2567E-03  [K,I,J]    2    2    8
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.1820E-03  [K,I,J]    3    2    8
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.1143E-03  [K,I,J]    2    2    9
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.7454E-04  [K,I,J]    2    2    9
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.4354E-04  [K,I,J]    2    2   10
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.2782E-04  [K,I,J]    2    2   10
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.1822E-04  [K,I,J]    2    2   11
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.1294E-04  [K,I,J]    2    2   11
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.8097E-05  [K,I,J]    2    2   11
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =  0.4987E-05  [K,I,J]    2    2   12
#  Outer Iter.  1  Inner Iter. 23:  Max. DC =  0.3151E-05  [K,I,J]    2    2   12
#  Outer Iter.  1  Inner Iter. 24:  Max. DC =  0.2038E-05  [K,I,J]    3    3   13
#  Outer Iter.  1  Inner Iter. 25:  Max. DC =  0.1393E-05  [K,I,J]    3    3   13
#  Outer Iter.  1  Inner Iter. 26:  Max. DC =  0.9872E-06  [K,I,J]    3    3   14
#  Outer Iter.  1  Inner Iter. 27:  Max. DC =  0.6458E-06  [K,I,J]    3    3   14
#  Outer Iter.  1  Inner Iter. 28:  Max. DC =  0.4380E-06  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 29:  Max. DC =  0.3074E-06  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 30:  Max. DC =  0.2116E-06  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 31:  Max. DC =  0.1426E-06  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 32:  Max. DC =  0.8651E-07  [K,I,J]    4    3   17
#  Transport Step:    2   Step Size:  7.6656E-02 Total Elapsed Time:   3.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.1308E-01  [K,I,J]    6    1    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2487E-02  [K,I,J]    2    2    3
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.5064E-03  [K,I,J]    8    3    2
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8155E-04  [K,I,J]    4    1    2
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1648E-04  [K,I,J]    3    2    2
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3722E-05  [K,I,J]    2    2    2
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.9623E-06  [K,I,J]    1    2    2
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2130E-06  [K,I,J]    1    2    3
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.3876E-07  [K,I,J]    2    2    3
#
#   STRESS PERIOD    1 TIME STEP    4 FROM TIME =   3.0000     TO    4.0000
#
#  Transport Step:    1   Step Size:  0.9233     Total Elapsed Time:   3.9233
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9907E-01  [K,I,J]    6    1    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.4027E-01  [K,I,J]    8    2    2
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2611E-01  [K,I,J]    4    1    3
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1909E-01  [K,I,J]    3    2    3
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1137E-01  [K,I,J]    2    2    4
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.5111E-02  [K,I,J]   10    2    3
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2570E-02  [K,I,J]    1    2    5
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1483E-02  [K,I,J]    1    2    6
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1200E-02  [K,I,J]    2    2    6
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.8681E-03  [K,I,J]    2    2    7
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.4685E-03  [K,I,J]    1    2    7
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.2782E-03  [K,I,J]    2    2    8
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1545E-03  [K,I,J]    2    2    8
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.1092E-03  [K,I,J]    2    2    9
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.7776E-04  [K,I,J]    3    2    9
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.5348E-04  [K,I,J]    2    2   10
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.3326E-04  [K,I,J]    2    2   10
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.1793E-04  [K,I,J]    2    2   11
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.1175E-04  [K,I,J]    2    2   11
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.8110E-05  [K,I,J]    2    2   12
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.5956E-05  [K,I,J]    2    2   12
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =  0.3673E-05  [K,I,J]    2    2   12
#  Outer Iter.  1  Inner Iter. 23:  Max. DC =  0.2278E-05  [K,I,J]    3    3   13
#  Outer Iter.  1  Inner Iter. 24:  Max. DC =  0.1381E-05  [K,I,J]    3    3   14
#  Outer Iter.  1  Inner Iter. 25:  Max. DC =  0.9925E-06  [K,I,J]    3    3   14
#  Outer Iter.  1  Inner Iter. 26:  Max. DC =  0.7530E-06  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 27:  Max. DC =  0.5367E-06  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 28:  Max. DC =  0.3281E-06  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 29:  Max. DC =  0.2108E-06  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 30:  Max. DC =  0.1410E-06  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 31:  Max. DC =  0.9951E-07  [K,I,J]    4    3   17
#  Transport Step:    2   Step Size:  7.6741E-02 Total Elapsed Time:   4.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.9129E-02  [K,I,J]    6    1    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1912E-02  [K,I,J]    2    2    4
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.4035E-03  [K,I,J]    8    3    2
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5738E-04  [K,I,J]    4    1    2
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1019E-04  [K,I,J]    3    2    2
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2009E-05  [K,I,J]    1    2    5
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4674E-06  [K,I,J]    1    2    2
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1313E-06  [K,I,J]    1    2    3
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2848E-07  [K,I,J]    2    1    3
#
#   STRESS PERIOD    1 TIME STEP    5 FROM TIME =   4.0000     TO    5.0000
#
#  Transport Step:    1   Step Size:  0.9231     Total Elapsed Time:   4.9231
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7210E-01  [K,I,J]    7    1    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.3318E-01  [K,I,J]    8    2    2
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2023E-01  [K,I,J]    4    1    3
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1609E-01  [K,I,J]    3    2    4
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.1001E-01  [K,I,J]    2    2    4
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.4581E-02  [K,I,J]   10    2    3
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1907E-02  [K,I,J]    1    2    5
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.9868E-03  [K,I,J]   11    2    2
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.7969E-03  [K,I,J]    2    2    7
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.6386E-03  [K,I,J]    1    2    7
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.3947E-03  [K,I,J]    1    2    8
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.2191E-03  [K,I,J]    2    2    8
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1152E-03  [K,I,J]    2    2    9
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.7171E-04  [K,I,J]    1    1    5
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.5553E-04  [K,I,J]    2    1    5
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.1806E-03  [K,I,J]    2    1    6
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.1401E-03  [K,I,J]    3    1    5
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.1760E-04  [K,I,J]    3    2   11
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.8422E-05  [K,I,J]    2    2   11
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.5693E-05  [K,I,J]    2    2   12
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.4011E-05  [K,I,J]    3    2   12
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =  0.2796E-05  [K,I,J]    3    2   13
#  Outer Iter.  1  Inner Iter. 23:  Max. DC =  0.1766E-05  [K,I,J]    3    3   14
#  Outer Iter.  1  Inner Iter. 24:  Max. DC =  0.1036E-05  [K,I,J]    3    3   14
#  Outer Iter.  1  Inner Iter. 25:  Max. DC =  0.6833E-06  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 26:  Max. DC =  0.5375E-06  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 27:  Max. DC =  0.4102E-06  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 28:  Max. DC =  0.2557E-06  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 29:  Max. DC =  0.1509E-06  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 30:  Max. DC =  0.9139E-07  [K,I,J]    4    3   17
#  Transport Step:    2   Step Size:  7.6853E-02 Total Elapsed Time:   5.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.7226E-02  [K,I,J]    6    1    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1553E-02  [K,I,J]    3    2    4
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.3137E-03  [K,I,J]    8    3    3
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.4095E-04  [K,I,J]    4    1    3
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7391E-05  [K,I,J]    2    2    5
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1536E-05  [K,I,J]    1    2    5
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2903E-06  [K,I,J]    4    1    3
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.9564E-07  [K,I,J]   39    1    9
#
#   STRESS PERIOD    1 TIME STEP    6 FROM TIME =   5.0000     TO    6.0000
#
#  Transport Step:    1   Step Size:  0.9230     Total Elapsed Time:   5.9230
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5837E-01  [K,I,J]    7    1    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2741E-01  [K,I,J]    8    2    2
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1653E-01  [K,I,J]    4    1    4
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1376E-01  [K,I,J]    3    2    4
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8777E-02  [K,I,J]    2    2    5
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3954E-02  [K,I,J]   10    2    3
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1586E-02  [K,I,J]    8    2    4
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.7835E-03  [K,I,J]   11    2    2
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.5305E-03  [K,I,J]    2    2    7
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.4868E-03  [K,I,J]    2    3    3
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.3297E-03  [K,I,J]    1    2    8
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1941E-03  [K,I,J]    1    3    4
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.9354E-04  [K,I,J]    2    2    9
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.6263E-04  [K,I,J]    2    3    5
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.3091E-04  [K,I,J]    3    2   11
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.2842E-04  [K,I,J]    2    2   11
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.2164E-04  [K,I,J]    3    2   11
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.3374E-04  [K,I,J]   39    1    8
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.2580E-04  [K,I,J]   39    1    8
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.4852E-05  [K,I,J]    2    2   12
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.3069E-05  [K,I,J]    3    3   13
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =  0.2268E-05  [K,I,J]    3    3   14
#  Outer Iter.  1  Inner Iter. 23:  Max. DC =  0.1611E-05  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 24:  Max. DC =  0.9558E-06  [K,I,J]    3    3   15
#  Outer Iter.  1  Inner Iter. 25:  Max. DC =  0.5368E-06  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 26:  Max. DC =  0.3823E-06  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 27:  Max. DC =  0.3032E-06  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 28:  Max. DC =  0.2120E-06  [K,I,J]    4    3   17
#  Outer Iter.  1  Inner Iter. 29:  Max. DC =  0.1289E-06  [K,I,J]    4    3   17
#  Outer Iter.  1  Inner Iter. 30:  Max. DC =  0.6963E-07  [K,I,J]    4    3   18
#  Transport Step:    2   Step Size:  7.6984E-02 Total Elapsed Time:   6.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5840E-02  [K,I,J]    6    1    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1326E-02  [K,I,J]    2    2    5
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2821E-03  [K,I,J]    8    3    3
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.3325E-04  [K,I,J]    4    1    3
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6281E-05  [K,I,J]    2    2    5
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1279E-05  [K,I,J]    1    2    5
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2155E-06  [K,I,J]   40    1    9
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1060E-06  [K,I,J]   39    1    9
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1576E-07  [K,I,J]   40    1    9
#
#   STRESS PERIOD    1 TIME STEP    7 FROM TIME =   6.0000     TO    7.0000
#
#  Transport Step:    1   Step Size:  0.9229     Total Elapsed Time:   6.9229
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.5224E-01  [K,I,J]   14    3    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2429E-01  [K,I,J]    8    3    3
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1401E-01  [K,I,J]    4    1    4
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1192E-01  [K,I,J]    3    2    5
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7995E-02  [K,I,J]    2    2    5
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3412E-02  [K,I,J]    8    2    3
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1297E-02  [K,I,J]    8    2    4
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.7090E-03  [K,I,J]   11    1    3
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.3975E-03  [K,I,J]    9    2    3
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.3475E-03  [K,I,J]    2    3    3
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.2590E-03  [K,I,J]    2    3    9
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1624E-03  [K,I,J]    1    3    4
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.8641E-04  [K,I,J]    2    2   10
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.4508E-04  [K,I,J]    2    3    5
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.2270E-04  [K,I,J]    3    2   11
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.1760E-04  [K,I,J]    2    2   11
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.1492E-04  [K,I,J]    2    2   12
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.1084E-04  [K,I,J]    3    2   12
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.5356E-05  [K,I,J]    2    3   12
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.3087E-05  [K,I,J]    4    3   14
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.2211E-05  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =  0.1757E-05  [K,I,J]    3    3   15
#  Outer Iter.  1  Inner Iter. 23:  Max. DC =  0.1395E-05  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 24:  Max. DC =  0.9097E-06  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 25:  Max. DC =  0.5558E-06  [K,I,J]    4    3   17
#  Outer Iter.  1  Inner Iter. 26:  Max. DC =  0.9651E-07  [K,I,J]    4    1    6
#  Transport Step:    2   Step Size:  7.7127E-02 Total Elapsed Time:   7.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4929E-02  [K,I,J]    6    1    4
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1163E-02  [K,I,J]    3    2    5
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2481E-03  [K,I,J]    8    3    3
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2672E-04  [K,I,J]    4    1    3
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5505E-05  [K,I,J]    2    2    5
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1115E-05  [K,I,J]    1    2    5
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2378E-06  [K,I,J]   40    1    9
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.9852E-07  [K,I,J]   39    1    9
#
#   STRESS PERIOD    1 TIME STEP    8 FROM TIME =   7.0000     TO    8.0000
#
#  Transport Step:    1   Step Size:  0.9227     Total Elapsed Time:   7.9227
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4736E-01  [K,I,J]   14    3    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2217E-01  [K,I,J]    8    2    3
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1203E-01  [K,I,J]    9    2    3
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1065E-01  [K,I,J]    3    2    5
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.7202E-02  [K,I,J]    2    2    5
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.3065E-02  [K,I,J]    8    2    3
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.1071E-02  [K,I,J]   11    1    2
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.6337E-03  [K,I,J]   11    1    3
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2934E-03  [K,I,J]    9    2    3
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.2323E-03  [K,I,J]    2    3    3
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.2054E-03  [K,I,J]    2    3    9
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1382E-03  [K,I,J]    2    2    9
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.8589E-04  [K,I,J]    2    2   10
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.3947E-04  [K,I,J]    3    2   10
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.1863E-04  [K,I,J]    3    2   11
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.1274E-04  [K,I,J]    3    2   12
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.1119E-04  [K,I,J]    3    3   12
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.9571E-05  [K,I,J]    3    3   13
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.5384E-05  [K,I,J]    3    3   14
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.2840E-05  [K,I,J]    3    3   15
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.1753E-05  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =  0.1345E-05  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 23:  Max. DC =  0.1172E-05  [K,I,J]    3    3   16
#  Outer Iter.  1  Inner Iter. 24:  Max. DC =  0.4622E-05  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 25:  Max. DC =  0.3712E-05  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 26:  Max. DC =  0.2704E-06  [K,I,J]    4    3   17
#  Outer Iter.  1  Inner Iter. 27:  Max. DC =  0.1626E-06  [K,I,J]    4    3   18
#  Outer Iter.  1  Inner Iter. 28:  Max. DC =  0.1204E-06  [K,I,J]    4    3   18
#  Outer Iter.  1  Inner Iter. 29:  Max. DC =  0.9249E-07  [K,I,J]    4    3   19
#  Transport Step:    2   Step Size:  7.7280E-02 Total Elapsed Time:   8.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4264E-02  [K,I,J]    6    1    4
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1027E-02  [K,I,J]    3    2    6
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.2159E-03  [K,I,J]    8    3    3
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2242E-04  [K,I,J]    4    1    4
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4930E-05  [K,I,J]    2    2    5
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1005E-05  [K,I,J]    1    2    5
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3011E-06  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.8116E-07  [K,I,J]   39    1    9
#
#   STRESS PERIOD    1 TIME STEP    9 FROM TIME =   8.0000     TO    9.0000
#
#  Transport Step:    1   Step Size:  0.9226     Total Elapsed Time:   8.9226
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.4269E-01  [K,I,J]   14    3    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2014E-01  [K,I,J]    8    2    3
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1085E-01  [K,I,J]    9    2    3
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9489E-02  [K,I,J]    3    2    6
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6586E-02  [K,I,J]    2    2    6
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2685E-02  [K,I,J]    8    2    3
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.9895E-03  [K,I,J]    9    2    3
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.5709E-03  [K,I,J]   11    2    3
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.2200E-03  [K,I,J]    5    2    4
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1574E-03  [K,I,J]    1    2   10
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1541E-03  [K,I,J]    2    3    9
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.1182E-03  [K,I,J]    2    3   10
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.8329E-04  [K,I,J]    2    2   10
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.4126E-04  [K,I,J]    2    2   11
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.1841E-04  [K,I,J]    3    2   11
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.1046E-04  [K,I,J]    3    3   13
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.9000E-05  [K,I,J]    3    3   14
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.8557E-05  [K,I,J]    4    3   14
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.5364E-05  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.2533E-05  [K,I,J]    3    3   15
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.1346E-05  [K,I,J]    3    3   16
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =  0.9495E-06  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 23:  Max. DC =  0.8855E-06  [K,I,J]    4    3   17
#  Outer Iter.  1  Inner Iter. 24:  Max. DC =  0.1851E-05  [K,I,J]    3    1   10
#  Outer Iter.  1  Inner Iter. 25:  Max. DC =  0.2585E-05  [K,I,J]    3    1   10
#  Outer Iter.  1  Inner Iter. 26:  Max. DC =  0.2387E-06  [K,I,J]    4    3   19
#  Outer Iter.  1  Inner Iter. 27:  Max. DC =  0.1275E-06  [K,I,J]    4    3   19
#  Outer Iter.  1  Inner Iter. 28:  Max. DC =  0.8918E-07  [K,I,J]    4    3   20
#  Transport Step:    2   Step Size:  7.7440E-02 Total Elapsed Time:   9.0000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3682E-02  [K,I,J]    6    1    4
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.9399E-03  [K,I,J]    3    2    6
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1949E-03  [K,I,J]    8    2    3
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1930E-04  [K,I,J]    4    1    4
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4486E-05  [K,I,J]    2    2    6
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9119E-06  [K,I,J]    1    2    5
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3756E-06  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.7208E-07  [K,I,J]    4    3   16
#
#   STRESS PERIOD    1 TIME STEP   10 FROM TIME =   9.0000     TO    10.000
#
#  Transport Step:    1   Step Size:  0.9224     Total Elapsed Time:   9.9224
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3835E-01  [K,I,J]   14    3    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1820E-01  [K,I,J]    8    2    3
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9767E-02  [K,I,J]    9    2    3
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8730E-02  [K,I,J]    3    2    6
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6069E-02  [K,I,J]    2    2    6
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2436E-02  [K,I,J]    1    2    6
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.9033E-03  [K,I,J]    9    2    3
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.5157E-03  [K,I,J]   11    2    3
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1820E-03  [K,I,J]   11    2    4
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.1185E-03  [K,I,J]    1    2   10
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.1099E-03  [K,I,J]    2    3    9
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.9530E-04  [K,I,J]    2    3   10
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.7496E-04  [K,I,J]    2    2   10
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.4660E-04  [K,I,J]    2    2   11
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.2173E-04  [K,I,J]    3    3   12
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.1012E-04  [K,I,J]    4    3   14
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.7506E-05  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.7243E-05  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.4732E-05  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.2051E-05  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.9620E-06  [K,I,J]    4    3   17
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =  0.6787E-06  [K,I,J]    3    1   10
#  Outer Iter.  1  Inner Iter. 23:  Max. DC =  0.5963E-06  [K,I,J]    3    2   10
#  Outer Iter.  1  Inner Iter. 24:  Max. DC =  0.7915E-06  [K,I,J]    3    1   10
#  Outer Iter.  1  Inner Iter. 25:  Max. DC =  0.1965E-07  [K,I,J]    4    3   13
#  Transport Step:    2   Step Size:  7.7607E-02 Total Elapsed Time:   10.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3300E-02  [K,I,J]    6    1    5
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.8586E-03  [K,I,J]    3    2    6
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1757E-03  [K,I,J]    8    2    3
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1664E-04  [K,I,J]    4    1    4
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4150E-05  [K,I,J]    2    2    6
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.9475E-06  [K,I,J]    5    3   15
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4241E-06  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.6831E-07  [K,I,J]    4    3   17
#
#   STRESS PERIOD    1 TIME STEP   11 FROM TIME =   10.000     TO    11.000
#
#  Transport Step:    1   Step Size:  0.9222     Total Elapsed Time:   10.922
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3439E-01  [K,I,J]   14    3    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1653E-01  [K,I,J]    8    1    3
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8991E-02  [K,I,J]    9    2    4
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8002E-02  [K,I,J]    3    2    6
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5568E-02  [K,I,J]    2    2    6
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2254E-02  [K,I,J]    1    2    6
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.8311E-03  [K,I,J]    9    2    4
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.4650E-03  [K,I,J]   11    2    3
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1668E-03  [K,I,J]   11    2    4
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.8967E-04  [K,I,J]    1    2   10
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.8167E-04  [K,I,J]    2    3   11
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.7279E-04  [K,I,J]    2    2   11
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.6433E-04  [K,I,J]    2    2   12
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.5331E-04  [K,I,J]    3    3   13
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.3068E-04  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.1179E-04  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.6350E-05  [K,I,J]    4    3   17
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.5533E-05  [K,I,J]    4    3   18
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.3480E-05  [K,I,J]    4    3   19
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.1526E-05  [K,I,J]    2    1    9
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.9138E-06  [K,I,J]    2    3   10
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =  0.4286E-06  [K,I,J]    3    1   10
#  Outer Iter.  1  Inner Iter. 23:  Max. DC =  0.7870E-06  [K,I,J]    3    2   10
#  Outer Iter.  1  Inner Iter. 24:  Max. DC =  0.6496E-05  [K,I,J]    2    2   10
#  Outer Iter.  1  Inner Iter. 25:  Max. DC =  0.2543E-05  [K,I,J]    3    2   11
#  Outer Iter.  1  Inner Iter. 26:  Max. DC =  0.1950E-05  [K,I,J]    3    1   11
#  Outer Iter.  1  Inner Iter. 27:  Max. DC =  0.2199E-05  [K,I,J]    3    1   11
#  Outer Iter.  1  Inner Iter. 28:  Max. DC =  0.5198E-07  [K,I,J]    4    1    9
#  Transport Step:    2   Step Size:  7.7778E-02 Total Elapsed Time:   11.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2967E-02  [K,I,J]    6    1    5
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7918E-03  [K,I,J]    3    2    7
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1609E-03  [K,I,J]    8    2    4
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1455E-04  [K,I,J]    4    1    5
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4142E-05  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1152E-05  [K,I,J]    5    3   15
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4459E-06  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.6997E-07  [K,I,J]    4    3   17
#
#   STRESS PERIOD    1 TIME STEP   12 FROM TIME =   11.000     TO    12.000
#
#  Transport Step:    1   Step Size:  0.9220     Total Elapsed Time:   11.922
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3168E-01  [K,I,J]   16    1    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1527E-01  [K,I,J]    8    2    4
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.8421E-02  [K,I,J]    9    2    4
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.7329E-02  [K,I,J]    3    2    7
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5156E-02  [K,I,J]    2    2    7
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2106E-02  [K,I,J]    1    2    7
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.7886E-03  [K,I,J]    9    2    4
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.4205E-03  [K,I,J]   11    2    3
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1563E-03  [K,I,J]   11    2    4
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.7266E-04  [K,I,J]    3    3   15
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.6720E-04  [K,I,J]    3    3   14
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.6200E-04  [K,I,J]    3    3   15
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.5724E-04  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.6119E-04  [K,I,J]    3    3   15
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.4981E-04  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.1787E-04  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.5649E-05  [K,I,J]    4    3   17
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.3815E-05  [K,I,J]   40    3    4
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.3358E-05  [K,I,J]   40    3    4
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.1570E-05  [K,I,J]    3    3   10
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.4143E-06  [K,I,J]    2    3   10
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =  0.8096E-04  [K,I,J]    2    3   11
#  Outer Iter.  1  Inner Iter. 23:  Max. DC =  0.9151E-04  [K,I,J]    2    3   11
#  Outer Iter.  1  Inner Iter. 24:  Max. DC =  0.1857E-05  [K,I,J]    3    3   11
#  Outer Iter.  1  Inner Iter. 25:  Max. DC =  0.3140E-06  [K,I,J]    3    2   11
#  Outer Iter.  1  Inner Iter. 26:  Max. DC =  0.9464E-07  [K,I,J]    4    3   22
#  Transport Step:    2   Step Size:  7.7954E-02 Total Elapsed Time:   12.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2698E-02  [K,I,J]    6    2    6
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.7404E-03  [K,I,J]    3    2    7
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1511E-03  [K,I,J]    8    2    4
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1312E-04  [K,I,J]    4    1    5
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4915E-05  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1332E-05  [K,I,J]    5    3   15
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4382E-06  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.6786E-07  [K,I,J]    4    3   17
#
#   STRESS PERIOD    1 TIME STEP   13 FROM TIME =   12.000     TO    13.000
#
#  Transport Step:    1   Step Size:  0.9219     Total Elapsed Time:   12.922
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.3049E-01  [K,I,J]   16    1    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1438E-01  [K,I,J]    8    1    4
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7863E-02  [K,I,J]    9    2    4
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6854E-02  [K,I,J]    3    2    7
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4814E-02  [K,I,J]    2    2    7
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2016E-02  [K,I,J]   16    3    3
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.7579E-03  [K,I,J]    9    2    5
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3821E-03  [K,I,J]   11    2    3
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1492E-03  [K,I,J]   11    2    4
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.7236E-04  [K,I,J]    3    3   15
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.6233E-04  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.5943E-04  [K,I,J]    3    3   15
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.5183E-04  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.6379E-04  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.7283E-04  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.2911E-04  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.4779E-05  [K,I,J]    3    3   18
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.3718E-05  [K,I,J]   40    3    4
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.3532E-06  [K,I,J]   40    3    4
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.1908E-04  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.7292E-04  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =  0.2404E-04  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 23:  Max. DC =  0.2859E-05  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 24:  Max. DC =  0.7257E-06  [K,I,J]   40    2    3
#  Outer Iter.  1  Inner Iter. 25:  Max. DC =  0.1882E-06  [K,I,J]   40    2    4
#  Outer Iter.  1  Inner Iter. 26:  Max. DC =  0.8704E-07  [K,I,J]    4    3   22
#  Transport Step:    2   Step Size:  7.8134E-02 Total Elapsed Time:   13.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2491E-02  [K,I,J]    6    3    7
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6913E-03  [K,I,J]    3    2    7
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1415E-03  [K,I,J]    8    2    4
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1391E-04  [K,I,J]    5    3   15
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.5692E-05  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1477E-05  [K,I,J]    5    3   15
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.4129E-06  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.6783E-07  [K,I,J]    4    3   17
#
#   STRESS PERIOD    1 TIME STEP   14 FROM TIME =   13.000     TO    14.000
#
#  Transport Step:    1   Step Size:  0.9217     Total Elapsed Time:   13.922
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2927E-01  [K,I,J]   16    1    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1355E-01  [K,I,J]    8    1    4
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.7329E-02  [K,I,J]    9    2    4
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.6395E-02  [K,I,J]    3    2    7
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4483E-02  [K,I,J]    2    2    7
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1962E-02  [K,I,J]   16    3    3
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.7395E-03  [K,I,J]    9    2    5
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3493E-03  [K,I,J]   11    2    3
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1442E-03  [K,I,J]   11    2    4
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.7234E-04  [K,I,J]    3    3   15
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.6402E-04  [K,I,J]    3    3   16
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.6237E-04  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.5130E-04  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.6484E-04  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.7661E-04  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.3211E-04  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.4361E-05  [K,I,J]    4    3   19
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.3086E-05  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.5379E-05  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.3659E-03  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.4208E-03  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 22:  Max. DC =  0.1233E-04  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 23:  Max. DC =  0.2330E-05  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 24:  Max. DC =  0.6098E-06  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter. 25:  Max. DC =  0.1468E-06  [K,I,J]   40    2    4
#  Outer Iter.  1  Inner Iter. 26:  Max. DC =  0.6930E-07  [K,I,J]    4    3   22
#  Transport Step:    2   Step Size:  7.8317E-02 Total Elapsed Time:   14.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2348E-02  [K,I,J]    6    3    7
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.6507E-03  [K,I,J]    3    2    8
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1322E-03  [K,I,J]    8    2    4
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.1559E-04  [K,I,J]    5    3   15
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.6439E-05  [K,I,J]    4    3   15
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1577E-05  [K,I,J]    5    3   15
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.3780E-06  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.6760E-07  [K,I,J]    4    3   17
#
#   STRESS PERIOD    1 TIME STEP   15 FROM TIME =   14.000     TO    15.000
#
#  Transport Step:    1   Step Size:  0.9215     Total Elapsed Time:   14.921
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.2804E-01  [K,I,J]   16    1    2
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.1274E-01  [K,I,J]    8    1    4
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.6824E-02  [K,I,J]    9    2    4
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.5989E-02  [K,I,J]    3    2    8
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.4206E-02  [K,I,J]    2    2    8
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.1903E-02  [K,I,J]   16    3    3
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.7185E-03  [K,I,J]    9    2    5
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.3214E-03  [K,I,J]   11    2    3
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.1401E-03  [K,I,J]   11    2    4
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.7317E-04  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.6775E-04  [K,I,J]    3    3   16
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.6873E-04  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.5468E-04  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.6388E-04  [K,I,J]    4    3   16
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.6299E-04  [K,I,J]    4    3   17
# ...
#
#  Transport Step:    1   Step Size:  0.8994     Total Elapsed Time:   94.899
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6561E-02  [K,I,J]   24    3    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2579E-02  [K,I,J]   15    3   10
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1518E-02  [K,I,J]    9    1   19
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9148E-03  [K,I,J]    3    1   22
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.9284E-03  [K,I,J]    2    3   27
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6239E-03  [K,I,J]    3    1   27
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2750E-03  [K,I,J]    3    1   28
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1759E-03  [K,I,J]    9    1   11
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.8186E-04  [K,I,J]    8    1   11
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.4045E-04  [K,I,J]    8    1   12
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.2756E-04  [K,I,J]    5    3   21
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.2439E-04  [K,I,J]    5    3   20
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1576E-04  [K,I,J]    4    3   20
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.8132E-05  [K,I,J]    5    3   20
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.4271E-05  [K,I,J]    3    3   21
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.2335E-05  [K,I,J]    3    2   21
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.1802E-05  [K,I,J]    3    1   21
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.1048E-05  [K,I,J]    3    1   20
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.5570E-06  [K,I,J]    2    1   20
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.2739E-06  [K,I,J]    3    1   22
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.5505E-07  [K,I,J]    2    1   24
#  Transport Step:    2   Step Size:  0.1006     Total Elapsed Time:   95.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6785E-03  [K,I,J]   24    3    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2076E-03  [K,I,J]    3    1   22
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9316E-04  [K,I,J]    4    3   22
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2528E-04  [K,I,J]    5    3   22
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8559E-05  [K,I,J]    4    3   22
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2102E-05  [K,I,J]    5    3   22
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.5657E-06  [K,I,J]    3    2   28
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2035E-06  [K,I,J]    3    2   27
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.6824E-07  [K,I,J]    4    2   29
#
#   STRESS PERIOD    1 TIME STEP   96 FROM TIME =   95.000     TO    96.000
#
#  Transport Step:    1   Step Size:  0.8991     Total Elapsed Time:   95.899
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6542E-02  [K,I,J]   24    3    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2555E-02  [K,I,J]   15    3   10
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1510E-02  [K,I,J]    9    1   19
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.9058E-03  [K,I,J]    3    1   22
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.9223E-03  [K,I,J]    2    3   27
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6222E-03  [K,I,J]    3    1   27
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2739E-03  [K,I,J]    3    1   28
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1726E-03  [K,I,J]    9    1   11
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.8089E-04  [K,I,J]    9    1   12
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.4020E-04  [K,I,J]    8    1   12
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.2723E-04  [K,I,J]    5    3   21
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.2410E-04  [K,I,J]    5    3   20
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1558E-04  [K,I,J]    4    3   20
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.8057E-05  [K,I,J]    5    3   20
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.4237E-05  [K,I,J]    3    3   21
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.2302E-05  [K,I,J]    3    2   21
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.1778E-05  [K,I,J]    3    1   21
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.1036E-05  [K,I,J]    3    1   20
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.5499E-06  [K,I,J]    2    1   20
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.2730E-06  [K,I,J]    3    1   22
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.5766E-07  [K,I,J]    2    1   24
#  Transport Step:    2   Step Size:  0.1009     Total Elapsed Time:   96.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6785E-03  [K,I,J]   24    3    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2064E-03  [K,I,J]    3    1   22
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9283E-04  [K,I,J]    4    3   22
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2522E-04  [K,I,J]    5    3   22
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8534E-05  [K,I,J]    4    3   22
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2111E-05  [K,I,J]    5    3   22
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.5687E-06  [K,I,J]    3    2   28
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2045E-06  [K,I,J]    3    2   27
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.6882E-07  [K,I,J]    4    2   29
#
#   STRESS PERIOD    1 TIME STEP   97 FROM TIME =   96.000     TO    97.000
#
#  Transport Step:    1   Step Size:  0.8988     Total Elapsed Time:   96.899
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6515E-02  [K,I,J]   24    3    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2531E-02  [K,I,J]   15    3   10
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1501E-02  [K,I,J]    9    1   19
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8992E-03  [K,I,J]    3    3   27
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.9161E-03  [K,I,J]    2    3   27
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6203E-03  [K,I,J]    3    1   27
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2728E-03  [K,I,J]    3    1   28
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1694E-03  [K,I,J]    9    1   11
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.8012E-04  [K,I,J]    9    1   12
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.3995E-04  [K,I,J]    8    1   12
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.2691E-04  [K,I,J]    5    3   21
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.2381E-04  [K,I,J]    5    3   20
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1541E-04  [K,I,J]    4    3   20
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.7981E-05  [K,I,J]    5    3   20
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.4204E-05  [K,I,J]    3    3   21
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.2271E-05  [K,I,J]    3    2   21
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.1754E-05  [K,I,J]    3    1   21
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.1025E-05  [K,I,J]    3    1   20
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.5430E-06  [K,I,J]    2    1   20
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.2721E-06  [K,I,J]    3    1   22
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.6011E-07  [K,I,J]    2    1   24
#  Transport Step:    2   Step Size:  0.1012     Total Elapsed Time:   97.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6777E-03  [K,I,J]   24    3    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2052E-03  [K,I,J]    3    1   22
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9249E-04  [K,I,J]    4    3   22
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2516E-04  [K,I,J]    5    3   22
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8508E-05  [K,I,J]    4    3   22
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2119E-05  [K,I,J]    5    3   22
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.5715E-06  [K,I,J]    3    2   28
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2054E-06  [K,I,J]    3    2   27
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.6939E-07  [K,I,J]    4    2   29
#
#   STRESS PERIOD    1 TIME STEP   98 FROM TIME =   97.000     TO    98.000
#
#  Transport Step:    1   Step Size:  0.8986     Total Elapsed Time:   97.899
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6481E-02  [K,I,J]   24    3    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2507E-02  [K,I,J]   15    3   10
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1492E-02  [K,I,J]    9    1   19
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8943E-03  [K,I,J]    3    3   27
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.9099E-03  [K,I,J]    2    3   27
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6183E-03  [K,I,J]    3    1   27
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2718E-03  [K,I,J]    3    1   28
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1662E-03  [K,I,J]    9    1   11
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.7934E-04  [K,I,J]    9    1   12
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.3969E-04  [K,I,J]    8    1   12
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.2660E-04  [K,I,J]    5    3   21
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.2352E-04  [K,I,J]    5    3   20
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1524E-04  [K,I,J]    4    3   20
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.7905E-05  [K,I,J]    5    3   20
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.4171E-05  [K,I,J]    3    3   21
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.2240E-05  [K,I,J]    3    2   21
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.1730E-05  [K,I,J]    3    1   21
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.1013E-05  [K,I,J]    3    1   20
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.5361E-06  [K,I,J]    2    1   20
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.2711E-06  [K,I,J]    3    1   22
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.6241E-07  [K,I,J]    2    1   24
#  Transport Step:    2   Step Size:  0.1014     Total Elapsed Time:   98.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6761E-03  [K,I,J]   24    3    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2040E-03  [K,I,J]    3    1   22
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9216E-04  [K,I,J]    4    3   22
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2509E-04  [K,I,J]    5    3   22
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8482E-05  [K,I,J]    4    3   22
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2127E-05  [K,I,J]    5    3   22
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.5743E-06  [K,I,J]    3    2   28
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2063E-06  [K,I,J]    3    2   27
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.6995E-07  [K,I,J]    4    2   29
#
#   STRESS PERIOD    1 TIME STEP   99 FROM TIME =   98.000     TO    99.000
#
#  Transport Step:    1   Step Size:  0.8983     Total Elapsed Time:   98.898
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6438E-02  [K,I,J]   24    3    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2484E-02  [K,I,J]   15    3   10
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1483E-02  [K,I,J]    9    1   19
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8894E-03  [K,I,J]    3    3   27
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.9036E-03  [K,I,J]    2    3   27
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6162E-03  [K,I,J]    3    1   27
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2708E-03  [K,I,J]    3    1   28
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1631E-03  [K,I,J]    9    1   11
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.7855E-04  [K,I,J]    9    1   12
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.3944E-04  [K,I,J]    8    1   12
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.2628E-04  [K,I,J]    5    3   21
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.2324E-04  [K,I,J]    5    3   20
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1507E-04  [K,I,J]    4    3   20
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.7830E-05  [K,I,J]    5    3   20
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.4137E-05  [K,I,J]    3    3   21
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.2210E-05  [K,I,J]    3    2   21
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.1706E-05  [K,I,J]    3    1   21
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.1002E-05  [K,I,J]    3    1   20
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.5294E-06  [K,I,J]    2    1   20
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.2700E-06  [K,I,J]    3    1   22
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.6457E-07  [K,I,J]    2    1   24
#  Transport Step:    2   Step Size:  0.1017     Total Elapsed Time:   99.000
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6739E-03  [K,I,J]   24    3    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2029E-03  [K,I,J]    3    1   22
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9182E-04  [K,I,J]    4    3   22
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2503E-04  [K,I,J]    5    3   22
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8455E-05  [K,I,J]    4    3   22
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2135E-05  [K,I,J]    5    3   22
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.5768E-06  [K,I,J]    3    2   28
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2071E-06  [K,I,J]    3    2   27
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.7049E-07  [K,I,J]    4    2   29
#
#   STRESS PERIOD    1 TIME STEP  100 FROM TIME =   99.000     TO    100.00
#
#  Transport Step:    1   Step Size:  0.8980     Total Elapsed Time:   99.898
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6389E-02  [K,I,J]   24    3    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2460E-02  [K,I,J]   15    3   10
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.1474E-02  [K,I,J]    9    1   19
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.8844E-03  [K,I,J]    3    3   27
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8972E-03  [K,I,J]    2    3   27
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.6141E-03  [K,I,J]    3    1   27
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.2699E-03  [K,I,J]    3    1   28
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.1600E-03  [K,I,J]    9    1   11
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.7776E-04  [K,I,J]    9    1   12
#  Outer Iter.  1  Inner Iter. 10:  Max. DC =  0.3919E-04  [K,I,J]    8    1   12
#  Outer Iter.  1  Inner Iter. 11:  Max. DC =  0.2598E-04  [K,I,J]    5    3   21
#  Outer Iter.  1  Inner Iter. 12:  Max. DC =  0.2296E-04  [K,I,J]    5    3   20
#  Outer Iter.  1  Inner Iter. 13:  Max. DC =  0.1491E-04  [K,I,J]    4    3   20
#  Outer Iter.  1  Inner Iter. 14:  Max. DC =  0.7754E-05  [K,I,J]    5    3   20
#  Outer Iter.  1  Inner Iter. 15:  Max. DC =  0.4104E-05  [K,I,J]    3    3   21
#  Outer Iter.  1  Inner Iter. 16:  Max. DC =  0.2182E-05  [K,I,J]    3    2   21
#  Outer Iter.  1  Inner Iter. 17:  Max. DC =  0.1682E-05  [K,I,J]    3    1   21
#  Outer Iter.  1  Inner Iter. 18:  Max. DC =  0.9912E-06  [K,I,J]    3    1   20
#  Outer Iter.  1  Inner Iter. 19:  Max. DC =  0.5230E-06  [K,I,J]    4    1   19
#  Outer Iter.  1  Inner Iter. 20:  Max. DC =  0.2689E-06  [K,I,J]    3    1   22
#  Outer Iter.  1  Inner Iter. 21:  Max. DC =  0.6659E-07  [K,I,J]    2    1   24
#  Transport Step:    2   Step Size:  0.1020     Total Elapsed Time:   100.00
#  Outer Iter.  1  Inner Iter.  1:  Max. DC =  0.6710E-03  [K,I,J]   24    3    3
#  Outer Iter.  1  Inner Iter.  2:  Max. DC =  0.2017E-03  [K,I,J]    3    1   22
#  Outer Iter.  1  Inner Iter.  3:  Max. DC =  0.9147E-04  [K,I,J]    4    3   22
#  Outer Iter.  1  Inner Iter.  4:  Max. DC =  0.2496E-04  [K,I,J]    5    3   22
#  Outer Iter.  1  Inner Iter.  5:  Max. DC =  0.8428E-05  [K,I,J]    4    3   22
#  Outer Iter.  1  Inner Iter.  6:  Max. DC =  0.2142E-05  [K,I,J]    5    3   22
#  Outer Iter.  1  Inner Iter.  7:  Max. DC =  0.5793E-06  [K,I,J]    3    2   28
#  Outer Iter.  1  Inner Iter.  8:  Max. DC =  0.2079E-06  [K,I,J]    3    2   27
#  Outer Iter.  1  Inner Iter.  9:  Max. DC =  0.7102E-07  [K,I,J]    4    2   29
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2018/08/27 18:42:50
#  Elapsed run time: 12.815 Seconds
#
#  Normal termination of SEAWAT
#  Elapsed run time: 12.815 Seconds
#
#  Normal termination of SEAWAT

# %% [markdown]
# ## Post-processing results

# %%
#Post-processing functions
def plotdischarge(modelname,model_ws,color='w',kstpkper_ind=-1,scale=50):
    fname = os.path.join(model_ws, '' + modelname + '.cbc')
    budobj = flopy.utils.CellBudgetFile(fname)
    qx = budobj.get_data(text='FLOW RIGHT FACE')[kstpkper_ind]
    qz = budobj.get_data(text='FLOW LOWER FACE')[kstpkper_ind]
    
    # Average flows to cell centers
    qx_avg = np.empty(qx.shape, dtype=qx.dtype)
    qx_avg[:, :, 1:] = 0.5 * (qx[:, :, 0:ncol-1] + qx[:, :, 1:ncol])
    qx_avg[:, :, 0] = 0.5 * qx[:, :, 0]
    qz_avg = np.empty(qz.shape, dtype=qz.dtype)
    qz_avg[1:, :, :] = 0.5 * (qz[0:nlay-1, :, :] + qz[1:nlay, :, :])
    qz_avg[0, :, :] = 0.5 * qz[0, :, :]
    
    y, x, z = dis.get_node_coordinates()
    X, Z = np.meshgrid(x, z[:, 0, 0])
    iskip = 1 #how many cells to skip, 1 means plot every cell
    
    ax = plt.gca()
    cpatchcollection = ax.quiver(X[::iskip, ::iskip], Z[::iskip, ::iskip],
              qx_avg[::iskip, 0, ::iskip], -qz_avg[::iskip, 0, ::iskip],
              color=color, scale=scale, headwidth=4, headlength=2,
              headaxislength=1, width=0.0025)
    return cpatchcollection

def permute_kstpkper(ucnobj):
    kstpkper = ucnobj.get_kstpkper()
    kstpkper_unique = []
    index_unique = []
    niter = 0
    for entry in kstpkper:
        if not entry in kstpkper_unique:
            kstpkper_unique.append(entry)
            index_unique.append(niter)
        niter += 1
    return kstpkper_unique, index_unique

def kstpkper_from_time(ucnobj,tottim):
    kstpkpers = ucnobj.get_kstpkper()
    times = ucnobj.get_times()
    timeind = times.index(tottim)    
    kstpkper = kstpkpers[timeind]
    return kstpkper

def kstpkper_ind_from_kstpkper(ucnobj,kstpkper=(0,0)):
    kstpkpers = ucnobj.get_kstpkper()
    kstpkper_unique = permute_kstpkper(ucnobj)[0]
    kstpkper_ind = kstpkper_unique.index(kstpkper)
    return kstpkper_ind

def get_ocean_outflow(m,ocean_coords):
    fname = os.path.join(m.model_ws, m.name + '.cbc') 
    budobj = flopy.utils.CellBudgetFile(fname)
    qx = budobj.get_data(text='FLOW RIGHT FACE')[-1]
    qz = budobj.get_data(text='FLOW LOWER FACE')[-1]
    #ocean_flow = np.sqrt(np.square(-qz[ocean_coords]) + np.square(qx[ocean_coords]))
    ocean_flow = -qz[ocean_coords]
    return ocean_flow

def get_salt_outflow(m,ocean_coords,totim=None):
    fname = os.path.join(m.model_ws, 'MT3D001.UCN')
    ucnobj = flopy.utils.binaryfile.UcnFile(fname)
    if times==None:
        totim = ucnobj.get_times()[-1]
    ocean_conc = ucnobj.get_data(totim=totim)[ocean_coords]
    return ocean_conc
    
def plot_background(mm,array,label=None):
    if label==None:
        label = [ k for k,v in locals().items() if v is array][0]
    cpatchcollection = mm.plot_array(array,cmap='jet')
    cpatchcollection.set_label(label)
    return cpatchcollection,label

# %% [markdown]
# #Temporarily removed... the 'constant head' data doesn't seem right...
# def get_ocean_outflow(m,ocean_col):
#     fname = os.path.join(m.model_ws, m.name + '.cbc')
#     budobj = flopy.utils.CellBudgetFile(fname)
#     ch = budobj.get_data(text='CONSTANT HEAD')
#     ocean_col_vec = np.arange(ocean_col[0],ocean_col[1]+1)
#     ocean_nodes = np.ravel_multi_index([np.zeros(ocean_col_vec.size,dtype=int), #nodes in constant head flow file are 1-based
#                                       np.zeros(ocean_col_vec.size,dtype=int),   #create a list of node numbers for ocean cells
#                                       ocean_col_vec],
#                                      (m.dis.nlay,m.dis.nrow,m.dis.ncol)) + 1
#
#     ocean_flow =  [ch[-1]['q'][i] for i,node in enumerate(ch[-1]['node']) if node in ocean_nodes]
#     tot_flow = np.sum(ocean_flow)
#     return flow

# %%
# Extract heads
fname = os.path.join(model_ws, '' + modelname + '.hds')
hdobj = flopy.utils.binaryfile.HeadFile(fname)
times = hdobj.get_times()
hds = hdobj.get_data(totim=times[-1])
hds[np.where(ibound != 1)] = np.nan

# Extract salinity
fname = os.path.join(model_ws, 'MT3D001.UCN')
ucnobj = flopy.utils.binaryfile.UcnFile(fname)
times = ucnobj.get_times()
conc = ucnobj.get_data(totim=times[-1])
conc[np.where(ibound != 1)] = np.nan
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8309b14b752d> in <module>()
#       1 # Extract heads
# ----> 2 fname = os.path.join(model_ws, '' + modelname + '.hds')
#       3 hdobj = flopy.utils.binaryfile.HeadFile(fname)
#       4 times = hdobj.get_times()
#       5 hds = hdobj.get_data(totim=times[-1])
#
# NameError: name 'os' is not defined

# %%
# Make head and quiver plot
import utils
printyn = 0
f, axs = plt.subplots(2,1, sharex=True, figsize=(15, 8),
                     gridspec_kw = {'height_ratios':[1, 7]})
plt.tight_layout()

#Plot discharge and ibound
mm = flopy.plot.ModelCrossSection(ax=axs[1], model=m, line={'row':1})
cpatchcollection,label = plot_background(mm,hds,'hds')
mm.plot_ibound()
plotdischarge(m.name,model_ws,color='white',kstpkper_ind=-1,scale=1);
plt.xlabel('Distance (m)')
plt.ylabel('Height (m)')

#plot SGD
ocean_flow = 100 * np.asarray(utils.get_ocean_outflow_chd(m,ocean_bool))

plt.sca(axs[0]) #set current axes
plt.bar(ocean_col_vec[2]+delc/2,ocean_flow)
axs[0].axhline()
axs[0].set_ylim(np.min(ocean_flow)*0.9,np.max(ocean_flow)*1.1)
plt.ylabel('SGD (cm/d)')
axs[0].annotate('total flow = ' + str(np.sum(ocean_flow)) + ' cm/d', xy=(.1,.5),
            xytext=(0.1, 0.5), xycoords='axes fraction', textcoords='axes fraction')

#Plot salt content of cells beneath outflow
ocean_below_vec = (ocean_col_vec[0]+1,) +ocean_col_vec[1:]
ocean_salt_outflow = get_salt_outflow(m,ocean_below_vec)
axs02 = axs[0].twinx()
plt.plot(ocean_col_vec[2]+delc/2 , ocean_salt_outflow,'r.')
#axs02.set_ylim(0,Csalt)

plt.ylabel('conc of underlying (g/L)')

#align plots and set colorbar
f.subplots_adjust(right=0.93)
cbar_ax = f.add_axes([0.95, 0.1, 0.02, 0.7])
cb = f.colorbar(cpatchcollection,cax=cbar_ax)
cb.set_label(label)
if printyn == 1:
    plt.savefig(os.path.join(model_ws, modelname + '_flow_vectors.png'),dpi=300)
plt.show()
# Out:
# /Users/ianpg/anaconda/lib/python3.6/site-packages/flopy/utils/binaryfile.py:756: FutureWarning: Assignment between structured arrays with different field names will change in numpy 1.14.
#
# Previously fields in the dst would be set to the value of the identically-named field in the src. In numpy 1.14 fields will instead be assigned 'by position': The Nth field of the dst will be set to the Nth field of the src array.
#
# See the release notes for details
#   header2 = header2.astype(self.header2_dtype)

# %%
# Load the mas file and make a plot of total mass in aquifer versus time
fname = os.path.join(model_ws, 'MT3D001.MAS')
mas = flopy.mt3d.Mt3dms.load_mas(fname)
f = plt.figure()
ax = f.add_subplot(1, 1, 1)
lines = ax.plot(mas.time, mas.total_mass)
mas[0]
plt.show()

# %% [markdown]
# #Issue: which "flow" is the correct flow?
#     #Can get flow from the cell-by-cell file in either FLOW RIGHT FACE and FLOW LOWER FACE
#     # Or from the constant head flow
#
# ocean_flow = get_ocean_outflow(m,ocean_col);
# print('total flow into ocean cells from const. head flow:',-np.sum(ocean_flow),'m^3/d')
#
# fname = os.path.join(model_ws, '' + modelname + '.cbc')
# budobj = flopy.utils.CellBudgetFile(fname)
# qx = budobj.get_data(text='FLOW RIGHT FACE')[-1]
# qz = budobj.get_data(text='FLOW LOWER FACE')[-1]
# tot_flow = np.sum( np.sqrt(np.square(-qz[ocean_coords]) + np.square(qx[ocean_coords])))
# print('Total flow from lower-right face in cbc file', tot_flow ,'m^3/d' )

# %%
ocean_flow = 100 * np.asarray(utils.get_ocean_outflow_chd(m,ocean_col))
print(ocean_flow)
# Out:
# /Users/ianpg/anaconda/lib/python3.6/site-packages/flopy/utils/binaryfile.py:756: FutureWarning: Assignment between structured arrays with different field names will change in numpy 1.14.
#
# Previously fields in the dst would be set to the value of the identically-named field in the src. In numpy 1.14 fields will instead be assigned 'by position': The Nth field of the dst will be set to the Nth field of the src array.
#
# See the release notes for details
#   header2 = header2.astype(self.header2_dtype)
# [ 23.3296833   12.69997025   7.57542849   4.9172473    3.4799006
#    2.67985511   2.22119117   1.94806755   1.77697265   1.66282153
#    1.58089435   1.51782739   1.46626592   1.42211628   1.38306344
#    1.34776759   1.31541133   1.28559148   1.25803149   1.23253107
#    1.20894587   1.18716562   1.16706693   1.14854836   1.13151932
#    1.1158973    1.10160744   1.08858287   1.07676399   1.06609797
#    1.05653834   1.04804397   1.04057896   1.03411222   1.02861714
#    1.02407134   1.02045631   1.01775765   1.01596439   1.01506948]

# %%
def get_ocean_outflow_chd(m,ocean_col):
    fname = os.path.join(m.model_ws,m.name + '.cbc')
    budobj = flopy.utils.CellBudgetFile(fname)
    ch = budobj.get_data(text='CONSTANT HEAD')
    ocean_flow = []
    for node,flux in ch[-1]:
        if node in range(ocean_col[0],ocean_col[1]+2):
            ocean_flow.append(-flux)
    return np.asarray(ocean_flow)

# %%
fname = os.path.join(m.model_ws,m.name + '.cbc')
budobj = flopy.utils.CellBudgetFile(fname)
ch = budobj.get_data(text='CONSTANT HEAD')
for node,flux in ch[-1]:
    print(node,flux)
# Out:
# /Users/ianpg/anaconda/lib/python3.6/site-packages/flopy/utils/binaryfile.py:756: FutureWarning: Assignment between structured arrays with different field names will change in numpy 1.14.
#
# Previously fields in the dst would be set to the value of the identically-named field in the src. In numpy 1.14 fields will instead be assigned 'by position': The Nth field of the dst will be set to the Nth field of the src array.
#
# See the release notes for details
#   header2 = header2.astype(self.header2_dtype)
# 1 0.0242437
# 31 -0.00272918
# 32 -0.00268549
# 33 -0.00263946
# 34 -0.00259559
# 35 -0.0025596
# 36 -0.00246229
# 37 -0.00221326
# 38 -0.0020003
# 39 -0.00183721
# 40 -0.00173432
# 41 -0.0017394
# 42 -0.00156783
# 43 -0.00139634
# 44 -0.0012861
# 45 -0.00120008
# 46 -0.00112258
# 47 -0.0010791
# 48 -0.00106006
# 49 -0.00103199
# 50 -0.00100064
# 51 -0.000968897
# 52 -0.000938125
# 53 -0.000908957
# 54 -0.000881698
# 55 -0.000856474
# 56 -0.000833219
# 57 -0.000811841
# 58 -0.000792259
# 59 -0.000774401
# 60 -0.00075821
# 61 -0.000743634
# 62 -0.000730631
# 63 -0.000719161
# 64 -0.000709193
# 65 -0.000700699
# 66 -0.000693655
# 67 -0.000688042
# 68 -0.000683846
# 69 -0.000681054
# 70 -0.00067966
# 71 0.0242439
# 101 -0.00272791
# 102 -0.00268233
# 103 -0.00263265
# 104 -0.00258216
# 105 -0.00253701
# 106 -0.00244152
# 107 -0.00224887
# 108 -0.00207996
# 109 -0.00193422
# 110 -0.00180929
# 111 -0.00174936
# 112 -0.00162179
# 113 -0.00147949
# 114 -0.001371
# 115 -0.0012741
# 116 -0.00117396
# 117 -0.00109676
# 118 -0.00106899
# 119 -0.00103556
# 120 -0.00100167
# 121 -0.000968901
# 122 -0.000937789
# 123 -0.000908595
# 124 -0.000881474
# 125 -0.000856361
# 126 -0.000833166
# 127 -0.000811818
# 128 -0.000792248
# 129 -0.000774397
# 130 -0.000758208
# 131 -0.000743634
# 132 -0.00073063
# 133 -0.000719161
# 134 -0.000709193
# 135 -0.000700699
# 136 -0.000693655
# 137 -0.000688042
# 138 -0.000683846
# 139 -0.000681054
# 140 -0.00067966
# 141 0.0242441
# 171 -0.00272645
# 172 -0.00267858
# 173 -0.00262397
# 174 -0.00256209
# 175 -0.0024858
# 176 -0.00236655
# 177 -0.00224452
# 178 -0.00212213
# 179 -0.00200045
# 180 -0.00188024
# 181 -0.0017618
# 182 -0.00165448
# 183 -0.00154806
# 184 -0.00144336
# 185 -0.00134054
# 186 -0.00123942
# 187 -0.00113991
# 188 -0.00108323
# 189 -0.00104035
# 190 -0.00100306
# 191 -0.000969057
# 192 -0.00093755
# 193 -0.000908318
# 194 -0.000881301
# 195 -0.000856265
# 196 -0.000833118
# 197 -0.000811795
# 198 -0.000792238
# 199 -0.000774392
# 200 -0.000758206
# 201 -0.000743633
# 202 -0.00073063
# 203 -0.000719161
# 204 -0.000709193
# 205 -0.000700699
# 206 -0.000693655
# 207 -0.000688042
# 208 -0.000683846
# 209 -0.000681054
# 210 -0.00067966
# 211 0.0251365
# 281 0.0251366
# 351 0.0251367
# 421 0.0329082
# 491 0.0329084
# 561 0.0329087
# 631 0.0259933
# 701 0.0259937
# 771 0.0259942
# 841 0.0238715
# 911 0.0238424
# 981 0.0238136
# 1051 0.00030373
# 1121 0.000216826
# 1191 0.00513455
# 1261 0.000261461
# 1331 0.000184011
# 1401 0.00439741
# 1471 0.0162305
# 1541 0.0162052
# 1611 0.0161808
# 1681 0.00855751
# 1751 0.00855607
# 1821 0.00855505
# 1891 0.00690928
# 1961 0.00690831
# 2031 0.00690764
# 2101 0.0081793
# 2171 0.00818016
# 2241 0.00818128
# 2311 0.00837998
# 2381 0.00838061
# 2451 0.00838173
# 2521 0.00612893
# 2591 0.00604227
# 2661 0.00596459
# 2731 0.00154594
# 2801 0.00156553
# 2871 0.00159099
# 2941 0.00482314
# 3011 0.00498753
# 3081 0.00518671
# 3151 0.00166385
# 3221 0.00293324
# 3291 0.00679848
# 3361 0.00149685
# 3431 0.00257914
# 3501 0.00590436
# 3571 0.00148707
# 3641 0.00174752
# 3711 0.00221558
# 3781 0.00121237
# 3851 0.00144786
# 3921 0.00185721
# 3991 0.00128372
# 4061 0.00121639
# 4131 0.00116859
# 4201 0.00218502
# 4271 0.0019967
# 4341 0.00186196
# 4411 0.00206289
# 4481 0.00206983
# 4551 0.00207689
# 4621 0.00110901
# 4691 0.00111199
# 4761 0.00111519
# 4831 0.00077883
# 4901 0.000781274
# 4971 0.000783973
# 5041 7.6463e-05
# 5111 7.83499e-05
# 5181 8.051e-05
# 5251 -0.000487562
# 5321 -0.00046407
# 5391 -0.000443644
# 5461 -0.000542738
# 5531 -0.000527484
# 5601 -0.0005144
# 5671 -0.00181548
# 5741 -0.00181325
# 5811 -0.00181149
# 5881 -0.00187819
# 5951 -0.00186965
# 6021 -0.00186219
# 6091 -0.00108342
# 6161 -0.00107698
# 6231 -0.00107215
# 6301 -0.00362816
# 6371 -0.00362802
# 6441 -0.00362926
# 6511 -0.00779168
# 6581 -0.000157772
# 6651 -0.000149589
# 6721 -0.00535867
# 6791 -0.000135561
# 6861 -0.000148797
# 6931 -0.00385636
# 7001 -0.00385821
# 7071 -0.00386105
# 7141 -0.00936836
# 7211 -0.00936657
# 7281 -0.00936582
# 7351 -0.0127588
# 7421 -0.0127581
# 7491 -0.0127578
# 7561 -0.0186594
# 7631 -0.0186586
# 7701 -0.0186579
# 7771 -0.0181891
# 7841 -0.0181509
# 7911 -0.0181138
# 7981 -0.02685
# 8051 -0.0267982
# 8121 -0.0267479
# 8191 -0.0617594
# 8261 -0.0617569
# 8331 -0.0617545

# %%
outflow = get_ocean_outflow_chd(m,ocean_bool)
plt.imshow(outflow[:,0,:])
# Out:
# /Users/ianpg/anaconda/lib/python3.6/site-packages/flopy/utils/binaryfile.py:756: FutureWarning: Assignment between structured arrays with different field names will change in numpy 1.14.
#
# Previously fields in the dst would be set to the value of the identically-named field in the src. In numpy 1.14 fields will instead be assigned 'by position': The Nth field of the dst will be set to the Nth field of the src array.
#
# See the release notes for details
#   header2 = header2.astype(self.header2_dtype)

# %%
flx
# Out:
# array([ 0.00272918,  0.00268549,  0.00263946,  0.00259559,  0.0025596 ,
#         0.00246229,  0.00221326,  0.0020003 ,  0.00183721,  0.00173432,
#         0.0017394 ,  0.00156783,  0.00139634,  0.0012861 ,  0.00120008,
#         0.00112258,  0.0010791 ,  0.00106006,  0.00103199,  0.00100064,
#         0.0009689 ,  0.00093813,  0.00090896,  0.0008817 ,  0.00085647,
#         0.00083322,  0.00081184,  0.00079226,  0.0007744 ,  0.00075821,
#         0.00074363,  0.00073063,  0.00071916,  0.00070919,  0.0007007 ,
#         0.00069365,  0.00068804,  0.00068385,  0.00068105,  0.00067966,
#         0.00272791,  0.00268233,  0.00263265,  0.00258216,  0.00253701,
#         0.00244152,  0.00224887,  0.00207996,  0.00193422,  0.00180929,
#         0.00174936,  0.00162179,  0.00147949,  0.001371  ,  0.0012741 ,
#         0.00117396,  0.00109676,  0.00106899,  0.00103556,  0.00100167,
#         0.0009689 ,  0.00093779,  0.0009086 ,  0.00088147,  0.00085636,
#         0.00083317,  0.00081182,  0.00079225,  0.0007744 ,  0.00075821,
#         0.00074363,  0.00073063,  0.00071916,  0.00070919,  0.0007007 ,
#         0.00069365,  0.00068804,  0.00068385,  0.00068105,  0.00067966,
#         0.00272645,  0.00267858,  0.00262397,  0.00256209,  0.0024858 ,
#         0.00236655,  0.00224452,  0.00212213,  0.00200045,  0.00188024,
#         0.0017618 ,  0.00165448,  0.00154806,  0.00144336,  0.00134054,
#         0.00123942,  0.00113991,  0.00108323,  0.00104035,  0.00100306,
#         0.00096906,  0.00093755,  0.00090832,  0.0008813 ,  0.00085627,
#         0.00083312,  0.0008118 ,  0.00079224,  0.00077439,  0.00075821,
#         0.00074363,  0.00073063,  0.00071916,  0.00070919,  0.0007007 ,
#         0.00069365,  0.00068804,  0.00068385,  0.00068105,  0.00067966], dtype=float32)
